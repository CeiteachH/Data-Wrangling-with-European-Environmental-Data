# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os
import joblib
from pathlib import Path

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
POLLUTANT = "SO2"

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
RESULTS_SAVE_FOLDER = os.getenv("RESULTS_SAVE_FOLDER")

# %%
# reading in data
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
# saving results
RUN_ID = f"{COUNTRY_CODE}_{POLLUTANT}"

output_dir = Path(RESULTS_SAVE_FOLDER) / f"Results_{RUN_ID}"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# saving model
model_filename = output_dir / f"xgboost_model_{COUNTRY_CODE}_{POLLUTANT}.pkl"

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#                 Samplingpoint      Start     Value
# 0  IE/SPO.IE.IE001BPSample1_1 2013-01-01  4.919072
# 1  IE/SPO.IE.IE001BPSample1_1 2013-01-02  4.570028
# 2  IE/SPO.IE.IE001BPSample1_1 2013-01-03  4.116535
# 3  IE/SPO.IE.IE001BPSample1_1 2013-01-04  3.341625
# 4  IE/SPO.IE.IE001BPSample1_1 2013-01-05  3.654729
# 5  IE/SPO.IE.IE001BPSample1_1 2013-01-06  3.847764
# 6  IE/SPO.IE.IE001BPSample1_1 2013-01-07  4.654076
# 7  IE/SPO.IE.IE001BPSample1_1 2013-01-08  5.409590
# 8  IE/SPO.IE.IE001BPSample1_1 2013-01-09  7.644729
# 9  IE/SPO.IE.IE001BPSample1_1 2013-01-10  6.387694

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (53344, 11)
#        Start               Samplingpoint     Value  DayOfWeek  Month  \
# 0 2013-01-01  IE/SPO.IE.IE001BPSample1_1  4.919072          1      1
# 1 2013-01-02  IE/SPO.IE.IE001BPSample1_1  4.570028          2      1
# 2 2013-01-03  IE/SPO.IE.IE001BPSample1_1  4.116535          3      1
# 3 2013-01-04  IE/SPO.IE.IE001BPSample1_1  3.341625          4      1
# 4 2013-01-05  IE/SPO.IE.IE001BPSample1_1  3.654729          5      1
# 5 2013-01-06  IE/SPO.IE.IE001BPSample1_1  3.847764          6      1
# 6 2013-01-07  IE/SPO.IE.IE001BPSample1_1  4.654076          0      1
# 7 2013-01-08  IE/SPO.IE.IE001BPSample1_1  5.409590          1      1
# 8 2013-01-09  IE/SPO.IE.IE001BPSample1_1  7.644729          2      1
# 9 2013-01-10  IE/SPO.IE.IE001BPSample1_1  6.387694          3      1
#
#    DayOfYear  IsWeekend     Lag_1     Lag_7  Rolling_Mean_7D    Target
# 0          1          0       NaN       NaN              NaN  4.570028
# 1          2          0  4.919072       NaN              NaN  4.116535
# 2          3          0  4.570028       NaN              NaN  3.341625
# 3          4          0  4.116535       NaN         4.236815  3.654729
# 4          5          1  3.341625       NaN         4.120398  3.847764
# 5          6          1  3.654729       NaN         4.074959  4.654076
# 6          7          0  3.847764       NaN         4.157690  5.409590
# 7          8          0  4.654076  4.919072         4.227764  7.644729
# 8          9          0  5.409590  4.570028         4.667007  6.387694
# 9         10          0  7.644729  4.116535         4.991458  7.605014

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start               Samplingpoint     Value  DayOfWeek  Month  \
# 0 2013-01-01  IE/SPO.IE.IE001BPSample1_1  4.919072          1      1
# 1 2013-01-02  IE/SPO.IE.IE001BPSample1_1  4.570028          2      1
# 2 2013-01-03  IE/SPO.IE.IE001BPSample1_1  4.116535          3      1
# 3 2013-01-04  IE/SPO.IE.IE001BPSample1_1  3.341625          4      1
# 4 2013-01-05  IE/SPO.IE.IE001BPSample1_1  3.654729          5      1
# 5 2013-01-06  IE/SPO.IE.IE001BPSample1_1  3.847764          6      1
# 6 2013-01-07  IE/SPO.IE.IE001BPSample1_1  4.654076          0      1
# 7 2013-01-08  IE/SPO.IE.IE001BPSample1_1  5.409590          1      1
# 8 2013-01-09  IE/SPO.IE.IE001BPSample1_1  7.644729          2      1
# 9 2013-01-10  IE/SPO.IE.IE001BPSample1_1  6.387694          3      1
#
#    DayOfYear  IsWeekend     Lag_1     Lag_7  Rolling_Mean_7D    Target
# 0          1          0       NaN       NaN              NaN  4.570028
# 1          2          0  4.919072       NaN              NaN  4.116535
# 2          3          0  4.570028       NaN              NaN  3.341625
# 3          4          0  4.116535       NaN         4.236815  3.654729
# 4          5          1  3.341625       NaN         4.120398  3.847764
# 5          6          1  3.654729       NaN         4.074959  4.654076
# 6          7          0  3.847764       NaN         4.157690  5.409590
# 7          8          0  4.654076  4.919072         4.227764  7.644729
# 8          9          0  5.409590  4.570028         4.667007  6.387694
# 9         10          0  7.644729  4.116535         4.991458  7.605014
# Start                 0
# Samplingpoint         0
# Value               414
# DayOfWeek             0
# Month                 0
# DayOfYear             0
# IsWeekend             0
# Lag_1               759
# Lag_7              1786
# Rolling_Mean_7D     948
# Target                0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (20903, 9), Val shape: (8657, 9), Test shape: (9028, 9)

# %%
# save features 
feature_names = list(X_train.columns)
features_filename = output_dir / f"xgboost_features_{COUNTRY_CODE}_{POLLUTANT}.pkl"
joblib.dump(feature_names, features_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source\\SavedResults\\Results_IE_SO2\\xgboost_features_IE_SO2.pkl']

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 04:07:59,427] A new study created in memory with name: no-name-a6fcb1c5-2300-449e-81b4-5753203d3bc4
# [I 2026-03-12 04:08:04,841] Trial 0 finished with value: 2.6774410864902243 and parameters: {'n_estimators': 793, 'learning_rate': 0.02280082687667076, 'max_depth': 6, 'subsample': 0.5888659824343245, 'colsample_bytree': 0.9632258338032922, 'min_child_weight': 3, 'gamma': 3.0759953314944326, 'reg_lambda': 6.726274214511399}. Best is trial 0 with value: 2.6774410864902243.
# [I 2026-03-12 04:08:08,699] Trial 1 finished with value: 2.7427756723309438 and parameters: {'n_estimators': 355, 'learning_rate': 0.022435495982677408, 'max_depth': 8, 'subsample': 0.8707600391112031, 'colsample_bytree': 0.7380438560762044, 'min_child_weight': 6, 'gamma': 4.252587229944651, 'reg_lambda': 0.027338909351291976}. Best is trial 0 with value: 2.6774410864902243.
# [I 2026-03-12 04:08:21,616] Trial 2 finished with value: 2.6841208646600374 and parameters: {'n_estimators': 964, 'learning_rate': 0.009127270923732677, 'max_depth': 12, 'subsample': 0.7658525339509379, 'colsample_bytree': 0.7927989941429681, 'min_child_weight': 10, 'gamma': 3.5899877071095476, 'reg_lambda': 0.8505297467656716}. Best is trial 0 with value: 2.6774410864902243.
# [I 2026-03-12 04:08:36,630] Trial 3 finished with value: 2.677724247334501 and parameters: {'n_estimators': 889, 'learning_rate': 0.007213803850257574, 'max_depth': 11, 'subsample': 0.5956276205905412, 'colsample_bytree': 0.8086759136755568, 'min_child_weight': 6, 'gamma': 2.2142364151309346, 'reg_lambda': 8.748972923911348}. Best is trial 0 with value: 2.6774410864902243.
# [I 2026-03-12 04:08:47,752] Trial 4 finished with value: 2.8600915457551443 and parameters: {'n_estimators': 630, 'learning_rate': 0.014285642248517954, 'max_depth': 10, 'subsample': 0.8534984950463795, 'colsample_bytree': 0.9763199175644217, 'min_child_weight': 2, 'gamma': 0.30176611634930905, 'reg_lambda': 0.00814336612740602}. Best is trial 0 with value: 2.6774410864902243.
# [I 2026-03-12 04:08:50,982] Trial 5 finished with value: 2.6563823333036365 and parameters: {'n_estimators': 1176, 'learning_rate': 0.053977669948645696, 'max_depth': 3, 'subsample': 0.709735511567201, 'colsample_bytree': 0.5509256341717754, 'min_child_weight': 9, 'gamma': 3.2377625006098776, 'reg_lambda': 0.326678477127437}. Best is trial 5 with value: 2.6563823333036365.
# [I 2026-03-12 04:08:54,074] Trial 6 pruned.
# [I 2026-03-12 04:08:55,382] Trial 7 pruned.
# [I 2026-03-12 04:08:56,314] Trial 8 pruned.
# [I 2026-03-12 04:09:00,631] Trial 9 finished with value: 2.665296109802968 and parameters: {'n_estimators': 1103, 'learning_rate': 0.014508571870240615, 'max_depth': 5, 'subsample': 0.7999375502945786, 'colsample_bytree': 0.8388334981731836, 'min_child_weight': 8, 'gamma': 0.8616577922663526, 'reg_lambda': 0.17701181273820316}. Best is trial 5 with value: 2.6563823333036365.
# [I 2026-03-12 04:09:01,408] Trial 10 pruned.
# [I 2026-03-12 04:09:04,043] Trial 11 finished with value: 2.6307073111328 and parameters: {'n_estimators': 1200, 'learning_rate': 0.04624659432041674, 'max_depth': 3, 'subsample': 0.6773304299379362, 'colsample_bytree': 0.6400635778417404, 'min_child_weight': 8, 'gamma': 1.7661661926786305, 'reg_lambda': 0.16157953234716163}. Best is trial 11 with value: 2.6307073111328.
# [I 2026-03-12 04:09:06,990] Trial 12 finished with value: 2.630369248725155 and parameters: {'n_estimators': 673, 'learning_rate': 0.050810601867740716, 'max_depth': 3, 'subsample': 0.6876561478900122, 'colsample_bytree': 0.5831027468225968, 'min_child_weight': 8, 'gamma': 1.7806462390239977, 'reg_lambda': 0.665078762049528}. Best is trial 12 with value: 2.630369248725155.
# [I 2026-03-12 04:09:08,635] Trial 13 pruned.
# [I 2026-03-12 04:09:09,327] Trial 14 pruned.
# [I 2026-03-12 04:09:11,428] Trial 15 finished with value: 2.6301554996694225 and parameters: {'n_estimators': 753, 'learning_rate': 0.03632250329021412, 'max_depth': 3, 'subsample': 0.5292041175544352, 'colsample_bytree': 0.6704255654707265, 'min_child_weight': 7, 'gamma': 2.757750465281872, 'reg_lambda': 0.5088416874088793}. Best is trial 15 with value: 2.6301554996694225.
# [I 2026-03-12 04:09:12,956] Trial 16 pruned.
# [I 2026-03-12 04:09:13,619] Trial 17 pruned.
# [I 2026-03-12 04:09:14,916] Trial 18 pruned.
# [I 2026-03-12 04:09:16,316] Trial 19 pruned.
# [I 2026-03-12 04:09:16,872] Trial 20 pruned.
# [I 2026-03-12 04:09:18,908] Trial 21 finished with value: 2.6234564113244816 and parameters: {'n_estimators': 963, 'learning_rate': 0.046035410463210226, 'max_depth': 3, 'subsample': 0.6893497538450624, 'colsample_bytree': 0.6747253342425704, 'min_child_weight': 9, 'gamma': 1.7334655531907668, 'reg_lambda': 0.15566551355657482}. Best is trial 21 with value: 2.6234564113244816.
# [I 2026-03-12 04:09:20,721] Trial 22 finished with value: 2.6333014665574987 and parameters: {'n_estimators': 926, 'learning_rate': 0.039121859589952956, 'max_depth': 3, 'subsample': 0.7099230204048665, 'colsample_bytree': 0.6926478422979357, 'min_child_weight': 9, 'gamma': 2.7646470521820525, 'reg_lambda': 0.09541419308978133}. Best is trial 21 with value: 2.6234564113244816.
# [I 2026-03-12 04:09:21,352] Trial 23 pruned.
# [I 2026-03-12 04:09:21,977] Trial 24 pruned.
# [I 2026-03-12 04:09:22,992] Trial 25 pruned.
# [I 2026-03-12 04:09:23,520] Trial 26 pruned.
# [I 2026-03-12 04:09:24,562] Trial 27 pruned.
# [I 2026-03-12 04:09:25,331] Trial 28 pruned.
# [I 2026-03-12 04:09:28,699] Trial 29 pruned.
# [I 2026-03-12 04:09:29,883] Trial 30 pruned.
# [I 2026-03-12 04:09:31,389] Trial 31 finished with value: 2.641675838569822 and parameters: {'n_estimators': 850, 'learning_rate': 0.04580838732162188, 'max_depth': 3, 'subsample': 0.6618655606371132, 'colsample_bytree': 0.656956548743711, 'min_child_weight': 8, 'gamma': 1.7617190148289508, 'reg_lambda': 0.08883905226638358}. Best is trial 21 with value: 2.6234564113244816.
# [I 2026-03-12 04:09:32,250] Trial 32 pruned.
# [I 2026-03-12 04:09:33,598] Trial 33 finished with value: 2.627761848991396 and parameters: {'n_estimators': 1105, 'learning_rate': 0.06237680845555964, 'max_depth': 3, 'subsample': 0.6032684031201532, 'colsample_bytree': 0.6782909900982166, 'min_child_weight': 6, 'gamma': 1.2531542149154873, 'reg_lambda': 0.031522862687998206}. Best is trial 21 with value: 2.6234564113244816.
# [I 2026-03-12 04:09:34,049] Trial 34 pruned.
# [I 2026-03-12 04:09:34,927] Trial 35 pruned.
# [I 2026-03-12 04:09:35,500] Trial 36 pruned.
# [I 2026-03-12 04:09:36,697] Trial 37 pruned.
# [I 2026-03-12 04:09:37,816] Trial 38 pruned.
# [I 2026-03-12 04:09:39,328] Trial 39 pruned.
# [I 2026-03-12 04:09:39,995] Trial 40 pruned.
# [I 2026-03-12 04:09:40,667] Trial 41 pruned.
# [I 2026-03-12 04:09:41,630] Trial 42 pruned.
# [I 2026-03-12 04:09:42,267] Trial 43 pruned.
# [I 2026-03-12 04:09:44,121] Trial 44 finished with value: 2.6359921884117274 and parameters: {'n_estimators': 1074, 'learning_rate': 0.027425794402794353, 'max_depth': 3, 'subsample': 0.7843070847746277, 'colsample_bytree': 0.6411465019448096, 'min_child_weight': 6, 'gamma': 1.0443473236447343, 'reg_lambda': 0.11895801537129731}. Best is trial 21 with value: 2.6234564113244816.
# [I 2026-03-12 04:09:46,100] Trial 45 pruned.
# [I 2026-03-12 04:09:47,128] Trial 46 pruned.
# [I 2026-03-12 04:09:47,967] Trial 47 pruned.
# [I 2026-03-12 04:09:49,633] Trial 48 pruned.
# [I 2026-03-12 04:09:50,198] Trial 49 pruned.
# [I 2026-03-12 04:09:50,856] Trial 50 pruned.
# [I 2026-03-12 04:09:52,495] Trial 51 finished with value: 2.6359896934179847 and parameters: {'n_estimators': 937, 'learning_rate': 0.03657229624953267, 'max_depth': 3, 'subsample': 0.7126017064396902, 'colsample_bytree': 0.6981957019066642, 'min_child_weight': 9, 'gamma': 2.856006920842853, 'reg_lambda': 0.12748232954365898}. Best is trial 21 with value: 2.6234564113244816.
# [I 2026-03-12 04:09:53,938] Trial 52 finished with value: 2.6199335824440073 and parameters: {'n_estimators': 908, 'learning_rate': 0.041844390783148916, 'max_depth': 3, 'subsample': 0.7575384259815704, 'colsample_bytree': 0.6921959820369064, 'min_child_weight': 9, 'gamma': 3.3307911812602327, 'reg_lambda': 0.2369188702625843}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:09:55,402] Trial 53 finished with value: 2.635363781072746 and parameters: {'n_estimators': 1043, 'learning_rate': 0.0498891750818921, 'max_depth': 3, 'subsample': 0.819423900180879, 'colsample_bytree': 0.7335386430302034, 'min_child_weight': 8, 'gamma': 3.3025412859454324, 'reg_lambda': 0.34138419330991143}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:09:56,450] Trial 54 pruned.
# [I 2026-03-12 04:10:04,265] Trial 55 finished with value: 2.656008013593682 and parameters: {'n_estimators': 664, 'learning_rate': 0.005536697402566613, 'max_depth': 3, 'subsample': 0.7663061719469115, 'colsample_bytree': 0.6836275283972042, 'min_child_weight': 7, 'gamma': 3.0483267142647192, 'reg_lambda': 0.34001415852180294}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:10:05,185] Trial 56 pruned.
# [I 2026-03-12 04:10:07,466] Trial 57 pruned.
# [I 2026-03-12 04:10:08,777] Trial 58 pruned.
# [I 2026-03-12 04:10:10,021] Trial 59 pruned.
# [I 2026-03-12 04:10:11,343] Trial 60 pruned.
# [I 2026-03-12 04:10:13,313] Trial 61 finished with value: 2.630795894837597 and parameters: {'n_estimators': 919, 'learning_rate': 0.04280254703282148, 'max_depth': 3, 'subsample': 0.7198645570511482, 'colsample_bytree': 0.6946543250722947, 'min_child_weight': 9, 'gamma': 3.04107225580804, 'reg_lambda': 0.10787002568918873}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:10:14,013] Trial 62 pruned.
# [I 2026-03-12 04:10:14,753] Trial 63 pruned.
# [I 2026-03-12 04:10:17,247] Trial 64 finished with value: 2.6221623668076592 and parameters: {'n_estimators': 882, 'learning_rate': 0.034163011415434714, 'max_depth': 3, 'subsample': 0.6942954391450864, 'colsample_bytree': 0.6936838872678406, 'min_child_weight': 9, 'gamma': 2.6042470662397625, 'reg_lambda': 0.6758694622852359}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:10:18,282] Trial 65 pruned.
# [I 2026-03-12 04:10:20,668] Trial 66 finished with value: 2.63800973268056 and parameters: {'n_estimators': 974, 'learning_rate': 0.024965656233708448, 'max_depth': 3, 'subsample': 0.6697283010130651, 'colsample_bytree': 0.6849706968505664, 'min_child_weight': 7, 'gamma': 4.153964335207699, 'reg_lambda': 1.2132586997852064}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:10:21,883] Trial 67 pruned.
# [I 2026-03-12 04:10:22,732] Trial 68 pruned.
# [I 2026-03-12 04:10:23,718] Trial 69 pruned.
# [I 2026-03-12 04:10:24,277] Trial 70 pruned.
# [I 2026-03-12 04:10:25,956] Trial 71 finished with value: 2.631510238867681 and parameters: {'n_estimators': 930, 'learning_rate': 0.04169679652707152, 'max_depth': 3, 'subsample': 0.7770945522173542, 'colsample_bytree': 0.6951109503358421, 'min_child_weight': 9, 'gamma': 3.6140189434318124, 'reg_lambda': 0.06758263438301053}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:10:27,564] Trial 72 finished with value: 2.628436123726162 and parameters: {'n_estimators': 898, 'learning_rate': 0.04575292630043579, 'max_depth': 3, 'subsample': 0.7274379307974912, 'colsample_bytree': 0.7046287577864929, 'min_child_weight': 9, 'gamma': 2.966108549851007, 'reg_lambda': 0.15433773542521584}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:10:28,128] Trial 73 pruned.
# [I 2026-03-12 04:10:28,751] Trial 74 pruned.
# [I 2026-03-12 04:10:29,524] Trial 75 pruned.
# [I 2026-03-12 04:10:30,049] Trial 76 pruned.
# [I 2026-03-12 04:10:31,020] Trial 77 pruned.
# [I 2026-03-12 04:10:32,808] Trial 78 finished with value: 2.6366792906413945 and parameters: {'n_estimators': 998, 'learning_rate': 0.04055665369787178, 'max_depth': 3, 'subsample': 0.8217848061063335, 'colsample_bytree': 0.7264450089923751, 'min_child_weight': 9, 'gamma': 2.0139764634454678, 'reg_lambda': 0.024084979080431345}. Best is trial 52 with value: 2.6199335824440073.
# [I 2026-03-12 04:10:34,228] Trial 79 pruned.
# [I 2026-03-12 04:10:35,974] Trial 80 finished with value: 2.617238191645869 and parameters: {'n_estimators': 1162, 'learning_rate': 0.06742922372991025, 'max_depth': 3, 'subsample': 0.688131562276568, 'colsample_bytree': 0.6790416341900365, 'min_child_weight': 10, 'gamma': 2.276220019104131, 'reg_lambda': 0.13848784676939746}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:10:36,801] Trial 81 pruned.
# [I 2026-03-12 04:10:37,361] Trial 82 pruned.
# [I 2026-03-12 04:10:38,325] Trial 83 pruned.
# [I 2026-03-12 04:10:38,855] Trial 84 pruned.
# [I 2026-03-12 04:10:39,395] Trial 85 pruned.
# [I 2026-03-12 04:10:40,098] Trial 86 pruned.
# [I 2026-03-12 04:10:41,333] Trial 87 pruned.
# [I 2026-03-12 04:10:42,951] Trial 88 finished with value: 2.625530099122277 and parameters: {'n_estimators': 802, 'learning_rate': 0.04588925533479373, 'max_depth': 3, 'subsample': 0.7581064330218882, 'colsample_bytree': 0.6729138345383676, 'min_child_weight': 8, 'gamma': 2.913902195879199, 'reg_lambda': 1.02868438004858}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:10:43,524] Trial 89 pruned.
# [I 2026-03-12 04:10:44,711] Trial 90 pruned.
# [I 2026-03-12 04:10:45,431] Trial 91 pruned.
# [I 2026-03-12 04:10:47,049] Trial 92 finished with value: 2.631633089012852 and parameters: {'n_estimators': 626, 'learning_rate': 0.05933717800558517, 'max_depth': 3, 'subsample': 0.7248843204312118, 'colsample_bytree': 0.6874117218165902, 'min_child_weight': 9, 'gamma': 3.1027736773209575, 'reg_lambda': 0.610587373981821}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:10:48,723] Trial 93 pruned.
# [I 2026-03-12 04:10:49,512] Trial 94 pruned.
# [I 2026-03-12 04:10:50,230] Trial 95 pruned.
# [I 2026-03-12 04:10:51,013] Trial 96 pruned.
# [I 2026-03-12 04:10:52,705] Trial 97 finished with value: 2.6477595583895184 and parameters: {'n_estimators': 464, 'learning_rate': 0.03991617741781511, 'max_depth': 3, 'subsample': 0.7757222785959466, 'colsample_bytree': 0.6773776981512145, 'min_child_weight': 10, 'gamma': 1.3555276313735778, 'reg_lambda': 0.3749800708118121}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:10:53,337] Trial 98 pruned.
# [I 2026-03-12 04:10:54,340] Trial 99 pruned.
# [I 2026-03-12 04:10:55,137] Trial 100 pruned.
# [I 2026-03-12 04:10:56,763] Trial 101 finished with value: 2.6298454700888416 and parameters: {'n_estimators': 911, 'learning_rate': 0.04304550768180278, 'max_depth': 3, 'subsample': 0.7408611396862369, 'colsample_bytree': 0.7009640849099449, 'min_child_weight': 9, 'gamma': 3.037358937281047, 'reg_lambda': 0.12055600056096084}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:10:57,474] Trial 102 pruned.
# [I 2026-03-12 04:10:58,072] Trial 103 pruned.
# [I 2026-03-12 04:10:59,514] Trial 104 finished with value: 2.6205582744812412 and parameters: {'n_estimators': 765, 'learning_rate': 0.04355879122395832, 'max_depth': 3, 'subsample': 0.7256097509875434, 'colsample_bytree': 0.7001506725487401, 'min_child_weight': 10, 'gamma': 3.336507918230124, 'reg_lambda': 0.24000170202260132}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:11:00,431] Trial 105 pruned.
# [I 2026-03-12 04:11:01,181] Trial 106 pruned.
# [I 2026-03-12 04:11:02,557] Trial 107 pruned.
# [I 2026-03-12 04:11:04,209] Trial 108 finished with value: 2.6268692599781875 and parameters: {'n_estimators': 944, 'learning_rate': 0.06805981184848885, 'max_depth': 3, 'subsample': 0.7277136243446553, 'colsample_bytree': 0.6913718807177507, 'min_child_weight': 10, 'gamma': 2.8126456898814913, 'reg_lambda': 0.7417462812837567}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:11:04,736] Trial 109 pruned.
# [I 2026-03-12 04:11:05,238] Trial 110 pruned.
# [I 2026-03-12 04:11:06,271] Trial 111 pruned.
# [I 2026-03-12 04:11:07,005] Trial 112 pruned.
# [I 2026-03-12 04:11:07,851] Trial 113 pruned.
# [I 2026-03-12 04:11:09,282] Trial 114 finished with value: 2.6315029845587983 and parameters: {'n_estimators': 754, 'learning_rate': 0.04805568903853673, 'max_depth': 3, 'subsample': 0.7396619080163119, 'colsample_bytree': 0.6700962325002952, 'min_child_weight': 10, 'gamma': 2.632840847370069, 'reg_lambda': 0.18694494956454355}. Best is trial 80 with value: 2.617238191645869.
# [I 2026-03-12 04:11:11,113] Trial 115 finished with value: 2.615952145179599 and parameters: {'n_estimators': 869, 'learning_rate': 0.06166558267539336, 'max_depth': 3, 'subsample': 0.7048146667891843, 'colsample_bytree': 0.6873458174818649, 'min_child_weight': 9, 'gamma': 2.814343865686133, 'reg_lambda': 7.9858521777700755}. Best is trial 115 with value: 2.615952145179599.
# [I 2026-03-12 04:11:11,844] Trial 116 pruned.
# [I 2026-03-12 04:11:13,452] Trial 117 pruned.
# [I 2026-03-12 04:11:14,161] Trial 118 pruned.
# [I 2026-03-12 04:11:15,708] Trial 119 finished with value: 2.6546649901434196 and parameters: {'n_estimators': 963, 'learning_rate': 0.05683537971600141, 'max_depth': 3, 'subsample': 0.5189389557847879, 'colsample_bytree': 0.681275436638449, 'min_child_weight': 9, 'gamma': 3.1948471527124362, 'reg_lambda': 2.6267744832606694}. Best is trial 115 with value: 2.615952145179599.
# [I 2026-03-12 04:11:16,277] Trial 120 pruned.
# [I 2026-03-12 04:11:18,051] Trial 121 finished with value: 2.6110179346158895 and parameters: {'n_estimators': 890, 'learning_rate': 0.05122455546379064, 'max_depth': 3, 'subsample': 0.6779492268208586, 'colsample_bytree': 0.6721711429138424, 'min_child_weight': 9, 'gamma': 3.5842868274094295, 'reg_lambda': 7.688925203616895}. Best is trial 121 with value: 2.6110179346158895.
# [I 2026-03-12 04:11:20,049] Trial 122 finished with value: 2.6249854380211914 and parameters: {'n_estimators': 913, 'learning_rate': 0.03587034713480697, 'max_depth': 3, 'subsample': 0.5843513579787883, 'colsample_bytree': 0.6689393603951905, 'min_child_weight': 9, 'gamma': 3.5276608684301083, 'reg_lambda': 9.505749562181892}. Best is trial 121 with value: 2.6110179346158895.
# [I 2026-03-12 04:11:21,438] Trial 123 finished with value: 2.6123204460196283 and parameters: {'n_estimators': 928, 'learning_rate': 0.0640312885363721, 'max_depth': 3, 'subsample': 0.7087960471579342, 'colsample_bytree': 0.6693916070253928, 'min_child_weight': 9, 'gamma': 3.5571190710403617, 'reg_lambda': 8.365160022279717}. Best is trial 121 with value: 2.6110179346158895.
# [I 2026-03-12 04:11:23,036] Trial 124 finished with value: 2.632454802894117 and parameters: {'n_estimators': 893, 'learning_rate': 0.063778675639682, 'max_depth': 3, 'subsample': 0.6800001497536617, 'colsample_bytree': 0.6677477325386961, 'min_child_weight': 9, 'gamma': 4.004170916687603, 'reg_lambda': 9.056693993088055}. Best is trial 121 with value: 2.6110179346158895.
# [I 2026-03-12 04:11:24,187] Trial 125 pruned.
# [I 2026-03-12 04:11:26,109] Trial 126 finished with value: 2.619694907415146 and parameters: {'n_estimators': 983, 'learning_rate': 0.0683494495729079, 'max_depth': 3, 'subsample': 0.7064971450182569, 'colsample_bytree': 0.6888512767121694, 'min_child_weight': 10, 'gamma': 3.5256495101440772, 'reg_lambda': 7.622363099748539}. Best is trial 121 with value: 2.6110179346158895.
# [I 2026-03-12 04:11:27,292] Trial 127 pruned.
# [I 2026-03-12 04:11:28,609] Trial 128 pruned.
# [I 2026-03-12 04:11:29,515] Trial 129 pruned.
# [I 2026-03-12 04:11:31,465] Trial 130 finished with value: 2.606892502439076 and parameters: {'n_estimators': 860, 'learning_rate': 0.060895622480818194, 'max_depth': 3, 'subsample': 0.6250542928377578, 'colsample_bytree': 0.6738911784624977, 'min_child_weight': 10, 'gamma': 3.515814272391107, 'reg_lambda': 6.039871445089722}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:32,820] Trial 131 pruned.
# [I 2026-03-12 04:11:34,632] Trial 132 finished with value: 2.6444128094871795 and parameters: {'n_estimators': 875, 'learning_rate': 0.06557322957438076, 'max_depth': 3, 'subsample': 0.6222274413675682, 'colsample_bytree': 0.6803231876987383, 'min_child_weight': 10, 'gamma': 3.4671568084105107, 'reg_lambda': 7.142738149651295}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:36,549] Trial 133 finished with value: 2.639472679519527 and parameters: {'n_estimators': 930, 'learning_rate': 0.0750545405528474, 'max_depth': 3, 'subsample': 0.6673177278213658, 'colsample_bytree': 0.6903229289524307, 'min_child_weight': 1, 'gamma': 3.72004776231568, 'reg_lambda': 5.814327120114773}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:38,962] Trial 134 finished with value: 2.6621824433112184 and parameters: {'n_estimators': 970, 'learning_rate': 0.05117087401448108, 'max_depth': 3, 'subsample': 0.5821461305401703, 'colsample_bytree': 0.6575469850834141, 'min_child_weight': 10, 'gamma': 3.510311780532797, 'reg_lambda': 9.495757563276623}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:39,480] Trial 135 pruned.
# [I 2026-03-12 04:11:41,573] Trial 136 finished with value: 2.615176924977367 and parameters: {'n_estimators': 945, 'learning_rate': 0.05658163266603733, 'max_depth': 3, 'subsample': 0.6480127293146362, 'colsample_bytree': 0.6715929456044974, 'min_child_weight': 10, 'gamma': 3.915055339043552, 'reg_lambda': 7.856730855063675}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:43,400] Trial 137 finished with value: 2.6408332956748284 and parameters: {'n_estimators': 935, 'learning_rate': 0.056418221533897916, 'max_depth': 3, 'subsample': 0.6580869424379533, 'colsample_bytree': 0.670727725597687, 'min_child_weight': 10, 'gamma': 4.557462340056497, 'reg_lambda': 5.017523065517387}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:44,383] Trial 138 pruned.
# [I 2026-03-12 04:11:45,211] Trial 139 pruned.
# [I 2026-03-12 04:11:46,949] Trial 140 finished with value: 2.6288476125590927 and parameters: {'n_estimators': 916, 'learning_rate': 0.03274189920978146, 'max_depth': 3, 'subsample': 0.6501916386706962, 'colsample_bytree': 0.7195839158758343, 'min_child_weight': 10, 'gamma': 3.55318659817597, 'reg_lambda': 3.8477577075222733}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:48,315] Trial 141 finished with value: 2.611860461499714 and parameters: {'n_estimators': 951, 'learning_rate': 0.06225673541469921, 'max_depth': 3, 'subsample': 0.6140458385444216, 'colsample_bytree': 0.6815278083053304, 'min_child_weight': 9, 'gamma': 3.6627437847024655, 'reg_lambda': 6.024546183874482}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:51,445] Trial 142 finished with value: 2.6105309587907537 and parameters: {'n_estimators': 950, 'learning_rate': 0.05934120794555072, 'max_depth': 3, 'subsample': 0.6119688823064463, 'colsample_bytree': 0.6820155653180477, 'min_child_weight': 9, 'gamma': 3.6819357167890723, 'reg_lambda': 6.298911606257565}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:53,092] Trial 143 finished with value: 2.623558705675502 and parameters: {'n_estimators': 988, 'learning_rate': 0.060218798619111676, 'max_depth': 3, 'subsample': 0.6094553715557054, 'colsample_bytree': 0.6674846295510697, 'min_child_weight': 9, 'gamma': 3.6600228212159855, 'reg_lambda': 5.654105411773285}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:54,334] Trial 144 pruned.
# [I 2026-03-12 04:11:56,068] Trial 145 finished with value: 2.623948016681564 and parameters: {'n_estimators': 1053, 'learning_rate': 0.05318205005231138, 'max_depth': 3, 'subsample': 0.5898836830711598, 'colsample_bytree': 0.7100354440320371, 'min_child_weight': 9, 'gamma': 3.7281786510546024, 'reg_lambda': 7.503129213967707}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:56,973] Trial 146 pruned.
# [I 2026-03-12 04:11:58,907] Trial 147 finished with value: 2.615371324125062 and parameters: {'n_estimators': 1035, 'learning_rate': 0.0526781315223353, 'max_depth': 3, 'subsample': 0.6282943431576359, 'colsample_bytree': 0.7112694168270528, 'min_child_weight': 9, 'gamma': 4.358149636529558, 'reg_lambda': 6.607906853902626}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:11:59,733] Trial 148 pruned.
# [I 2026-03-12 04:12:01,405] Trial 149 pruned.
# [I 2026-03-12 04:12:03,387] Trial 150 finished with value: 2.614288034092984 and parameters: {'n_estimators': 986, 'learning_rate': 0.06392953256880973, 'max_depth': 3, 'subsample': 0.6218035224870271, 'colsample_bytree': 0.6985072021671036, 'min_child_weight': 9, 'gamma': 4.453158825778983, 'reg_lambda': 6.164335175075596}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:05,610] Trial 151 finished with value: 2.616954458436784 and parameters: {'n_estimators': 977, 'learning_rate': 0.06556275435153161, 'max_depth': 3, 'subsample': 0.6185793496560287, 'colsample_bytree': 0.6973191544175142, 'min_child_weight': 9, 'gamma': 4.400467701159898, 'reg_lambda': 6.673053491086252}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:06,735] Trial 152 pruned.
# [I 2026-03-12 04:12:08,537] Trial 153 pruned.
# [I 2026-03-12 04:12:13,269] Trial 154 finished with value: 2.6256372324893724 and parameters: {'n_estimators': 949, 'learning_rate': 0.01141845754869254, 'max_depth': 3, 'subsample': 0.648731758467881, 'colsample_bytree': 0.691125905953013, 'min_child_weight': 9, 'gamma': 4.743069754451885, 'reg_lambda': 6.408614415581605}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:14,063] Trial 155 pruned.
# [I 2026-03-12 04:12:15,084] Trial 156 pruned.
# [I 2026-03-12 04:12:15,554] Trial 157 pruned.
# [I 2026-03-12 04:12:16,283] Trial 158 pruned.
# [I 2026-03-12 04:12:17,768] Trial 159 pruned.
# [I 2026-03-12 04:12:18,409] Trial 160 pruned.
# [I 2026-03-12 04:12:19,085] Trial 161 pruned.
# [I 2026-03-12 04:12:20,010] Trial 162 pruned.
# [I 2026-03-12 04:12:20,822] Trial 163 pruned.
# [I 2026-03-12 04:12:22,218] Trial 164 finished with value: 2.6190389545332105 and parameters: {'n_estimators': 912, 'learning_rate': 0.054757830654485175, 'max_depth': 3, 'subsample': 0.623421246585407, 'colsample_bytree': 0.677143758378537, 'min_child_weight': 8, 'gamma': 3.8119557879494677, 'reg_lambda': 8.307532125513237}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:23,751] Trial 165 finished with value: 2.615746656177632 and parameters: {'n_estimators': 922, 'learning_rate': 0.05376834201400322, 'max_depth': 3, 'subsample': 0.6211233309147762, 'colsample_bytree': 0.7064841567015085, 'min_child_weight': 8, 'gamma': 4.703112975650978, 'reg_lambda': 9.928411702516586}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:25,238] Trial 166 pruned.
# [I 2026-03-12 04:12:26,192] Trial 167 pruned.
# [I 2026-03-12 04:12:27,457] Trial 168 finished with value: 2.640190672591955 and parameters: {'n_estimators': 940, 'learning_rate': 0.07871078176411561, 'max_depth': 3, 'subsample': 0.6312546146076242, 'colsample_bytree': 0.6804701691212702, 'min_child_weight': 10, 'gamma': 4.227228939377746, 'reg_lambda': 9.857801884504898}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:28,892] Trial 169 pruned.
# [I 2026-03-12 04:12:30,384] Trial 170 pruned.
# [I 2026-03-12 04:12:31,569] Trial 171 pruned.
# [I 2026-03-12 04:12:32,963] Trial 172 pruned.
# [I 2026-03-12 04:12:33,804] Trial 173 pruned.
# [I 2026-03-12 04:12:35,594] Trial 174 finished with value: 2.621922854137037 and parameters: {'n_estimators': 883, 'learning_rate': 0.05888858965940074, 'max_depth': 3, 'subsample': 0.6400523530718222, 'colsample_bytree': 0.6916564877116592, 'min_child_weight': 8, 'gamma': 4.671720291620512, 'reg_lambda': 8.319550645812086}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:36,485] Trial 175 pruned.
# [I 2026-03-12 04:12:38,106] Trial 176 finished with value: 2.6266750056558257 and parameters: {'n_estimators': 845, 'learning_rate': 0.05772460140078953, 'max_depth': 3, 'subsample': 0.6233010256718451, 'colsample_bytree': 0.7231965737723017, 'min_child_weight': 8, 'gamma': 4.813189517738961, 'reg_lambda': 8.051356133189818}. Best is trial 130 with value: 2.606892502439076.
# [I 2026-03-12 04:12:38,907] Trial 177 pruned.
# [I 2026-03-12 04:12:39,493] Trial 178 pruned.
# [I 2026-03-12 04:12:40,091] Trial 179 pruned.
# [I 2026-03-12 04:12:40,806] Trial 180 pruned.
# [I 2026-03-12 04:12:42,223] Trial 181 pruned.
# [I 2026-03-12 04:12:43,224] Trial 182 pruned.
# [I 2026-03-12 04:12:45,140] Trial 183 finished with value: 2.5985315489436283 and parameters: {'n_estimators': 1001, 'learning_rate': 0.045444309052454064, 'max_depth': 3, 'subsample': 0.692479756609638, 'colsample_bytree': 0.7082456850417895, 'min_child_weight': 9, 'gamma': 3.4728619701209147, 'reg_lambda': 9.92387307541532}. Best is trial 183 with value: 2.5985315489436283.
# [I 2026-03-12 04:12:46,380] Trial 184 pruned.
# [I 2026-03-12 04:12:47,910] Trial 185 finished with value: 2.6138010334460042 and parameters: {'n_estimators': 974, 'learning_rate': 0.06696278808459939, 'max_depth': 3, 'subsample': 0.6984193616624205, 'colsample_bytree': 0.7020348984429708, 'min_child_weight': 10, 'gamma': 3.797939870354552, 'reg_lambda': 8.409673485328632}. Best is trial 183 with value: 2.5985315489436283.
# [I 2026-03-12 04:12:48,965] Trial 186 pruned.
# [I 2026-03-12 04:12:49,839] Trial 187 pruned.
# [I 2026-03-12 04:12:50,897] Trial 188 pruned.
# [I 2026-03-12 04:12:52,581] Trial 189 finished with value: 2.6525981660012996 and parameters: {'n_estimators': 952, 'learning_rate': 0.06806211544708421, 'max_depth': 3, 'subsample': 0.6549411821751627, 'colsample_bytree': 0.6960414225341525, 'min_child_weight': 10, 'gamma': 3.6610423464303485, 'reg_lambda': 8.51228874743154}. Best is trial 183 with value: 2.5985315489436283.
# [I 2026-03-12 04:12:53,870] Trial 190 pruned.
# [I 2026-03-12 04:12:55,306] Trial 191 finished with value: 2.641596822642639 and parameters: {'n_estimators': 911, 'learning_rate': 0.06220904642554224, 'max_depth': 3, 'subsample': 0.7060118171958216, 'colsample_bytree': 0.69785160143186, 'min_child_weight': 3, 'gamma': 3.7322222831942504, 'reg_lambda': 4.813961002522891}. Best is trial 183 with value: 2.5985315489436283.
# [I 2026-03-12 04:12:56,441] Trial 192 pruned.
# [I 2026-03-12 04:12:58,326] Trial 193 finished with value: 2.597939174275197 and parameters: {'n_estimators': 891, 'learning_rate': 0.06554251345977033, 'max_depth': 3, 'subsample': 0.7179332777589613, 'colsample_bytree': 0.7073196630013163, 'min_child_weight': 9, 'gamma': 2.3094197084286723, 'reg_lambda': 7.787320243993622}. Best is trial 193 with value: 2.597939174275197.
# [I 2026-03-12 04:12:59,810] Trial 194 finished with value: 2.6116241934370312 and parameters: {'n_estimators': 898, 'learning_rate': 0.06527247830461362, 'max_depth': 3, 'subsample': 0.7216773875984679, 'colsample_bytree': 0.7079593868357761, 'min_child_weight': 9, 'gamma': 3.619588675650897, 'reg_lambda': 7.932783005225398}. Best is trial 193 with value: 2.597939174275197.
# [I 2026-03-12 04:13:00,536] Trial 195 pruned.
# [I 2026-03-12 04:13:01,156] Trial 196 pruned.
# [I 2026-03-12 04:13:01,904] Trial 197 pruned.
# [I 2026-03-12 04:13:03,314] Trial 198 finished with value: 2.610602724686222 and parameters: {'n_estimators': 911, 'learning_rate': 0.06347562734570081, 'max_depth': 3, 'subsample': 0.7092139270209673, 'colsample_bytree': 0.6798001791492525, 'min_child_weight': 9, 'gamma': 2.120539515767468, 'reg_lambda': 7.55682142205858}. Best is trial 193 with value: 2.597939174275197.
# [I 2026-03-12 04:13:03,978] Trial 199 pruned.
# Best trial parameters: {'n_estimators': 891, 'learning_rate': 0.06554251345977033, 'max_depth': 3, 'subsample': 0.7179332777589613, 'colsample_bytree': 0.7073196630013163, 'min_child_weight': 9, 'gamma': 2.3094197084286723, 'reg_lambda': 7.787320243993622}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# bestt_iteration gets the exact number of decision trees where it peaked (best amouunt of trees for model), and hardcode to overwrite n_estimators from params
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7073196630013163, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=2.3094197084286723, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.06554251345977033,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=9, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=98, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# saving best model
joblib.dump(best_model, model_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source\\SavedResults\\Results_IE_SO2\\xgboost_model_IE_SO2.pkl']

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 2.9120
# MAE:  1.0282
# R2:   0.6530

# %%
# For Comparrison a naive non ML just guessing that tomorrow's pollutant will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 2.9120
# Naive Baseline RMSE: 3.1195

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title(f"SHAP Feature Importance: What drives {POLLUTANT} Pollution?")
plt.tight_layout()
plt.savefig(output_dir / f"{RUN_ID}_SHAP_Feature_importance.png", bbox_inches='tight')
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.title(f"Feature Importance of {POLLUTANT}")
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
plt.savefig(output_dir / f"{RUN_ID}_Feature_Importance.png", bbox_inches='tight')

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")


# folder for these prediction plots
pred_plot_dir = output_dir / "Predict_vs_Actual_Plots"
pred_plot_dir.mkdir(parents=True, exist_ok=True)

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

station_metrics_list = [] 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])

    station_metrics_list.append({ # add evalutation to list
        'Station': station,
        'RMSE': round(st_rmse, 3),
        'MAE': round(st_mae, 3),
        'R2': round(st_r2, 3)
    })
    
    print(f"Samplingpoint {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label=f'Actual {POLLUTANT}', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label=f'Predicted {POLLUTANT}', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted {POLLUTANT}\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel(f'{POLLUTANT} ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    clean_station_name = str(station).replace(".", "_").replace("/", "_")
    file_name = f"{COUNTRY_CODE}_{POLLUTANT}_{clean_station_name}_predict.png"
    plt.savefig(pred_plot_dir / file_name, dpi=150)

    plt.show()
    plt.close()


# list to df to csv
metrics_df = pd.DataFrame(station_metrics_list)
csv_filename = output_dir / f"{COUNTRY_CODE}_{POLLUTANT}_Every_Station_Metrics.csv"
metrics_df.to_csv(csv_filename, index=False)
# Out:
# RMSE: 2.9120
# MAE:  1.0282
# R2:   0.6530
# Samplingpoint IE/SPO.IE.IE004APSample1_1 -> RMSE: 0.73 | MAE: 0.49 | R2: 0.33
# Samplingpoint IE/SPO.IE.IE0108ASample1_1 -> RMSE: 1.13 | MAE: 0.43 | R2: 0.79
# Samplingpoint IE/SPO.IE.IE0098ASample1_1 -> RMSE: 1.17 | MAE: 0.74 | R2: 0.79
# Samplingpoint IE/SPO.IE.IE028DSample2_1 -> RMSE: 1.33 | MAE: 0.85 | R2: 0.71
# Samplingpoint IE/SPO.IE.IE001CMSample1_1 -> RMSE: 0.90 | MAE: 0.54 | R2: 0.63
# Samplingpoint IE/SPO.IE.IE0028ASample1_1 -> RMSE: 0.67 | MAE: 0.39 | R2: 0.77
# Samplingpoint IE/SPO.IE.IE0137ASample1_1 -> RMSE: 3.73 | MAE: 1.91 | R2: 0.55
# Samplingpoint IE/SPO.IE.IE0090ASample1_1 -> RMSE: 0.31 | MAE: 0.24 | R2: 0.89
# Samplingpoint IE/SPO.IE.IE006CPSample1_1 -> RMSE: 9.18 | MAE: 5.04 | R2: 0.50
# Samplingpoint IE/SPO.IE.IE002CMSample1_1 -> RMSE: 1.17 | MAE: 0.69 | R2: 0.80
# Samplingpoint IE/SPO.IE.IE027DSample2_1 -> RMSE: 1.36 | MAE: 0.82 | R2: 0.73
# Samplingpoint IE/SPO.IE.IE005OYSample2_1 -> RMSE: 0.73 | MAE: 0.44 | R2: 0.86
# Samplingpoint IE/SPO.IE.IE010CKSample1_1 -> RMSE: 1.44 | MAE: 0.95 | R2: 0.67
# Samplingpoint IE/SPO.IE.IE001BPSample1_1 -> RMSE: 0.93 | MAE: 0.50 | R2: 0.86
