# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
POLLUTANT = "CO"

# %%
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#                  Samplingpoint      Start  Value
# 0  IE/SPO.IE.IE001BPSample2_10 2015-01-01    NaN
# 1  IE/SPO.IE.IE001BPSample2_10 2015-01-02    NaN
# 2  IE/SPO.IE.IE001BPSample2_10 2015-01-03    NaN
# 3  IE/SPO.IE.IE001BPSample2_10 2015-01-04    NaN
# 4  IE/SPO.IE.IE001BPSample2_10 2015-01-05    NaN
# 5  IE/SPO.IE.IE001BPSample2_10 2015-01-06    NaN
# 6  IE/SPO.IE.IE001BPSample2_10 2015-01-07    NaN
# 7  IE/SPO.IE.IE001BPSample2_10 2015-01-08    NaN
# 8  IE/SPO.IE.IE001BPSample2_10 2015-01-09    NaN
# 9  IE/SPO.IE.IE001BPSample2_10 2015-01-10    NaN

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (19020, 11)
#        Start                Samplingpoint  Value  DayOfWeek  Month  DayOfYear  \
# 0 2015-01-01  IE/SPO.IE.IE001BPSample2_10    NaN          3      1          1
# 1 2015-01-02  IE/SPO.IE.IE001BPSample2_10    NaN          4      1          2
# 2 2015-01-03  IE/SPO.IE.IE001BPSample2_10    NaN          5      1          3
# 3 2015-01-04  IE/SPO.IE.IE001BPSample2_10    NaN          6      1          4
# 4 2015-01-05  IE/SPO.IE.IE001BPSample2_10    NaN          0      1          5
# 5 2015-01-06  IE/SPO.IE.IE001BPSample2_10    NaN          1      1          6
# 6 2015-01-07  IE/SPO.IE.IE001BPSample2_10    NaN          2      1          7
# 7 2015-01-08  IE/SPO.IE.IE001BPSample2_10    NaN          3      1          8
# 8 2015-01-09  IE/SPO.IE.IE001BPSample2_10    NaN          4      1          9
# 9 2015-01-10  IE/SPO.IE.IE001BPSample2_10    NaN          5      1         10
#
#    IsWeekend  Lag_1  Lag_7  Rolling_Mean_7D  Target
# 0          0    NaN    NaN              NaN     NaN
# 1          0    NaN    NaN              NaN     NaN
# 2          1    NaN    NaN              NaN     NaN
# 3          1    NaN    NaN              NaN     NaN
# 4          0    NaN    NaN              NaN     NaN
# 5          0    NaN    NaN              NaN     NaN
# 6          0    NaN    NaN              NaN     NaN
# 7          0    NaN    NaN              NaN     NaN
# 8          0    NaN    NaN              NaN     NaN
# 9          1    NaN    NaN              NaN     NaN

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start                Samplingpoint     Value  DayOfWeek  Month  \
# 0 2016-01-07  IE/SPO.IE.IE001BPSample2_10       NaN          3      1
# 1 2016-01-08  IE/SPO.IE.IE001BPSample2_10  0.658333          4      1
# 2 2016-01-09  IE/SPO.IE.IE001BPSample2_10  0.641667          5      1
# 3 2016-01-10  IE/SPO.IE.IE001BPSample2_10  0.675000          6      1
# 4 2016-01-11  IE/SPO.IE.IE001BPSample2_10  0.745833          0      1
# 5 2016-01-12  IE/SPO.IE.IE001BPSample2_10  0.387500          1      1
# 6 2016-01-13  IE/SPO.IE.IE001BPSample2_10  0.579167          2      1
# 7 2016-01-14  IE/SPO.IE.IE001BPSample2_10  0.437500          3      1
# 8 2016-01-15  IE/SPO.IE.IE001BPSample2_10  0.425000          4      1
# 9 2016-01-16  IE/SPO.IE.IE001BPSample2_10  0.754167          5      1
#
#    DayOfYear  IsWeekend     Lag_1     Lag_7  Rolling_Mean_7D    Target
# 0          7          0       NaN       NaN              NaN  0.658333
# 1          8          0       NaN       NaN              NaN  0.641667
# 2          9          1  0.658333       NaN              NaN  0.675000
# 3         10          1  0.641667       NaN              NaN  0.745833
# 4         11          0  0.675000       NaN         0.680208  0.387500
# 5         12          0  0.745833       NaN         0.621667  0.579167
# 6         13          0  0.387500       NaN         0.614583  0.437500
# 7         14          0  0.579167       NaN         0.589286  0.425000
# 8         15          0  0.437500  0.658333         0.555952  0.754167
# 9         16          1  0.425000  0.641667         0.572024  0.504167
# Start                0
# Samplingpoint        0
# Value              104
# DayOfWeek            0
# Month                0
# DayOfYear            0
# IsWeekend            0
# Lag_1              190
# Lag_7              441
# Rolling_Mean_7D    214
# Target               0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (6999, 9), Val shape: (3398, 9), Test shape: (2959, 9)

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 00:49:01,647] A new study created in memory with name: no-name-dc1de51d-f89e-4467-a5fe-6295c9faf66c
# [I 2026-03-12 00:49:02,020] Trial 0 finished with value: 0.2078148095596039 and parameters: {'n_estimators': 1026, 'learning_rate': 0.05212318358526449, 'max_depth': 6, 'subsample': 0.7605182746539758, 'colsample_bytree': 0.8970151226583646, 'min_child_weight': 2, 'gamma': 3.857850637673897, 'reg_lambda': 0.2820491252451841}. Best is trial 0 with value: 0.2078148095596039.
# [I 2026-03-12 00:49:02,381] Trial 1 finished with value: 0.17574539738001033 and parameters: {'n_estimators': 421, 'learning_rate': 0.0205040883897919, 'max_depth': 12, 'subsample': 0.8661432823314261, 'colsample_bytree': 0.621781954369591, 'min_child_weight': 8, 'gamma': 1.3904150652341234, 'reg_lambda': 0.5972387745464696}. Best is trial 1 with value: 0.17574539738001033.
# [I 2026-03-12 00:49:03,242] Trial 2 finished with value: 0.15629346479344214 and parameters: {'n_estimators': 869, 'learning_rate': 0.006937214916859972, 'max_depth': 12, 'subsample': 0.5168728361871571, 'colsample_bytree': 0.7455736856976676, 'min_child_weight': 6, 'gamma': 4.954791424936659, 'reg_lambda': 5.444785548731446}. Best is trial 2 with value: 0.15629346479344214.
# [I 2026-03-12 00:49:03,699] Trial 3 finished with value: 0.17779046579486485 and parameters: {'n_estimators': 723, 'learning_rate': 0.011758631164681867, 'max_depth': 4, 'subsample': 0.9003114163687975, 'colsample_bytree': 0.7153915267974122, 'min_child_weight': 8, 'gamma': 2.7865815093679585, 'reg_lambda': 0.8113174503241922}. Best is trial 2 with value: 0.15629346479344214.
# [I 2026-03-12 00:49:04,311] Trial 4 finished with value: 0.18994058057580637 and parameters: {'n_estimators': 782, 'learning_rate': 0.021869168835923852, 'max_depth': 9, 'subsample': 0.87278307102946, 'colsample_bytree': 0.8135927091917237, 'min_child_weight': 1, 'gamma': 0.16763935458220303, 'reg_lambda': 0.07786402072208462}. Best is trial 2 with value: 0.15629346479344214.
# [I 2026-03-12 00:49:04,555] Trial 5 pruned.
# [I 2026-03-12 00:49:04,729] Trial 6 pruned.
# [I 2026-03-12 00:49:05,139] Trial 7 finished with value: 0.18405886157033421 and parameters: {'n_estimators': 583, 'learning_rate': 0.013949988048485872, 'max_depth': 9, 'subsample': 0.9779079803875297, 'colsample_bytree': 0.5862264596251847, 'min_child_weight': 2, 'gamma': 1.4197072973455365, 'reg_lambda': 0.3914383271611713}. Best is trial 2 with value: 0.15629346479344214.
# [I 2026-03-12 00:49:05,254] Trial 8 pruned.
# [I 2026-03-12 00:49:05,913] Trial 9 finished with value: 0.16849491073413933 and parameters: {'n_estimators': 821, 'learning_rate': 0.008263123374215657, 'max_depth': 10, 'subsample': 0.6907186233771772, 'colsample_bytree': 0.7757897869838979, 'min_child_weight': 9, 'gamma': 0.6967107525121552, 'reg_lambda': 0.03733806365185918}. Best is trial 2 with value: 0.15629346479344214.
# [I 2026-03-12 00:49:06,625] Trial 10 finished with value: 0.15633212099923657 and parameters: {'n_estimators': 159, 'learning_rate': 0.005601423154393562, 'max_depth': 12, 'subsample': 0.5027051200680265, 'colsample_bytree': 0.9962058055841241, 'min_child_weight': 5, 'gamma': 4.974921004328003, 'reg_lambda': 6.602743402410257}. Best is trial 2 with value: 0.15629346479344214.
# [I 2026-03-12 00:49:07,376] Trial 11 finished with value: 0.15064335770109696 and parameters: {'n_estimators': 191, 'learning_rate': 0.005143541104508082, 'max_depth': 12, 'subsample': 0.5023910499015798, 'colsample_bytree': 0.9805819314724558, 'min_child_weight': 5, 'gamma': 4.943348575418626, 'reg_lambda': 9.997908002889403}. Best is trial 11 with value: 0.15064335770109696.
# [I 2026-03-12 00:49:07,588] Trial 12 finished with value: 0.14990096050191284 and parameters: {'n_estimators': 144, 'learning_rate': 0.1711347542022956, 'max_depth': 12, 'subsample': 0.5231154720469494, 'colsample_bytree': 0.883157260853941, 'min_child_weight': 5, 'gamma': 4.9956370021456005, 'reg_lambda': 7.124376830376748}. Best is trial 12 with value: 0.14990096050191284.
# [I 2026-03-12 00:49:07,796] Trial 13 finished with value: 0.15417846847730696 and parameters: {'n_estimators': 115, 'learning_rate': 0.18551927441491894, 'max_depth': 7, 'subsample': 0.6080222001597897, 'colsample_bytree': 0.9897793576065534, 'min_child_weight': 5, 'gamma': 4.072148355362544, 'reg_lambda': 8.46611359866396}. Best is trial 12 with value: 0.14990096050191284.
# [I 2026-03-12 00:49:07,937] Trial 14 pruned.
# [I 2026-03-12 00:49:08,093] Trial 15 pruned.
# [I 2026-03-12 00:49:08,249] Trial 16 pruned.
# [I 2026-03-12 00:49:08,447] Trial 17 pruned.
# [I 2026-03-12 00:49:08,751] Trial 18 pruned.
# [I 2026-03-12 00:49:09,038] Trial 19 pruned.
# [I 2026-03-12 00:49:10,581] Trial 20 finished with value: 0.14803970766417934 and parameters: {'n_estimators': 1174, 'learning_rate': 0.005068492735308603, 'max_depth': 9, 'subsample': 0.6419084026887849, 'colsample_bytree': 0.9633320083725402, 'min_child_weight': 3, 'gamma': 1.95320636048658, 'reg_lambda': 9.690249057912805}. Best is trial 20 with value: 0.14803970766417934.
# [I 2026-03-12 00:49:12,563] Trial 21 finished with value: 0.14322742380892578 and parameters: {'n_estimators': 1149, 'learning_rate': 0.005247964291119297, 'max_depth': 12, 'subsample': 0.5521590694728035, 'colsample_bytree': 0.9499243396716257, 'min_child_weight': 3, 'gamma': 2.284388312223737, 'reg_lambda': 9.639916799265427}. Best is trial 21 with value: 0.14322742380892578.
# [I 2026-03-12 00:49:13,020] Trial 22 pruned.
# [I 2026-03-12 00:49:13,606] Trial 23 finished with value: 0.1654642704390725 and parameters: {'n_estimators': 1168, 'learning_rate': 0.016377849240483185, 'max_depth': 11, 'subsample': 0.64122371705858, 'colsample_bytree': 0.8745236083815704, 'min_child_weight': 3, 'gamma': 1.91178479132215, 'reg_lambda': 3.9257370520256036}. Best is trial 21 with value: 0.14322742380892578.
# [I 2026-03-12 00:49:15,538] Trial 24 finished with value: 0.12450469140087866 and parameters: {'n_estimators': 1141, 'learning_rate': 0.007163341662470833, 'max_depth': 7, 'subsample': 0.5485375489748262, 'colsample_bytree': 0.9481633498941814, 'min_child_weight': 1, 'gamma': 1.452335758065987, 'reg_lambda': 9.860457058486388}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:16,528] Trial 25 finished with value: 0.16115697800886 and parameters: {'n_estimators': 1186, 'learning_rate': 0.007388033821275427, 'max_depth': 7, 'subsample': 0.720106634406628, 'colsample_bytree': 0.9563667402447642, 'min_child_weight': 1, 'gamma': 1.3906641411465666, 'reg_lambda': 2.472689650856216}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:16,874] Trial 26 pruned.
# [I 2026-03-12 00:49:19,292] Trial 27 finished with value: 0.12627306463454013 and parameters: {'n_estimators': 945, 'learning_rate': 0.005048271412637281, 'max_depth': 6, 'subsample': 0.8085097545801423, 'colsample_bytree': 0.9465133064561354, 'min_child_weight': 1, 'gamma': 2.5096142779822053, 'reg_lambda': 9.515254721723553}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:20,251] Trial 28 pruned.
# [I 2026-03-12 00:49:20,598] Trial 29 pruned.
# [I 2026-03-12 00:49:21,065] Trial 30 pruned.
# [I 2026-03-12 00:49:23,236] Trial 31 finished with value: 0.14099567870590785 and parameters: {'n_estimators': 1197, 'learning_rate': 0.005009145682119706, 'max_depth': 5, 'subsample': 0.826099575449102, 'colsample_bytree': 0.9629553017295329, 'min_child_weight': 2, 'gamma': 1.6812902576359772, 'reg_lambda': 9.252926082954808}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:23,876] Trial 32 pruned.
# [I 2026-03-12 00:49:24,593] Trial 33 pruned.
# [I 2026-03-12 00:49:26,210] Trial 34 finished with value: 0.15364741935672774 and parameters: {'n_estimators': 1031, 'learning_rate': 0.005040909645152082, 'max_depth': 6, 'subsample': 0.8338898102036179, 'colsample_bytree': 0.8812423389765297, 'min_child_weight': 1, 'gamma': 1.634858859179047, 'reg_lambda': 2.943023199817399}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:26,483] Trial 35 pruned.
# [I 2026-03-12 00:49:26,888] Trial 36 pruned.
# [I 2026-03-12 00:49:27,358] Trial 37 pruned.
# [I 2026-03-12 00:49:28,634] Trial 38 finished with value: 0.16315259658277348 and parameters: {'n_estimators': 1137, 'learning_rate': 0.006340192820961348, 'max_depth': 6, 'subsample': 0.8954751925288542, 'colsample_bytree': 0.6667506716872799, 'min_child_weight': 1, 'gamma': 0.6508122373600358, 'reg_lambda': 1.707826345413448}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:29,097] Trial 39 pruned.
# [I 2026-03-12 00:49:30,166] Trial 40 finished with value: 0.15995393975122713 and parameters: {'n_estimators': 837, 'learning_rate': 0.008645303598637497, 'max_depth': 7, 'subsample': 0.768864031375306, 'colsample_bytree': 0.7691435473947527, 'min_child_weight': 3, 'gamma': 1.6724823394187127, 'reg_lambda': 5.3168201608763015}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:31,789] Trial 41 finished with value: 0.15056839386253437 and parameters: {'n_estimators': 1141, 'learning_rate': 0.005034254819269478, 'max_depth': 9, 'subsample': 0.6565137810745845, 'colsample_bytree': 0.9630654140309247, 'min_child_weight': 3, 'gamma': 2.0154672233074056, 'reg_lambda': 9.001269241741266}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:33,139] Trial 42 finished with value: 0.14129460067950783 and parameters: {'n_estimators': 1058, 'learning_rate': 0.005882603271337654, 'max_depth': 4, 'subsample': 0.6313725434574603, 'colsample_bytree': 0.9945298981663013, 'min_child_weight': 2, 'gamma': 1.319361269826526, 'reg_lambda': 9.670964821270994}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:33,637] Trial 43 pruned.
# [I 2026-03-12 00:49:34,462] Trial 44 finished with value: 0.13952080418864313 and parameters: {'n_estimators': 991, 'learning_rate': 0.010673512553932655, 'max_depth': 5, 'subsample': 0.7172684168411761, 'colsample_bytree': 0.9293696308325864, 'min_child_weight': 1, 'gamma': 0.5113751904016264, 'reg_lambda': 6.027465394708224}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:35,507] Trial 45 finished with value: 0.1379258999381091 and parameters: {'n_estimators': 940, 'learning_rate': 0.010862132655437624, 'max_depth': 5, 'subsample': 0.868993835312187, 'colsample_bytree': 0.9996858935347739, 'min_child_weight': 1, 'gamma': 0.3977387193888246, 'reg_lambda': 6.2263215866461}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:36,239] Trial 46 finished with value: 0.14921773915456424 and parameters: {'n_estimators': 782, 'learning_rate': 0.02634172039964528, 'max_depth': 5, 'subsample': 0.870248969434327, 'colsample_bytree': 0.903183466504781, 'min_child_weight': 1, 'gamma': 0.3906725973871127, 'reg_lambda': 4.841918570215394}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:37,560] Trial 47 finished with value: 0.1536728722371998 and parameters: {'n_estimators': 913, 'learning_rate': 0.011813864575770033, 'max_depth': 6, 'subsample': 0.9357451207111146, 'colsample_bytree': 0.9256348097482192, 'min_child_weight': 1, 'gamma': 0.017526923373961, 'reg_lambda': 1.5345430161032838}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:38,536] Trial 48 finished with value: 0.14255521019921855 and parameters: {'n_estimators': 984, 'learning_rate': 0.010384537593195521, 'max_depth': 5, 'subsample': 0.9066893923252359, 'colsample_bytree': 0.9748437878487818, 'min_child_weight': 1, 'gamma': 0.45335113217603623, 'reg_lambda': 5.992754838685447}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:38,814] Trial 49 pruned.
# [I 2026-03-12 00:49:39,645] Trial 50 finished with value: 0.13234716884459835 and parameters: {'n_estimators': 779, 'learning_rate': 0.019707694292831462, 'max_depth': 6, 'subsample': 0.8596795413411407, 'colsample_bytree': 0.9062253441663569, 'min_child_weight': 1, 'gamma': 0.24118674738562884, 'reg_lambda': 6.375402881594265}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:40,316] Trial 51 finished with value: 0.1323341121630583 and parameters: {'n_estimators': 766, 'learning_rate': 0.021680215029283228, 'max_depth': 6, 'subsample': 0.8529073912825653, 'colsample_bytree': 0.8960354059848307, 'min_child_weight': 1, 'gamma': 0.29415517115247214, 'reg_lambda': 6.616009464534947}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:41,115] Trial 52 finished with value: 0.13237428004038648 and parameters: {'n_estimators': 736, 'learning_rate': 0.017755534841750433, 'max_depth': 7, 'subsample': 0.8623394573710159, 'colsample_bytree': 0.9095434006054687, 'min_child_weight': 1, 'gamma': 0.308361379721278, 'reg_lambda': 6.559239726809563}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:41,510] Trial 53 pruned.
# [I 2026-03-12 00:49:42,257] Trial 54 finished with value: 0.14994088568976002 and parameters: {'n_estimators': 772, 'learning_rate': 0.031076687772453798, 'max_depth': 6, 'subsample': 0.8961638472264095, 'colsample_bytree': 0.8916617789013893, 'min_child_weight': 1, 'gamma': 0.09107267002388428, 'reg_lambda': 3.6783283592950906}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:43,128] Trial 55 finished with value: 0.1257842056160885 and parameters: {'n_estimators': 724, 'learning_rate': 0.020569783954296608, 'max_depth': 7, 'subsample': 0.8496793447912084, 'colsample_bytree': 0.8402614318915236, 'min_child_weight': 1, 'gamma': 0.30633633812691585, 'reg_lambda': 6.902327112901638}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:43,339] Trial 56 pruned.
# [I 2026-03-12 00:49:44,266] Trial 57 finished with value: 0.13027992210915734 and parameters: {'n_estimators': 649, 'learning_rate': 0.022570119747062214, 'max_depth': 7, 'subsample': 0.9121495798542535, 'colsample_bytree': 0.8618998181779637, 'min_child_weight': 1, 'gamma': 0.19083263087717883, 'reg_lambda': 7.274748657102759}. Best is trial 24 with value: 0.12450469140087866.
# [I 2026-03-12 00:49:44,627] Trial 58 pruned.
# [I 2026-03-12 00:49:44,940] Trial 59 pruned.
# [I 2026-03-12 00:49:45,487] Trial 60 finished with value: 0.12394761123658868 and parameters: {'n_estimators': 527, 'learning_rate': 0.04790871456052467, 'max_depth': 7, 'subsample': 0.794316461874959, 'colsample_bytree': 0.7918191132208443, 'min_child_weight': 1, 'gamma': 2.992677980022037, 'reg_lambda': 7.472644418144313}. Best is trial 60 with value: 0.12394761123658868.
# [I 2026-03-12 00:49:46,014] Trial 61 finished with value: 0.12483873940933897 and parameters: {'n_estimators': 579, 'learning_rate': 0.054033546779210725, 'max_depth': 7, 'subsample': 0.7848042874536344, 'colsample_bytree': 0.809878011488949, 'min_child_weight': 1, 'gamma': 3.000474663033103, 'reg_lambda': 7.104004188106339}. Best is trial 60 with value: 0.12394761123658868.
# [I 2026-03-12 00:49:46,560] Trial 62 finished with value: 0.15222053125802446 and parameters: {'n_estimators': 564, 'learning_rate': 0.05468470158822538, 'max_depth': 8, 'subsample': 0.9618902065385433, 'colsample_bytree': 0.7905479017891889, 'min_child_weight': 1, 'gamma': 3.0875204289340004, 'reg_lambda': 3.19538063875004}. Best is trial 60 with value: 0.12394761123658868.
# [I 2026-03-12 00:49:47,331] Trial 63 finished with value: 0.12612219529155647 and parameters: {'n_estimators': 458, 'learning_rate': 0.04512498972372884, 'max_depth': 7, 'subsample': 0.7823788185397713, 'colsample_bytree': 0.7760102010545991, 'min_child_weight': 1, 'gamma': 3.641341907474343, 'reg_lambda': 7.519476299036102}. Best is trial 60 with value: 0.12394761123658868.
# [I 2026-03-12 00:49:47,640] Trial 64 pruned.
# [I 2026-03-12 00:49:47,906] Trial 65 pruned.
# [I 2026-03-12 00:49:48,232] Trial 66 pruned.
# [I 2026-03-12 00:49:48,615] Trial 67 pruned.
# [I 2026-03-12 00:49:48,882] Trial 68 pruned.
# [I 2026-03-12 00:49:49,179] Trial 69 pruned.
# [I 2026-03-12 00:49:49,616] Trial 70 finished with value: 0.1255853343891112 and parameters: {'n_estimators': 536, 'learning_rate': 0.06626422473471776, 'max_depth': 6, 'subsample': 0.7627047656689074, 'colsample_bytree': 0.8130551611381959, 'min_child_weight': 1, 'gamma': 3.4316218560096914, 'reg_lambda': 9.91577944619908}. Best is trial 60 with value: 0.12394761123658868.
# [I 2026-03-12 00:49:50,068] Trial 71 finished with value: 0.12554261745137288 and parameters: {'n_estimators': 540, 'learning_rate': 0.06583075300694476, 'max_depth': 6, 'subsample': 0.7680949779782122, 'colsample_bytree': 0.8073571756233624, 'min_child_weight': 1, 'gamma': 3.1800129212999804, 'reg_lambda': 7.92113988497038}. Best is trial 60 with value: 0.12394761123658868.
# [I 2026-03-12 00:49:50,294] Trial 72 pruned.
# [I 2026-03-12 00:49:50,650] Trial 73 finished with value: 0.12747801439006753 and parameters: {'n_estimators': 554, 'learning_rate': 0.11720765370026055, 'max_depth': 6, 'subsample': 0.7473585243404886, 'colsample_bytree': 0.7853459048104185, 'min_child_weight': 1, 'gamma': 3.191824404901963, 'reg_lambda': 8.256683712294722}. Best is trial 60 with value: 0.12394761123658868.
# [I 2026-03-12 00:49:50,926] Trial 74 pruned.
# [I 2026-03-12 00:49:51,206] Trial 75 pruned.
# [I 2026-03-12 00:49:51,434] Trial 76 pruned.
# [I 2026-03-12 00:49:51,646] Trial 77 pruned.
# [I 2026-03-12 00:49:52,291] Trial 78 finished with value: 0.12027646331078388 and parameters: {'n_estimators': 398, 'learning_rate': 0.08221442183132173, 'max_depth': 8, 'subsample': 0.7551887391129795, 'colsample_bytree': 0.7731219595116517, 'min_child_weight': 1, 'gamma': 2.5790584591482437, 'reg_lambda': 7.724708539457204}. Best is trial 78 with value: 0.12027646331078388.
# [I 2026-03-12 00:49:52,529] Trial 79 pruned.
# [I 2026-03-12 00:49:52,785] Trial 80 pruned.
# [I 2026-03-12 00:49:53,329] Trial 81 finished with value: 0.11707634492948787 and parameters: {'n_estimators': 522, 'learning_rate': 0.08840885508702447, 'max_depth': 7, 'subsample': 0.7763192508288898, 'colsample_bytree': 0.8031594990958303, 'min_child_weight': 1, 'gamma': 2.500855817508214, 'reg_lambda': 9.92678855579677}. Best is trial 81 with value: 0.11707634492948787.
# [I 2026-03-12 00:49:53,613] Trial 82 pruned.
# [I 2026-03-12 00:49:54,169] Trial 83 finished with value: 0.11457137276873604 and parameters: {'n_estimators': 467, 'learning_rate': 0.07406529006602772, 'max_depth': 7, 'subsample': 0.772881851817478, 'colsample_bytree': 0.7371081156862017, 'min_child_weight': 1, 'gamma': 2.341418005170515, 'reg_lambda': 9.922828224830377}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:49:54,600] Trial 84 finished with value: 0.12340022906492762 and parameters: {'n_estimators': 339, 'learning_rate': 0.09358077155167674, 'max_depth': 8, 'subsample': 0.7408972262022008, 'colsample_bytree': 0.7221642641989202, 'min_child_weight': 1, 'gamma': 2.297171597332988, 'reg_lambda': 9.78472286966875}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:49:54,826] Trial 85 pruned.
# [I 2026-03-12 00:49:55,020] Trial 86 pruned.
# [I 2026-03-12 00:49:55,223] Trial 87 pruned.
# [I 2026-03-12 00:49:55,409] Trial 88 pruned.
# [I 2026-03-12 00:49:55,868] Trial 89 pruned.
# [I 2026-03-12 00:49:56,090] Trial 90 pruned.
# [I 2026-03-12 00:49:56,538] Trial 91 finished with value: 0.12803711855265482 and parameters: {'n_estimators': 408, 'learning_rate': 0.055142298026239836, 'max_depth': 7, 'subsample': 0.775169034612382, 'colsample_bytree': 0.8305675559429114, 'min_child_weight': 1, 'gamma': 2.9281885866376562, 'reg_lambda': 7.427945768362375}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:49:57,033] Trial 92 finished with value: 0.13559714272330553 and parameters: {'n_estimators': 259, 'learning_rate': 0.08761393669613744, 'max_depth': 7, 'subsample': 0.7544073593876208, 'colsample_bytree': 0.8118183031787468, 'min_child_weight': 1, 'gamma': 2.7866947502756627, 'reg_lambda': 6.573531026547047}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:49:57,307] Trial 93 pruned.
# [I 2026-03-12 00:49:57,740] Trial 94 finished with value: 0.12700511462913525 and parameters: {'n_estimators': 616, 'learning_rate': 0.03972627758518347, 'max_depth': 10, 'subsample': 0.7294370016847437, 'colsample_bytree': 0.7614297562107557, 'min_child_weight': 1, 'gamma': 2.561425923789178, 'reg_lambda': 5.569635314082075}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:49:57,935] Trial 95 pruned.
# [I 2026-03-12 00:49:58,315] Trial 96 finished with value: 0.1279561587553172 and parameters: {'n_estimators': 489, 'learning_rate': 0.09080431636006882, 'max_depth': 8, 'subsample': 0.8245633418266726, 'colsample_bytree': 0.7940699675495804, 'min_child_weight': 1, 'gamma': 3.042003783160384, 'reg_lambda': 8.226334051339974}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:49:58,914] Trial 97 pruned.
# [I 2026-03-12 00:49:59,271] Trial 98 pruned.
# [I 2026-03-12 00:49:59,547] Trial 99 pruned.
# [I 2026-03-12 00:49:59,828] Trial 100 pruned.
# [I 2026-03-12 00:50:00,273] Trial 101 pruned.
# [I 2026-03-12 00:50:00,635] Trial 102 pruned.
# [I 2026-03-12 00:50:01,332] Trial 103 finished with value: 0.12151092612021207 and parameters: {'n_estimators': 428, 'learning_rate': 0.03978544561660468, 'max_depth': 6, 'subsample': 0.7834260349158266, 'colsample_bytree': 0.7482293458944294, 'min_child_weight': 1, 'gamma': 3.689212018810541, 'reg_lambda': 8.537426963471294}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:01,701] Trial 104 pruned.
# [I 2026-03-12 00:50:02,453] Trial 105 finished with value: 0.12882828444648517 and parameters: {'n_estimators': 290, 'learning_rate': 0.03871802165394234, 'max_depth': 6, 'subsample': 0.7986244527242139, 'colsample_bytree': 0.8354928999734248, 'min_child_weight': 1, 'gamma': 2.5378338232907667, 'reg_lambda': 5.89604600757423}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:02,755] Trial 106 pruned.
# [I 2026-03-12 00:50:03,064] Trial 107 pruned.
# [I 2026-03-12 00:50:03,345] Trial 108 pruned.
# [I 2026-03-12 00:50:03,648] Trial 109 pruned.
# [I 2026-03-12 00:50:04,354] Trial 110 finished with value: 0.13285096111262426 and parameters: {'n_estimators': 483, 'learning_rate': 0.052157166920252615, 'max_depth': 8, 'subsample': 0.8820909714321191, 'colsample_bytree': 0.8712653107470112, 'min_child_weight': 1, 'gamma': 2.9197522757473724, 'reg_lambda': 6.8486713004826125}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:05,024] Trial 111 finished with value: 0.12331349205580941 and parameters: {'n_estimators': 534, 'learning_rate': 0.041054194374767795, 'max_depth': 7, 'subsample': 0.7810042232530621, 'colsample_bytree': 0.7627125827778687, 'min_child_weight': 1, 'gamma': 3.6269983018568017, 'reg_lambda': 7.919130870301076}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:05,843] Trial 112 finished with value: 0.12398395731669039 and parameters: {'n_estimators': 533, 'learning_rate': 0.029129521270608763, 'max_depth': 7, 'subsample': 0.7890117843006277, 'colsample_bytree': 0.7620808077590278, 'min_child_weight': 1, 'gamma': 3.5808764922033807, 'reg_lambda': 8.719937680066016}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:06,592] Trial 113 finished with value: 0.12214687568540566 and parameters: {'n_estimators': 540, 'learning_rate': 0.04122688098386699, 'max_depth': 7, 'subsample': 0.773672157497069, 'colsample_bytree': 0.7645058307067213, 'min_child_weight': 1, 'gamma': 4.319084909376998, 'reg_lambda': 8.762250904043333}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:07,619] Trial 114 finished with value: 0.12427240839683185 and parameters: {'n_estimators': 581, 'learning_rate': 0.029563456628144535, 'max_depth': 7, 'subsample': 0.775698945893452, 'colsample_bytree': 0.7477039639427715, 'min_child_weight': 1, 'gamma': 4.160171546567463, 'reg_lambda': 8.636255274168008}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:08,047] Trial 115 pruned.
# [I 2026-03-12 00:50:08,391] Trial 116 pruned.
# [I 2026-03-12 00:50:08,749] Trial 117 pruned.
# [I 2026-03-12 00:50:09,165] Trial 118 pruned.
# [I 2026-03-12 00:50:09,486] Trial 119 pruned.
# [I 2026-03-12 00:50:10,849] Trial 120 finished with value: 0.12459022611846583 and parameters: {'n_estimators': 366, 'learning_rate': 0.02485723811179142, 'max_depth': 7, 'subsample': 0.8053508476639025, 'colsample_bytree': 0.7098706123785674, 'min_child_weight': 1, 'gamma': 4.3038368699609, 'reg_lambda': 9.977057809530146}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:11,597] Trial 121 finished with value: 0.1242205848831012 and parameters: {'n_estimators': 297, 'learning_rate': 0.030050730811745342, 'max_depth': 7, 'subsample': 0.8045021688076479, 'colsample_bytree': 0.7125227534349988, 'min_child_weight': 1, 'gamma': 4.292556464412052, 'reg_lambda': 9.986713713470547}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:12,271] Trial 122 finished with value: 0.12571460135566076 and parameters: {'n_estimators': 293, 'learning_rate': 0.030530551891648952, 'max_depth': 7, 'subsample': 0.8041477678454823, 'colsample_bytree': 0.7068316752535664, 'min_child_weight': 1, 'gamma': 4.302193681552782, 'reg_lambda': 8.717570485029007}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:12,820] Trial 123 pruned.
# [I 2026-03-12 00:50:13,190] Trial 124 pruned.
# [I 2026-03-12 00:50:13,968] Trial 125 pruned.
# [I 2026-03-12 00:50:14,910] Trial 126 finished with value: 0.12298475182758185 and parameters: {'n_estimators': 393, 'learning_rate': 0.03431687781884787, 'max_depth': 7, 'subsample': 0.8271938645950574, 'colsample_bytree': 0.7346796652801405, 'min_child_weight': 1, 'gamma': 3.978754207920224, 'reg_lambda': 9.885054394555132}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:15,145] Trial 127 pruned.
# [I 2026-03-12 00:50:15,470] Trial 128 pruned.
# [I 2026-03-12 00:50:15,871] Trial 129 pruned.
# [I 2026-03-12 00:50:16,096] Trial 130 pruned.
# [I 2026-03-12 00:50:16,403] Trial 131 pruned.
# [I 2026-03-12 00:50:17,014] Trial 132 pruned.
# [I 2026-03-12 00:50:17,771] Trial 133 finished with value: 0.12358842399728266 and parameters: {'n_estimators': 268, 'learning_rate': 0.03407281657544096, 'max_depth': 7, 'subsample': 0.7860104875865686, 'colsample_bytree': 0.7761742130333287, 'min_child_weight': 1, 'gamma': 4.196480234932576, 'reg_lambda': 8.57226192987184}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:18,104] Trial 134 pruned.
# [I 2026-03-12 00:50:18,422] Trial 135 pruned.
# [I 2026-03-12 00:50:18,678] Trial 136 pruned.
# [I 2026-03-12 00:50:18,881] Trial 137 pruned.
# [I 2026-03-12 00:50:19,100] Trial 138 pruned.
# [I 2026-03-12 00:50:19,492] Trial 139 pruned.
# [I 2026-03-12 00:50:19,768] Trial 140 pruned.
# [I 2026-03-12 00:50:20,365] Trial 141 pruned.
# [I 2026-03-12 00:50:21,392] Trial 142 finished with value: 0.12566504808253118 and parameters: {'n_estimators': 350, 'learning_rate': 0.024802990936172196, 'max_depth': 7, 'subsample': 0.8153676121066666, 'colsample_bytree': 0.7319929832722052, 'min_child_weight': 1, 'gamma': 4.19036689408269, 'reg_lambda': 9.906847948737777}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:21,783] Trial 143 pruned.
# [I 2026-03-12 00:50:22,033] Trial 144 pruned.
# [I 2026-03-12 00:50:22,435] Trial 145 pruned.
# [I 2026-03-12 00:50:22,916] Trial 146 pruned.
# [I 2026-03-12 00:50:24,033] Trial 147 pruned.
# [I 2026-03-12 00:50:25,357] Trial 148 pruned.
# [I 2026-03-12 00:50:25,739] Trial 149 pruned.
# [I 2026-03-12 00:50:27,729] Trial 150 finished with value: 0.12807540137477366 and parameters: {'n_estimators': 550, 'learning_rate': 0.02345386294483517, 'max_depth': 8, 'subsample': 0.59768550966799, 'colsample_bytree': 0.7838408562029969, 'min_child_weight': 1, 'gamma': 2.471380345190842, 'reg_lambda': 8.25364601963689}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:29,705] Trial 151 finished with value: 0.12117469246230901 and parameters: {'n_estimators': 580, 'learning_rate': 0.013065405837974194, 'max_depth': 7, 'subsample': 0.7877531803895435, 'colsample_bytree': 0.7992984240932315, 'min_child_weight': 1, 'gamma': 1.2144127561332976, 'reg_lambda': 9.910168424240533}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:31,159] Trial 152 finished with value: 0.12264163792666295 and parameters: {'n_estimators': 671, 'learning_rate': 0.018327305097468875, 'max_depth': 7, 'subsample': 0.765672488708724, 'colsample_bytree': 0.7696331633738152, 'min_child_weight': 1, 'gamma': 3.5452715124441774, 'reg_lambda': 9.816308321950325}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:32,638] Trial 153 pruned.
# [I 2026-03-12 00:50:32,975] Trial 154 pruned.
# [I 2026-03-12 00:50:34,751] Trial 155 finished with value: 0.12228234404610738 and parameters: {'n_estimators': 564, 'learning_rate': 0.018058325158063465, 'max_depth': 7, 'subsample': 0.7883736304240985, 'colsample_bytree': 0.7807288246873949, 'min_child_weight': 1, 'gamma': 1.0414312582456067, 'reg_lambda': 8.4228406176859}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:37,080] Trial 156 finished with value: 0.12692831071232963 and parameters: {'n_estimators': 668, 'learning_rate': 0.01694426547891294, 'max_depth': 7, 'subsample': 0.726356280914741, 'colsample_bytree': 0.7980074238104942, 'min_child_weight': 1, 'gamma': 1.0190637281828636, 'reg_lambda': 7.807867304142058}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:38,532] Trial 157 pruned.
# [I 2026-03-12 00:50:40,310] Trial 158 finished with value: 0.12521907461785153 and parameters: {'n_estimators': 579, 'learning_rate': 0.014114808703593506, 'max_depth': 6, 'subsample': 0.7389959971517773, 'colsample_bytree': 0.7693179456325644, 'min_child_weight': 1, 'gamma': 0.7879623878356765, 'reg_lambda': 6.964363294267364}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:41,238] Trial 159 pruned.
# [I 2026-03-12 00:50:41,727] Trial 160 pruned.
# [I 2026-03-12 00:50:44,327] Trial 161 finished with value: 0.117007043918079 and parameters: {'n_estimators': 503, 'learning_rate': 0.019154182696364437, 'max_depth': 7, 'subsample': 0.7922377284695968, 'colsample_bytree': 0.7505961180368217, 'min_child_weight': 1, 'gamma': 0.8881278489214208, 'reg_lambda': 9.921179543859976}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:49,014] Trial 162 finished with value: 0.11782630981536779 and parameters: {'n_estimators': 499, 'learning_rate': 0.01856231286592356, 'max_depth': 7, 'subsample': 0.7941787224405652, 'colsample_bytree': 0.7348683584529296, 'min_child_weight': 1, 'gamma': 0.9372572363907651, 'reg_lambda': 9.995920374518597}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:50,799] Trial 163 finished with value: 0.12209687976288999 and parameters: {'n_estimators': 502, 'learning_rate': 0.021917016691834146, 'max_depth': 7, 'subsample': 0.7960659927915407, 'colsample_bytree': 0.799320251468289, 'min_child_weight': 1, 'gamma': 0.9331400109652995, 'reg_lambda': 8.618945875362163}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:52,094] Trial 164 finished with value: 0.12326829491970738 and parameters: {'n_estimators': 502, 'learning_rate': 0.019124395595986932, 'max_depth': 7, 'subsample': 0.7917595326865985, 'colsample_bytree': 0.8044850412025625, 'min_child_weight': 1, 'gamma': 0.8971124233670823, 'reg_lambda': 8.24286131411606}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:56,663] Trial 165 finished with value: 0.1278029359364308 and parameters: {'n_estimators': 501, 'learning_rate': 0.018072031160420405, 'max_depth': 7, 'subsample': 0.7932230695070336, 'colsample_bytree': 0.8020466268147844, 'min_child_weight': 1, 'gamma': 0.8905185226561829, 'reg_lambda': 6.281234616475251}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:50:59,421] Trial 166 finished with value: 0.12710323120888456 and parameters: {'n_estimators': 476, 'learning_rate': 0.01889776692812201, 'max_depth': 7, 'subsample': 0.7618034289359862, 'colsample_bytree': 0.8150408832835049, 'min_child_weight': 1, 'gamma': 1.0966516456829092, 'reg_lambda': 7.4990829865835895}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:00,893] Trial 167 finished with value: 0.11865086713336703 and parameters: {'n_estimators': 511, 'learning_rate': 0.019060477928167206, 'max_depth': 8, 'subsample': 0.7969511552880713, 'colsample_bytree': 0.8248082224613751, 'min_child_weight': 1, 'gamma': 0.6748290469375444, 'reg_lambda': 9.994483739675308}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:03,265] Trial 168 finished with value: 0.11834520057598776 and parameters: {'n_estimators': 456, 'learning_rate': 0.021746877506240166, 'max_depth': 9, 'subsample': 0.7759612243033428, 'colsample_bytree': 0.8201564585121616, 'min_child_weight': 1, 'gamma': 0.6244176003957345, 'reg_lambda': 9.923172232575848}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:04,548] Trial 169 finished with value: 0.11884421928082087 and parameters: {'n_estimators': 454, 'learning_rate': 0.02102823042969321, 'max_depth': 9, 'subsample': 0.7752894774412075, 'colsample_bytree': 0.8295795131225826, 'min_child_weight': 1, 'gamma': 0.6320863371009481, 'reg_lambda': 9.715833725743114}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:05,849] Trial 170 finished with value: 0.13144401949834666 and parameters: {'n_estimators': 457, 'learning_rate': 0.02203001958485573, 'max_depth': 9, 'subsample': 0.7725527539798175, 'colsample_bytree': 0.8223721063071197, 'min_child_weight': 1, 'gamma': 0.6154571302212276, 'reg_lambda': 5.968728979629273}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:06,390] Trial 171 pruned.
# [I 2026-03-12 00:51:07,611] Trial 172 finished with value: 0.120842839273249 and parameters: {'n_estimators': 504, 'learning_rate': 0.01579931566181054, 'max_depth': 10, 'subsample': 0.7971451421167816, 'colsample_bytree': 0.8273980117345269, 'min_child_weight': 1, 'gamma': 0.875828254681848, 'reg_lambda': 9.997113110251437}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:08,653] Trial 173 finished with value: 0.1253203961201116 and parameters: {'n_estimators': 500, 'learning_rate': 0.01564802528509616, 'max_depth': 10, 'subsample': 0.7974617790101084, 'colsample_bytree': 0.8321038250499305, 'min_child_weight': 1, 'gamma': 0.9700719299824775, 'reg_lambda': 7.630606954890226}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:10,055] Trial 174 finished with value: 0.11870191786025516 and parameters: {'n_estimators': 469, 'learning_rate': 0.018095962032601876, 'max_depth': 10, 'subsample': 0.7785622604950047, 'colsample_bytree': 0.8258307997872072, 'min_child_weight': 1, 'gamma': 0.857014704271804, 'reg_lambda': 9.99449753715113}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:11,322] Trial 175 finished with value: 0.12047192638754668 and parameters: {'n_estimators': 442, 'learning_rate': 0.01757439920355204, 'max_depth': 11, 'subsample': 0.8171603675950729, 'colsample_bytree': 0.8262068144659428, 'min_child_weight': 1, 'gamma': 0.5287998029023884, 'reg_lambda': 9.780776473347874}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:12,512] Trial 176 finished with value: 0.12859019501362826 and parameters: {'n_estimators': 426, 'learning_rate': 0.017592989754139515, 'max_depth': 11, 'subsample': 0.8136149677956095, 'colsample_bytree': 0.8263387698782103, 'min_child_weight': 1, 'gamma': 0.5339107826222821, 'reg_lambda': 6.593298162796633}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:13,586] Trial 177 finished with value: 0.11986019261191319 and parameters: {'n_estimators': 450, 'learning_rate': 0.021383490121845636, 'max_depth': 10, 'subsample': 0.8190985610270116, 'colsample_bytree': 0.8571831378645818, 'min_child_weight': 1, 'gamma': 0.751841598647668, 'reg_lambda': 9.870814416765818}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:15,199] Trial 178 finished with value: 0.12293249916249342 and parameters: {'n_estimators': 451, 'learning_rate': 0.013137263940357505, 'max_depth': 10, 'subsample': 0.8148392437763229, 'colsample_bytree': 0.8559546993296606, 'min_child_weight': 1, 'gamma': 0.7970597303599881, 'reg_lambda': 9.969096577845198}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:16,081] Trial 179 finished with value: 0.12170770667473567 and parameters: {'n_estimators': 468, 'learning_rate': 0.021283467818035754, 'max_depth': 10, 'subsample': 0.8002665231370102, 'colsample_bytree': 0.8472163238740784, 'min_child_weight': 1, 'gamma': 0.672118575132421, 'reg_lambda': 8.3298862845327}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:16,555] Trial 180 pruned.
# [I 2026-03-12 00:51:17,495] Trial 181 finished with value: 0.12169540052215734 and parameters: {'n_estimators': 443, 'learning_rate': 0.02119863463750537, 'max_depth': 10, 'subsample': 0.7765187486325704, 'colsample_bytree': 0.8416045562018261, 'min_child_weight': 1, 'gamma': 0.6102990167984192, 'reg_lambda': 8.590890612618708}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:18,391] Trial 182 finished with value: 0.12275299914860265 and parameters: {'n_estimators': 441, 'learning_rate': 0.020813215093682023, 'max_depth': 10, 'subsample': 0.776922806927251, 'colsample_bytree': 0.8437462870934525, 'min_child_weight': 1, 'gamma': 0.6871044731984203, 'reg_lambda': 8.121145004001587}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:19,371] Trial 183 finished with value: 0.1259409496546666 and parameters: {'n_estimators': 473, 'learning_rate': 0.021618342603695096, 'max_depth': 11, 'subsample': 0.8006350917121889, 'colsample_bytree': 0.8599562722290555, 'min_child_weight': 1, 'gamma': 0.3927350294761591, 'reg_lambda': 6.767248895239537}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:20,810] Trial 184 finished with value: 0.12434590762387525 and parameters: {'n_estimators': 418, 'learning_rate': 0.01595327815807473, 'max_depth': 10, 'subsample': 0.7889476979236296, 'colsample_bytree': 0.8375296613219207, 'min_child_weight': 1, 'gamma': 0.8513331919952447, 'reg_lambda': 7.93984948689896}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:22,034] Trial 185 finished with value: 0.12366551615353084 and parameters: {'n_estimators': 512, 'learning_rate': 0.017033621025523246, 'max_depth': 10, 'subsample': 0.7760141453890348, 'colsample_bytree': 0.818843893746464, 'min_child_weight': 1, 'gamma': 0.5737239899839089, 'reg_lambda': 8.548144601349554}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:22,818] Trial 186 pruned.
# [I 2026-03-12 00:51:24,853] Trial 187 finished with value: 0.12289330685029062 and parameters: {'n_estimators': 480, 'learning_rate': 0.01959264288599534, 'max_depth': 10, 'subsample': 0.8079088758154358, 'colsample_bytree': 0.833713116048031, 'min_child_weight': 1, 'gamma': 1.0206991299456076, 'reg_lambda': 8.695476063834075}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:25,788] Trial 188 pruned.
# [I 2026-03-12 00:51:26,567] Trial 189 finished with value: 0.12539580965169586 and parameters: {'n_estimators': 516, 'learning_rate': 0.02222414838098716, 'max_depth': 12, 'subsample': 0.7714174515601198, 'colsample_bytree': 0.8269225141013415, 'min_child_weight': 1, 'gamma': 0.9243107075131722, 'reg_lambda': 7.116720938792152}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:27,481] Trial 190 finished with value: 0.11951745683016027 and parameters: {'n_estimators': 489, 'learning_rate': 0.018071249292874608, 'max_depth': 9, 'subsample': 0.7968224650287707, 'colsample_bytree': 0.8688462942272137, 'min_child_weight': 1, 'gamma': 0.6242259482497531, 'reg_lambda': 9.905230025258719}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:28,308] Trial 191 finished with value: 0.12123796222409199 and parameters: {'n_estimators': 493, 'learning_rate': 0.017852007611116976, 'max_depth': 9, 'subsample': 0.8001107596373611, 'colsample_bytree': 0.8681147811034539, 'min_child_weight': 1, 'gamma': 0.6368423398804781, 'reg_lambda': 8.690178102343447}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:29,185] Trial 192 finished with value: 0.11906937711537416 and parameters: {'n_estimators': 457, 'learning_rate': 0.019773112758354014, 'max_depth': 9, 'subsample': 0.7960531461553316, 'colsample_bytree': 0.873146545430842, 'min_child_weight': 1, 'gamma': 0.6185324722709279, 'reg_lambda': 9.829815286838851}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:30,024] Trial 193 finished with value: 0.12011346256020015 and parameters: {'n_estimators': 452, 'learning_rate': 0.016616174644695572, 'max_depth': 9, 'subsample': 0.8034742099929351, 'colsample_bytree': 0.8697990295530802, 'min_child_weight': 1, 'gamma': 0.5883929214813106, 'reg_lambda': 9.963700520132772}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:31,180] Trial 194 finished with value: 0.12173897902369252 and parameters: {'n_estimators': 413, 'learning_rate': 0.016399935889678814, 'max_depth': 9, 'subsample': 0.8341486700395482, 'colsample_bytree': 0.870800745079595, 'min_child_weight': 1, 'gamma': 0.6098611776026578, 'reg_lambda': 9.979561117177843}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:32,377] Trial 195 pruned.
# [I 2026-03-12 00:51:34,039] Trial 196 finished with value: 0.12062412855735974 and parameters: {'n_estimators': 435, 'learning_rate': 0.015545757609482755, 'max_depth': 9, 'subsample': 0.8014540631731996, 'colsample_bytree': 0.8662974830080389, 'min_child_weight': 1, 'gamma': 0.6556455432547985, 'reg_lambda': 9.934936695844002}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:35,669] Trial 197 finished with value: 0.12116706884953474 and parameters: {'n_estimators': 437, 'learning_rate': 0.015046057711925196, 'max_depth': 9, 'subsample': 0.8068279048646464, 'colsample_bytree': 0.8641963583916857, 'min_child_weight': 1, 'gamma': 0.5314687034978559, 'reg_lambda': 9.913140111509732}. Best is trial 83 with value: 0.11457137276873604.
# [I 2026-03-12 00:51:36,771] Trial 198 pruned.
# [I 2026-03-12 00:51:39,279] Trial 199 pruned.
# Best trial parameters: {'n_estimators': 467, 'learning_rate': 0.07406529006602772, 'max_depth': 7, 'subsample': 0.772881851817478, 'colsample_bytree': 0.7371081156862017, 'min_child_weight': 1, 'gamma': 2.341418005170515, 'reg_lambda': 9.922828224830377}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# Get the exact number of trees where it peaked
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7371081156862017, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=2.341418005170515, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07406529006602772,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=92, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 0.1701
# MAE:  0.0571
# R2:   0.1590

# %%
# For Comparrison a naive non ML just guessing that tomorrow's CO will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 0.1701
# Naive Baseline RMSE: 0.0687

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title("SHAP Feature Importance: What drives CO Pollution?")
plt.tight_layout()
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
# Out:
# <BarContainer object of 8 artists>

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])
    
    print(f"Station {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label='Actual CO', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label='Predicted CO', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted CO\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel('CO ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()
# Out:
# RMSE: 0.1701
# MAE:  0.0571
# R2:   0.1590
# Station IE/SPO.IE.IE001CMSample1_10 -> RMSE: 0.31 | MAE: 0.08 | R2: -6.20
# Station IE/SPO.IE.IE0098ASample1_10 -> RMSE: 0.08 | MAE: 0.05 | R2: 0.61
# Station IE/SPO.IE.IE009DPSample1_10 -> RMSE: 0.14 | MAE: 0.10 | R2: 0.68
# Station IE/SPO.IE.IE027DSample2_10 -> RMSE: 0.06 | MAE: 0.04 | R2: 0.69
# Station IE/SPO.IE.IE002CMSample1_10 -> RMSE: 0.06 | MAE: 0.04 | R2: 0.80
