# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os
import joblib
from pathlib import Path

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
POLLUTANT = "NOXasNO2"

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
RESULTS_SAVE_FOLDER = os.getenv("RESULTS_SAVE_FOLDER")

# %%
# reading in data
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
# saving results
RUN_ID = f"{COUNTRY_CODE}_{POLLUTANT}"

output_dir = Path(RESULTS_SAVE_FOLDER) / f"Results_{RUN_ID}"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# saving model
model_filename = output_dir / f"xgboost_model_{COUNTRY_CODE}_{POLLUTANT}.pkl"

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#                 Samplingpoint      Start       Value
# 0  IE/SPO.IE.IE001APSample2_9 2018-11-20         NaN
# 1  IE/SPO.IE.IE001APSample2_9 2018-11-21   44.271667
# 2  IE/SPO.IE.IE001APSample2_9 2018-11-22   34.722500
# 3  IE/SPO.IE.IE001APSample2_9 2018-11-23   63.483750
# 4  IE/SPO.IE.IE001APSample2_9 2018-11-24   49.685833
# 5  IE/SPO.IE.IE001APSample2_9 2018-11-25   29.287500
# 6  IE/SPO.IE.IE001APSample2_9 2018-11-26  134.568333
# 7  IE/SPO.IE.IE001APSample2_9 2018-11-27   25.340417
# 8  IE/SPO.IE.IE001APSample2_9 2018-11-28   13.943333
# 9  IE/SPO.IE.IE001APSample2_9 2018-11-29   27.902917

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (91760, 11)
#        Start               Samplingpoint       Value  DayOfWeek  Month  \
# 0 2018-11-20  IE/SPO.IE.IE001APSample2_9         NaN          1     11
# 1 2018-11-21  IE/SPO.IE.IE001APSample2_9   44.271667          2     11
# 2 2018-11-22  IE/SPO.IE.IE001APSample2_9   34.722500          3     11
# 3 2018-11-23  IE/SPO.IE.IE001APSample2_9   63.483750          4     11
# 4 2018-11-24  IE/SPO.IE.IE001APSample2_9   49.685833          5     11
# 5 2018-11-25  IE/SPO.IE.IE001APSample2_9   29.287500          6     11
# 6 2018-11-26  IE/SPO.IE.IE001APSample2_9  134.568333          0     11
# 7 2018-11-27  IE/SPO.IE.IE001APSample2_9   25.340417          1     11
# 8 2018-11-28  IE/SPO.IE.IE001APSample2_9   13.943333          2     11
# 9 2018-11-29  IE/SPO.IE.IE001APSample2_9   27.902917          3     11
#
#    DayOfYear  IsWeekend       Lag_1      Lag_7  Rolling_Mean_7D      Target
# 0        324          0         NaN        NaN              NaN   44.271667
# 1        325          0         NaN        NaN              NaN   34.722500
# 2        326          0   44.271667        NaN              NaN   63.483750
# 3        327          0   34.722500        NaN              NaN   49.685833
# 4        328          1   63.483750        NaN        48.040938   29.287500
# 5        329          1   49.685833        NaN        44.290250  134.568333
# 6        330          0   29.287500        NaN        59.336597   25.340417
# 7        331          0  134.568333        NaN        54.480000   13.943333
# 8        332          0   25.340417  44.271667        50.147381   27.902917
# 9        333          0   13.943333  34.722500        49.173155   29.701667

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start               Samplingpoint       Value  DayOfWeek  Month  \
# 0 2018-11-20  IE/SPO.IE.IE001APSample2_9         NaN          1     11
# 1 2018-11-21  IE/SPO.IE.IE001APSample2_9   44.271667          2     11
# 2 2018-11-22  IE/SPO.IE.IE001APSample2_9   34.722500          3     11
# 3 2018-11-23  IE/SPO.IE.IE001APSample2_9   63.483750          4     11
# 4 2018-11-24  IE/SPO.IE.IE001APSample2_9   49.685833          5     11
# 5 2018-11-25  IE/SPO.IE.IE001APSample2_9   29.287500          6     11
# 6 2018-11-26  IE/SPO.IE.IE001APSample2_9  134.568333          0     11
# 7 2018-11-27  IE/SPO.IE.IE001APSample2_9   25.340417          1     11
# 8 2018-11-28  IE/SPO.IE.IE001APSample2_9   13.943333          2     11
# 9 2018-11-29  IE/SPO.IE.IE001APSample2_9   27.902917          3     11
#
#    DayOfYear  IsWeekend       Lag_1      Lag_7  Rolling_Mean_7D      Target
# 0        324          0         NaN        NaN              NaN   44.271667
# 1        325          0         NaN        NaN              NaN   34.722500
# 2        326          0   44.271667        NaN              NaN   63.483750
# 3        327          0   34.722500        NaN              NaN   49.685833
# 4        328          1   63.483750        NaN        48.040938   29.287500
# 5        329          1   49.685833        NaN        44.290250  134.568333
# 6        330          0   29.287500        NaN        59.336597   25.340417
# 7        331          0  134.568333        NaN        54.480000   13.943333
# 8        332          0   25.340417  44.271667        50.147381   27.902917
# 9        333          0   13.943333  34.722500        49.173155   29.701667
# Start                 0
# Samplingpoint         0
# Value               373
# DayOfWeek             0
# Month                 0
# DayOfYear             0
# IsWeekend             0
# Lag_1               672
# Lag_7              1756
# Rolling_Mean_7D     907
# Target                0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (37460, 9), Val shape: (19292, 9), Test shape: (24599, 9)

# %%
# save features 
feature_names = list(X_train.columns)
features_filename = output_dir / f"xgboost_features_{COUNTRY_CODE}_{POLLUTANT}.pkl"
joblib.dump(feature_names, features_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source\\SavedResults\\Results_IE_NOXasNO2\\xgboost_features_IE_NOXasNO2.pkl']

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 13:20:04,773] A new study created in memory with name: no-name-bd1956c4-0b2c-4c69-9382-abb296ed762f
# [I 2026-03-12 13:20:08,200] Trial 0 finished with value: 24.997773228651248 and parameters: {'n_estimators': 722, 'learning_rate': 0.14941834093177997, 'max_depth': 9, 'subsample': 0.6645581032611589, 'colsample_bytree': 0.9095879184562248, 'min_child_weight': 7, 'gamma': 1.7554085481083899, 'reg_lambda': 0.0054396682753069395}. Best is trial 0 with value: 24.997773228651248.
# [I 2026-03-12 13:20:11,308] Trial 1 finished with value: 24.953840718416835 and parameters: {'n_estimators': 922, 'learning_rate': 0.08497448731342049, 'max_depth': 7, 'subsample': 0.8310907344902092, 'colsample_bytree': 0.6491496942935906, 'min_child_weight': 4, 'gamma': 4.992265239091017, 'reg_lambda': 2.024865215506878}. Best is trial 1 with value: 24.953840718416835.
# [I 2026-03-12 13:20:16,019] Trial 2 finished with value: 24.949620416638883 and parameters: {'n_estimators': 1026, 'learning_rate': 0.08351883057815788, 'max_depth': 12, 'subsample': 0.6123460494050266, 'colsample_bytree': 0.9894497638089177, 'min_child_weight': 10, 'gamma': 0.9552001664500903, 'reg_lambda': 0.5862951320345421}. Best is trial 2 with value: 24.949620416638883.
# [I 2026-03-12 13:20:25,425] Trial 3 finished with value: 24.247736492938618 and parameters: {'n_estimators': 858, 'learning_rate': 0.010028306965189976, 'max_depth': 4, 'subsample': 0.86765355705067, 'colsample_bytree': 0.7865698967196804, 'min_child_weight': 10, 'gamma': 1.3566022552115764, 'reg_lambda': 0.14367994970172365}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:20:28,589] Trial 4 finished with value: 24.53237172919489 and parameters: {'n_estimators': 892, 'learning_rate': 0.04179038654781886, 'max_depth': 6, 'subsample': 0.6678393073125082, 'colsample_bytree': 0.7090197305661572, 'min_child_weight': 3, 'gamma': 2.653665638434559, 'reg_lambda': 0.012573598748810415}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:20:31,524] Trial 5 finished with value: 24.840620297316097 and parameters: {'n_estimators': 390, 'learning_rate': 0.10690927603376069, 'max_depth': 7, 'subsample': 0.8127275837523753, 'colsample_bytree': 0.8986532140961841, 'min_child_weight': 4, 'gamma': 2.205058546575679, 'reg_lambda': 0.5298936647772167}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:20:35,696] Trial 6 finished with value: 24.56293620313598 and parameters: {'n_estimators': 1035, 'learning_rate': 0.02608957343499662, 'max_depth': 6, 'subsample': 0.8059514671396808, 'colsample_bytree': 0.9834644572809803, 'min_child_weight': 3, 'gamma': 0.8892836270435872, 'reg_lambda': 0.006445738115274507}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:20:37,435] Trial 7 finished with value: 24.58669994300212 and parameters: {'n_estimators': 1016, 'learning_rate': 0.1269477281246128, 'max_depth': 5, 'subsample': 0.678712213200666, 'colsample_bytree': 0.9291508172181699, 'min_child_weight': 3, 'gamma': 2.204734132098449, 'reg_lambda': 0.09684301665715347}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:20:40,990] Trial 8 finished with value: 25.009902504539166 and parameters: {'n_estimators': 287, 'learning_rate': 0.08409181518900057, 'max_depth': 10, 'subsample': 0.7547743898747481, 'colsample_bytree': 0.8173251135947972, 'min_child_weight': 8, 'gamma': 3.8291086719481022, 'reg_lambda': 0.3885480613666362}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:20:45,180] Trial 9 finished with value: 25.31222742096912 and parameters: {'n_estimators': 467, 'learning_rate': 0.10515667741038964, 'max_depth': 12, 'subsample': 0.9734450367575191, 'colsample_bytree': 0.780029838436572, 'min_child_weight': 9, 'gamma': 0.13776424949359267, 'reg_lambda': 0.633387177221393}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:20:47,439] Trial 10 pruned.
# [I 2026-03-12 13:20:52,553] Trial 11 finished with value: 24.276465890506742 and parameters: {'n_estimators': 765, 'learning_rate': 0.020353247511987818, 'max_depth': 3, 'subsample': 0.9339667072057136, 'colsample_bytree': 0.6506149785892871, 'min_child_weight': 1, 'gamma': 3.058961042040009, 'reg_lambda': 0.027388344614561348}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:21:00,075] Trial 12 finished with value: 24.296152787554046 and parameters: {'n_estimators': 718, 'learning_rate': 0.00990190069042777, 'max_depth': 3, 'subsample': 0.9643351350675146, 'colsample_bytree': 0.6220784835450716, 'min_child_weight': 1, 'gamma': 3.914385448507713, 'reg_lambda': 0.04429760512661585}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:21:06,361] Trial 13 finished with value: 24.325517554962847 and parameters: {'n_estimators': 1197, 'learning_rate': 0.015285517513967213, 'max_depth': 4, 'subsample': 0.8962713054215414, 'colsample_bytree': 0.5859395329400165, 'min_child_weight': 1, 'gamma': 1.2936183190768535, 'reg_lambda': 0.0323876464413672}. Best is trial 3 with value: 24.247736492938618.
# [I 2026-03-12 13:21:13,565] Trial 14 finished with value: 24.24536541132209 and parameters: {'n_estimators': 640, 'learning_rate': 0.011659362935676274, 'max_depth': 4, 'subsample': 0.8926264965564834, 'colsample_bytree': 0.7138984880294645, 'min_child_weight': 10, 'gamma': 3.155415011732383, 'reg_lambda': 0.001134956211022954}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:21:23,503] Trial 15 finished with value: 24.34991785853124 and parameters: {'n_estimators': 557, 'learning_rate': 0.008048760162095886, 'max_depth': 5, 'subsample': 0.8565753563437747, 'colsample_bytree': 0.8317119430194925, 'min_child_weight': 10, 'gamma': 4.44956004669041, 'reg_lambda': 0.0011181610761031371}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:21:32,342] Trial 16 finished with value: 24.740233987512664 and parameters: {'n_estimators': 620, 'learning_rate': 0.012788489831901485, 'max_depth': 9, 'subsample': 0.9018814812684872, 'colsample_bytree': 0.7365491754401862, 'min_child_weight': 8, 'gamma': 0.20719413487071825, 'reg_lambda': 0.15434727238147888}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:21:34,340] Trial 17 finished with value: 24.366469035361053 and parameters: {'n_estimators': 886, 'learning_rate': 0.04387352192045405, 'max_depth': 5, 'subsample': 0.7572139967421941, 'colsample_bytree': 0.8402776536746358, 'min_child_weight': 9, 'gamma': 1.5116256966963388, 'reg_lambda': 0.00198484400464353}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:21:42,071] Trial 18 finished with value: 24.397925978623235 and parameters: {'n_estimators': 554, 'learning_rate': 0.005047766949050562, 'max_depth': 4, 'subsample': 0.8824993821540645, 'colsample_bytree': 0.7061746460202722, 'min_child_weight': 6, 'gamma': 2.909364702223449, 'reg_lambda': 0.10599141806754955}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:21:53,605] Trial 19 finished with value: 24.71309606357178 and parameters: {'n_estimators': 1164, 'learning_rate': 0.008103041822988304, 'max_depth': 8, 'subsample': 0.9949276296593534, 'colsample_bytree': 0.7741927944534894, 'min_child_weight': 10, 'gamma': 3.4567782988464297, 'reg_lambda': 2.2663786187683206}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:21:58,196] Trial 20 finished with value: 24.32208629135338 and parameters: {'n_estimators': 798, 'learning_rate': 0.017251162835119776, 'max_depth': 4, 'subsample': 0.9275357965507056, 'colsample_bytree': 0.5474965709482174, 'min_child_weight': 8, 'gamma': 1.9832495452329837, 'reg_lambda': 0.0030480608719521936}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:02,484] Trial 21 finished with value: 24.262241510534764 and parameters: {'n_estimators': 786, 'learning_rate': 0.022318420542933676, 'max_depth': 3, 'subsample': 0.9361555753061512, 'colsample_bytree': 0.6498072005720334, 'min_child_weight': 5, 'gamma': 2.8697194772630326, 'reg_lambda': 0.020916161605766228}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:06,001] Trial 22 finished with value: 24.2887992027259 and parameters: {'n_estimators': 650, 'learning_rate': 0.032624804761052686, 'max_depth': 4, 'subsample': 0.8605789461829971, 'colsample_bytree': 0.6915565993622508, 'min_child_weight': 5, 'gamma': 2.531496318695798, 'reg_lambda': 0.0157800160403907}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:12,937] Trial 23 finished with value: 24.25635843664854 and parameters: {'n_estimators': 821, 'learning_rate': 0.012688659241579353, 'max_depth': 3, 'subsample': 0.9452697702953771, 'colsample_bytree': 0.6761807943141867, 'min_child_weight': 7, 'gamma': 3.5327357215001993, 'reg_lambda': 0.1999264439060649}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:19,465] Trial 24 finished with value: 24.454029555061876 and parameters: {'n_estimators': 874, 'learning_rate': 0.011173897360954432, 'max_depth': 6, 'subsample': 0.7989123748545194, 'colsample_bytree': 0.7508879151299809, 'min_child_weight': 9, 'gamma': 3.9750154930244306, 'reg_lambda': 0.2050369234884508}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:27,572] Trial 25 finished with value: 24.372402877085545 and parameters: {'n_estimators': 551, 'learning_rate': 0.007157380019249348, 'max_depth': 5, 'subsample': 0.9988019420541742, 'colsample_bytree': 0.797259715967837, 'min_child_weight': 9, 'gamma': 3.4546812045852278, 'reg_lambda': 0.06360355649677517}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:31,871] Trial 26 finished with value: 24.2718951188508 and parameters: {'n_estimators': 652, 'learning_rate': 0.014456075433319488, 'max_depth': 4, 'subsample': 0.8533048938162494, 'colsample_bytree': 0.8731455597229644, 'min_child_weight': 7, 'gamma': 4.521089636362693, 'reg_lambda': 1.3507209415264676}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:41,378] Trial 27 finished with value: 24.25180509540285 and parameters: {'n_estimators': 971, 'learning_rate': 0.009161445329840525, 'max_depth': 3, 'subsample': 0.9110032109894629, 'colsample_bytree': 0.7339043704729586, 'min_child_weight': 7, 'gamma': 0.6459973928925322, 'reg_lambda': 0.0665664419309494}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:49,742] Trial 28 finished with value: 24.34497752341874 and parameters: {'n_estimators': 937, 'learning_rate': 0.009284814471381632, 'max_depth': 5, 'subsample': 0.7807232183714822, 'colsample_bytree': 0.7486059132802934, 'min_child_weight': 10, 'gamma': 0.7149069076178569, 'reg_lambda': 6.915249300366223}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:22:51,222] Trial 29 finished with value: 25.33457827283627 and parameters: {'n_estimators': 1074, 'learning_rate': 0.18431818456847854, 'max_depth': 8, 'subsample': 0.9049749681053696, 'colsample_bytree': 0.7295042164546959, 'min_child_weight': 8, 'gamma': 0.4026386887992262, 'reg_lambda': 0.008400781279409592}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:01,965] Trial 30 finished with value: 24.432799648152926 and parameters: {'n_estimators': 713, 'learning_rate': 0.0059546209627913665, 'max_depth': 6, 'subsample': 0.7115840001420539, 'colsample_bytree': 0.8604867510270076, 'min_child_weight': 7, 'gamma': 1.8317917744301138, 'reg_lambda': 0.004717156046401055}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:09,353] Trial 31 finished with value: 24.25937794635137 and parameters: {'n_estimators': 827, 'learning_rate': 0.011809492183383539, 'max_depth': 3, 'subsample': 0.9507113443574878, 'colsample_bytree': 0.6765656026432543, 'min_child_weight': 7, 'gamma': 1.4870040199832388, 'reg_lambda': 0.2150730036441708}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:19,273] Trial 32 finished with value: 24.275544546307195 and parameters: {'n_estimators': 954, 'learning_rate': 0.006909611316598541, 'max_depth': 3, 'subsample': 0.8824186065452289, 'colsample_bytree': 0.6166849760768285, 'min_child_weight': 6, 'gamma': 0.5588109073485731, 'reg_lambda': 0.30385839044777435}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:23,213] Trial 33 finished with value: 24.31150169550243 and parameters: {'n_estimators': 1085, 'learning_rate': 0.01778524120276009, 'max_depth': 4, 'subsample': 0.8389950777924334, 'colsample_bytree': 0.6662084057673502, 'min_child_weight': 7, 'gamma': 1.1316906078026816, 'reg_lambda': 0.9460793524236281}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:39,715] Trial 34 finished with value: 24.815270322457536 and parameters: {'n_estimators': 955, 'learning_rate': 0.009903320496934414, 'max_depth': 11, 'subsample': 0.925061354582958, 'colsample_bytree': 0.7184017302718491, 'min_child_weight': 9, 'gamma': 3.4031107788581427, 'reg_lambda': 0.07058953656347462}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:45,655] Trial 35 finished with value: 24.260996817502765 and parameters: {'n_estimators': 835, 'learning_rate': 0.013174320255918066, 'max_depth': 4, 'subsample': 0.6123825418267617, 'colsample_bytree': 0.7706190928865925, 'min_child_weight': 10, 'gamma': 3.686335590896675, 'reg_lambda': 3.017974372197383}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:47,345] Trial 36 finished with value: 24.258905840151936 and parameters: {'n_estimators': 709, 'learning_rate': 0.0632067317680684, 'max_depth': 3, 'subsample': 0.8278072440953714, 'colsample_bytree': 0.6889399273161716, 'min_child_weight': 8, 'gamma': 4.2861542563409, 'reg_lambda': 0.1351671964639467}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:23:51,473] Trial 37 finished with value: 24.73090528999631 and parameters: {'n_estimators': 1003, 'learning_rate': 0.02967178068693373, 'max_depth': 7, 'subsample': 0.966291832264391, 'colsample_bytree': 0.6155311577590671, 'min_child_weight': 4, 'gamma': 4.819881713724893, 'reg_lambda': 0.05476326652332254}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:24:01,104] Trial 38 finished with value: 24.340457282706083 and parameters: {'n_estimators': 1125, 'learning_rate': 0.006261520943771529, 'max_depth': 5, 'subsample': 0.8790027357887666, 'colsample_bytree': 0.7897532073242826, 'min_child_weight': 10, 'gamma': 2.6966288622095784, 'reg_lambda': 0.011824389997848999}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:24:11,212] Trial 39 finished with value: 24.52854463166275 and parameters: {'n_estimators': 869, 'learning_rate': 0.008089638389375993, 'max_depth': 6, 'subsample': 0.9034526134243192, 'colsample_bytree': 0.8060769590560436, 'min_child_weight': 5, 'gamma': 2.294508398758897, 'reg_lambda': 0.38195232151570385}. Best is trial 14 with value: 24.24536541132209.
# [I 2026-03-12 13:24:17,069] Trial 40 finished with value: 24.226438566605506 and parameters: {'n_estimators': 360, 'learning_rate': 0.021126109008091122, 'max_depth': 3, 'subsample': 0.7810448284909817, 'colsample_bytree': 0.751668983778592, 'min_child_weight': 9, 'gamma': 1.5700666861855275, 'reg_lambda': 0.0014688879174797485}. Best is trial 40 with value: 24.226438566605506.
# [I 2026-03-12 13:24:23,700] Trial 41 finished with value: 24.20458240140606 and parameters: {'n_estimators': 366, 'learning_rate': 0.023119879848429975, 'max_depth': 3, 'subsample': 0.699661976144817, 'colsample_bytree': 0.7092882294743479, 'min_child_weight': 9, 'gamma': 1.1397085874348016, 'reg_lambda': 0.0013862881040276477}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:28,015] Trial 42 finished with value: 24.231844651660204 and parameters: {'n_estimators': 307, 'learning_rate': 0.024444957852544223, 'max_depth': 4, 'subsample': 0.7355200071338697, 'colsample_bytree': 0.7636671273440705, 'min_child_weight': 9, 'gamma': 1.0260950580769914, 'reg_lambda': 0.0012578672447651643}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:30,720] Trial 43 finished with value: 24.276860229248573 and parameters: {'n_estimators': 314, 'learning_rate': 0.039315766654731875, 'max_depth': 4, 'subsample': 0.7147606248431985, 'colsample_bytree': 0.7578235193770203, 'min_child_weight': 9, 'gamma': 1.0084626635095026, 'reg_lambda': 0.0011568743112408296}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:34,111] Trial 44 finished with value: 24.328529729877765 and parameters: {'n_estimators': 137, 'learning_rate': 0.024800927234314665, 'max_depth': 4, 'subsample': 0.6380155661256965, 'colsample_bytree': 0.9404153257116054, 'min_child_weight': 9, 'gamma': 1.289716234429856, 'reg_lambda': 0.002014737033457251}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:39,633] Trial 45 finished with value: 24.324205911577145 and parameters: {'n_estimators': 373, 'learning_rate': 0.01937081611771191, 'max_depth': 5, 'subsample': 0.7127272240173748, 'colsample_bytree': 0.7053840365617287, 'min_child_weight': 10, 'gamma': 1.5312474737309363, 'reg_lambda': 0.0019352126219428262}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:43,404] Trial 46 finished with value: 24.236808965655175 and parameters: {'n_estimators': 183, 'learning_rate': 0.029223233862723078, 'max_depth': 3, 'subsample': 0.6811038821439882, 'colsample_bytree': 0.83318367287028, 'min_child_weight': 10, 'gamma': 1.6514268459574741, 'reg_lambda': 0.004347550313312776}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:47,481] Trial 47 finished with value: 24.240657484982478 and parameters: {'n_estimators': 196, 'learning_rate': 0.03451159683074695, 'max_depth': 3, 'subsample': 0.6878052676331492, 'colsample_bytree': 0.8202163193911309, 'min_child_weight': 10, 'gamma': 1.7374137773948246, 'reg_lambda': 0.003847952589310489}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:50,452] Trial 48 finished with value: 24.25622409870545 and parameters: {'n_estimators': 190, 'learning_rate': 0.05454470133572017, 'max_depth': 3, 'subsample': 0.6824334040916881, 'colsample_bytree': 0.8228178773423253, 'min_child_weight': 9, 'gamma': 1.721983940271946, 'reg_lambda': 0.004113159122102754}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:53,872] Trial 49 finished with value: 24.220976840752957 and parameters: {'n_estimators': 262, 'learning_rate': 0.03325171768111861, 'max_depth': 3, 'subsample': 0.7362791451252171, 'colsample_bytree': 0.879904363413385, 'min_child_weight': 8, 'gamma': 1.8091415953899763, 'reg_lambda': 0.0033505460616853255}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:24:57,568] Trial 50 finished with value: 24.243754855725545 and parameters: {'n_estimators': 308, 'learning_rate': 0.026034566648885635, 'max_depth': 3, 'subsample': 0.7354762080575292, 'colsample_bytree': 0.8898676111885965, 'min_child_weight': 8, 'gamma': 2.106983326779229, 'reg_lambda': 0.0026584249227172016}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:00,385] Trial 51 finished with value: 24.227768369826233 and parameters: {'n_estimators': 231, 'learning_rate': 0.03274963406866785, 'max_depth': 3, 'subsample': 0.6432348570733311, 'colsample_bytree': 0.9232975340517708, 'min_child_weight': 9, 'gamma': 1.745782477337647, 'reg_lambda': 0.00616276621995584}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:02,915] Trial 52 finished with value: 24.27035830677467 and parameters: {'n_estimators': 247, 'learning_rate': 0.04687290945091846, 'max_depth': 3, 'subsample': 0.6480156074659332, 'colsample_bytree': 0.9249148352734168, 'min_child_weight': 9, 'gamma': 1.1233696954170762, 'reg_lambda': 0.008074790672379529}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:05,951] Trial 53 finished with value: 24.30686771364636 and parameters: {'n_estimators': 408, 'learning_rate': 0.028948295157198625, 'max_depth': 3, 'subsample': 0.5790710967058021, 'colsample_bytree': 0.9629396804871394, 'min_child_weight': 8, 'gamma': 0.840897167108255, 'reg_lambda': 0.0015299311838904883}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:10,345] Trial 54 finished with value: 24.25180529782396 and parameters: {'n_estimators': 247, 'learning_rate': 0.022118000097383718, 'max_depth': 4, 'subsample': 0.7682450651170047, 'colsample_bytree': 0.8513992034886474, 'min_child_weight': 9, 'gamma': 1.925176547547483, 'reg_lambda': 0.006704089951140166}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:15,028] Trial 55 finished with value: 24.28463617967583 and parameters: {'n_estimators': 356, 'learning_rate': 0.034865426432755024, 'max_depth': 3, 'subsample': 0.5766074075055433, 'colsample_bytree': 0.881925891892902, 'min_child_weight': 2, 'gamma': 2.3983292811052794, 'reg_lambda': 0.0026917848451511314}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:17,554] Trial 56 finished with value: 24.273214000416125 and parameters: {'n_estimators': 457, 'learning_rate': 0.05194407063636408, 'max_depth': 4, 'subsample': 0.739007882437963, 'colsample_bytree': 0.9255092066226229, 'min_child_weight': 8, 'gamma': 1.6164067499708004, 'reg_lambda': 0.0018288362068634876}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:21,703] Trial 57 finished with value: 24.23495614484928 and parameters: {'n_estimators': 167, 'learning_rate': 0.03975115527576742, 'max_depth': 3, 'subsample': 0.647902937820746, 'colsample_bytree': 0.9509677211754872, 'min_child_weight': 10, 'gamma': 2.089999219193845, 'reg_lambda': 0.0012882661048043125}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:26,374] Trial 58 finished with value: 24.685883133120196 and parameters: {'n_estimators': 100, 'learning_rate': 0.037090063144991005, 'max_depth': 10, 'subsample': 0.6544382910202634, 'colsample_bytree': 0.9794370634665812, 'min_child_weight': 9, 'gamma': 2.087823815679371, 'reg_lambda': 0.0010058042945831978}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:30,467] Trial 59 finished with value: 24.346192930122026 and parameters: {'n_estimators': 253, 'learning_rate': 0.023544625588754413, 'max_depth': 5, 'subsample': 0.6173614785994715, 'colsample_bytree': 0.9988551951184277, 'min_child_weight': 8, 'gamma': 1.1054496619193106, 'reg_lambda': 0.00285095704916232}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:32,502] Trial 60 finished with value: 24.282723228022256 and parameters: {'n_estimators': 339, 'learning_rate': 0.0604730611615137, 'max_depth': 4, 'subsample': 0.7882683485677712, 'colsample_bytree': 0.9468410876163226, 'min_child_weight': 9, 'gamma': 1.4140996974116211, 'reg_lambda': 0.0014202077888696128}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:34,984] Trial 61 finished with value: 24.222909431758527 and parameters: {'n_estimators': 198, 'learning_rate': 0.0433557433653529, 'max_depth': 3, 'subsample': 0.6938661296276324, 'colsample_bytree': 0.9050946362612057, 'min_child_weight': 10, 'gamma': 1.273973864224811, 'reg_lambda': 0.005070592684221559}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:36,284] Trial 62 finished with value: 24.26368106020784 and parameters: {'n_estimators': 144, 'learning_rate': 0.07065756766719161, 'max_depth': 3, 'subsample': 0.6634891000046313, 'colsample_bytree': 0.9053924001441587, 'min_child_weight': 10, 'gamma': 1.3342209268311258, 'reg_lambda': 0.00573800869217195}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:38,378] Trial 63 finished with value: 24.28458369417749 and parameters: {'n_estimators': 278, 'learning_rate': 0.04619258843504707, 'max_depth': 3, 'subsample': 0.6948002867668078, 'colsample_bytree': 0.9702775433999411, 'min_child_weight': 9, 'gamma': 1.8608289667475948, 'reg_lambda': 0.0015927993235878776}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:40,896] Trial 64 finished with value: 24.28191687285877 and parameters: {'n_estimators': 434, 'learning_rate': 0.040051665991062094, 'max_depth': 4, 'subsample': 0.7305314461231861, 'colsample_bytree': 0.9191486080563888, 'min_child_weight': 10, 'gamma': 0.8797130703926304, 'reg_lambda': 0.0023523598579005814}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:43,971] Trial 65 finished with value: 24.310655566179552 and parameters: {'n_estimators': 214, 'learning_rate': 0.019290141221431252, 'max_depth': 3, 'subsample': 0.7589069308112755, 'colsample_bytree': 0.9542135062607029, 'min_child_weight': 9, 'gamma': 1.312673011356105, 'reg_lambda': 0.003464135004293567}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:47,651] Trial 66 finished with value: 24.50730374285542 and parameters: {'n_estimators': 154, 'learning_rate': 0.015952643940232165, 'max_depth': 4, 'subsample': 0.631136286693809, 'colsample_bytree': 0.9064315262250671, 'min_child_weight': 10, 'gamma': 2.0770550199291744, 'reg_lambda': 0.009640016833067429}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:50,558] Trial 67 finished with value: 24.26317064965849 and parameters: {'n_estimators': 218, 'learning_rate': 0.031022304450568774, 'max_depth': 3, 'subsample': 0.5694990800556922, 'colsample_bytree': 0.8659820558948711, 'min_child_weight': 8, 'gamma': 0.2913950300029493, 'reg_lambda': 0.001208972045645741}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:25:55,129] Trial 68 finished with value: 24.302795732574307 and parameters: {'n_estimators': 328, 'learning_rate': 0.027312515307551105, 'max_depth': 4, 'subsample': 0.6686757447645512, 'colsample_bytree': 0.9441294727340097, 'min_child_weight': 10, 'gamma': 2.288174300309831, 'reg_lambda': 0.016109163380964003}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:00,246] Trial 69 finished with value: 24.233466936819678 and parameters: {'n_estimators': 275, 'learning_rate': 0.021256993946703582, 'max_depth': 3, 'subsample': 0.7035628574515641, 'colsample_bytree': 0.8844325785614352, 'min_child_weight': 9, 'gamma': 1.2094091176044575, 'reg_lambda': 0.00634913460560563}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:04,829] Trial 70 finished with value: 24.232939169535076 and parameters: {'n_estimators': 512, 'learning_rate': 0.021535383402871422, 'max_depth': 3, 'subsample': 0.700988764438887, 'colsample_bytree': 0.8489585659882514, 'min_child_weight': 8, 'gamma': 0.7566766454738799, 'reg_lambda': 0.005626112053400607}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:10,126] Trial 71 finished with value: 24.233182613633403 and parameters: {'n_estimators': 407, 'learning_rate': 0.020996876194030963, 'max_depth': 3, 'subsample': 0.7027547716758957, 'colsample_bytree': 0.8890268017234214, 'min_child_weight': 8, 'gamma': 0.5138467263860245, 'reg_lambda': 0.02367207597696153}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:15,782] Trial 72 finished with value: 24.22751635939972 and parameters: {'n_estimators': 492, 'learning_rate': 0.01669402469445529, 'max_depth': 3, 'subsample': 0.7261469850869428, 'colsample_bytree': 0.8597167954713524, 'min_child_weight': 8, 'gamma': 0.4531510448294709, 'reg_lambda': 0.011219249517459281}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:19,663] Trial 73 finished with value: 24.252365756813642 and parameters: {'n_estimators': 495, 'learning_rate': 0.0172066349911551, 'max_depth': 4, 'subsample': 0.7220490516292346, 'colsample_bytree': 0.8471775880382839, 'min_child_weight': 8, 'gamma': 0.7331595689555501, 'reg_lambda': 0.005314666952213167}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:24,954] Trial 74 finished with value: 24.233804983043516 and parameters: {'n_estimators': 504, 'learning_rate': 0.014427089213737835, 'max_depth': 3, 'subsample': 0.7707459124261535, 'colsample_bytree': 0.8600644255250248, 'min_child_weight': 7, 'gamma': 0.11435832911617894, 'reg_lambda': 0.013361312525023102}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:28,155] Trial 75 finished with value: 24.26877804038727 and parameters: {'n_estimators': 527, 'learning_rate': 0.024432381497132005, 'max_depth': 3, 'subsample': 0.8057315155636274, 'colsample_bytree': 0.807980099678411, 'min_child_weight': 8, 'gamma': 0.9642843284746923, 'reg_lambda': 0.0022821009258810446}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:30,659] Trial 76 finished with value: 24.214149249823002 and parameters: {'n_estimators': 615, 'learning_rate': 0.03347840686723579, 'max_depth': 4, 'subsample': 0.7558968408677335, 'colsample_bytree': 0.8756204849261183, 'min_child_weight': 9, 'gamma': 0.4689755843628485, 'reg_lambda': 0.0329388657558892}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:33,760] Trial 77 finished with value: 24.256270960207594 and parameters: {'n_estimators': 602, 'learning_rate': 0.026886013063319458, 'max_depth': 4, 'subsample': 0.7494976571748356, 'colsample_bytree': 0.766882836300573, 'min_child_weight': 9, 'gamma': 0.00941670877094597, 'reg_lambda': 0.037458598827831695}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:36,638] Trial 78 finished with value: 24.33840612697104 and parameters: {'n_estimators': 379, 'learning_rate': 0.032224447302581574, 'max_depth': 5, 'subsample': 0.749160308796459, 'colsample_bytree': 0.8736149715026692, 'min_child_weight': 9, 'gamma': 0.3670680829136135, 'reg_lambda': 0.008571988491430997}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:40,408] Trial 79 finished with value: 24.253605991140628 and parameters: {'n_estimators': 576, 'learning_rate': 0.03526299018249058, 'max_depth': 4, 'subsample': 0.8238243649883231, 'colsample_bytree': 0.786101770766696, 'min_child_weight': 9, 'gamma': 0.5756891478091777, 'reg_lambda': 0.018188097216021906}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:47,682] Trial 80 finished with value: 24.700345293725245 and parameters: {'n_estimators': 293, 'learning_rate': 0.018101657785547346, 'max_depth': 8, 'subsample': 0.7859823227629463, 'colsample_bytree': 0.8989547806925342, 'min_child_weight': 9, 'gamma': 1.0359090264578987, 'reg_lambda': 0.011140559296981574}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:50,841] Trial 81 finished with value: 24.242085948593367 and parameters: {'n_estimators': 437, 'learning_rate': 0.024286948432825677, 'max_depth': 3, 'subsample': 0.7273453818702367, 'colsample_bytree': 0.9159441191390696, 'min_child_weight': 8, 'gamma': 0.8557989128760486, 'reg_lambda': 0.003933316713158074}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:26:56,118] Trial 82 finished with value: 24.227541169906534 and parameters: {'n_estimators': 469, 'learning_rate': 0.01563330214585842, 'max_depth': 3, 'subsample': 0.7411605798176681, 'colsample_bytree': 0.8418995799329597, 'min_child_weight': 7, 'gamma': 0.4819153588184272, 'reg_lambda': 0.007073922112285584}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:00,727] Trial 83 finished with value: 24.277476421169162 and parameters: {'n_estimators': 481, 'learning_rate': 0.01631929967740625, 'max_depth': 4, 'subsample': 0.7761426042245557, 'colsample_bytree': 0.7389930100413867, 'min_child_weight': 7, 'gamma': 0.41163368146232215, 'reg_lambda': 0.030155634203794017}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:03,669] Trial 84 finished with value: 24.21709655565064 and parameters: {'n_estimators': 353, 'learning_rate': 0.04282387093210085, 'max_depth': 3, 'subsample': 0.73915933674143, 'colsample_bytree': 0.7241488519926131, 'min_child_weight': 6, 'gamma': 1.55510454501395, 'reg_lambda': 0.003389461680513523}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:07,266] Trial 85 finished with value: 24.22910980582126 and parameters: {'n_estimators': 352, 'learning_rate': 0.04310611948231713, 'max_depth': 3, 'subsample': 0.7578423148670717, 'colsample_bytree': 0.7182940564677883, 'min_child_weight': 6, 'gamma': 1.537998947486253, 'reg_lambda': 0.0033637991857747318}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:09,516] Trial 86 finished with value: 24.27185851936559 and parameters: {'n_estimators': 679, 'learning_rate': 0.04884642195926246, 'max_depth': 3, 'subsample': 0.7452866880779664, 'colsample_bytree': 0.6949982709449697, 'min_child_weight': 6, 'gamma': 0.2238182497874095, 'reg_lambda': 0.008022472260269285}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:14,140] Trial 87 finished with value: 24.2684291468834 and parameters: {'n_estimators': 398, 'learning_rate': 0.014341732593382334, 'max_depth': 3, 'subsample': 0.7219248657205796, 'colsample_bytree': 0.6402149505750901, 'min_child_weight': 7, 'gamma': 1.41827861683635, 'reg_lambda': 0.007337457227431897}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:19,180] Trial 88 finished with value: 25.191939453904237 and parameters: {'n_estimators': 447, 'learning_rate': 0.056704506565577205, 'max_depth': 12, 'subsample': 0.793565333470184, 'colsample_bytree': 0.8338052146302702, 'min_child_weight': 5, 'gamma': 1.2196039606427413, 'reg_lambda': 0.005118644490389312}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:22,475] Trial 89 finished with value: 24.32963237718734 and parameters: {'n_estimators': 422, 'learning_rate': 0.03731631795855502, 'max_depth': 3, 'subsample': 0.6899335703110572, 'colsample_bytree': 0.5010736908786461, 'min_child_weight': 6, 'gamma': 1.8164842488694875, 'reg_lambda': 0.010830286935006053}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:25,478] Trial 90 finished with value: 24.298261207724998 and parameters: {'n_estimators': 234, 'learning_rate': 0.03275318742538901, 'max_depth': 3, 'subsample': 0.8141067761278605, 'colsample_bytree': 0.9350898636649672, 'min_child_weight': 7, 'gamma': 0.5312325359520907, 'reg_lambda': 0.001764933679064038}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:28,208] Trial 91 finished with value: 24.23159113902819 and parameters: {'n_estimators': 376, 'learning_rate': 0.04150381720615348, 'max_depth': 3, 'subsample': 0.7634036083504486, 'colsample_bytree': 0.72533259089195, 'min_child_weight': 6, 'gamma': 1.5488206217917089, 'reg_lambda': 0.003503452824404886}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:29,832] Trial 92 finished with value: 24.307512657710586 and parameters: {'n_estimators': 352, 'learning_rate': 0.07238254506692803, 'max_depth': 3, 'subsample': 0.7568076560839934, 'colsample_bytree': 0.7119793321969755, 'min_child_weight': 6, 'gamma': 1.9410686361220044, 'reg_lambda': 0.0032367435771852686}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:32,104] Trial 93 finished with value: 24.235164616102132 and parameters: {'n_estimators': 267, 'learning_rate': 0.04386769135883988, 'max_depth': 3, 'subsample': 0.7398074678138467, 'colsample_bytree': 0.7458240996339616, 'min_child_weight': 5, 'gamma': 1.5898391211369587, 'reg_lambda': 0.004485615345571909}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:34,716] Trial 94 finished with value: 24.69922083522015 and parameters: {'n_estimators': 471, 'learning_rate': 0.050805894055537426, 'max_depth': 7, 'subsample': 0.6720913365675037, 'colsample_bytree': 0.6713137007832471, 'min_child_weight': 6, 'gamma': 1.716679974226661, 'reg_lambda': 0.002275995024661979}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:37,168] Trial 95 finished with value: 24.278432817826275 and parameters: {'n_estimators': 754, 'learning_rate': 0.043961072656534934, 'max_depth': 4, 'subsample': 0.7161613354893357, 'colsample_bytree': 0.6855971431113672, 'min_child_weight': 7, 'gamma': 1.4642880604019406, 'reg_lambda': 0.00322643953683326}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:42,141] Trial 96 finished with value: 24.377082003717764 and parameters: {'n_estimators': 318, 'learning_rate': 0.011124479598828452, 'max_depth': 3, 'subsample': 0.7752248204486234, 'colsample_bytree': 0.7043983525712327, 'min_child_weight': 7, 'gamma': 1.2125727902124759, 'reg_lambda': 0.013759077957122202}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:46,845] Trial 97 finished with value: 24.797740713082778 and parameters: {'n_estimators': 357, 'learning_rate': 0.02940967980192574, 'max_depth': 9, 'subsample': 0.7987877159595189, 'colsample_bytree': 0.6610109463856233, 'min_child_weight': 8, 'gamma': 0.6608414127020497, 'reg_lambda': 0.0027288268113364773}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:51,292] Trial 98 finished with value: 24.229946121126996 and parameters: {'n_estimators': 546, 'learning_rate': 0.019488831869230137, 'max_depth': 3, 'subsample': 0.7300211596273631, 'colsample_bytree': 0.8713331978025965, 'min_child_weight': 6, 'gamma': 1.6724137664002856, 'reg_lambda': 0.021689200590239176}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:53,925] Trial 99 finished with value: 24.327817361548068 and parameters: {'n_estimators': 295, 'learning_rate': 0.036629174948276486, 'max_depth': 4, 'subsample': 0.5942575606178631, 'colsample_bytree': 0.7223807091371899, 'min_child_weight': 5, 'gamma': 1.4053343569077341, 'reg_lambda': 0.006356179533904517}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:27:57,468] Trial 100 finished with value: 24.231211237792596 and parameters: {'n_estimators': 608, 'learning_rate': 0.02659433623732279, 'max_depth': 3, 'subsample': 0.7084737789410116, 'colsample_bytree': 0.8957871257502318, 'min_child_weight': 9, 'gamma': 1.8121963816674853, 'reg_lambda': 0.004571829647525274}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:02,475] Trial 101 finished with value: 24.235056376977074 and parameters: {'n_estimators': 588, 'learning_rate': 0.018488920200542044, 'max_depth': 3, 'subsample': 0.7326252763955861, 'colsample_bytree': 0.8678124755825173, 'min_child_weight': 6, 'gamma': 1.6709556852723026, 'reg_lambda': 0.015747676649937186}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:08,237] Trial 102 finished with value: 24.235653905539117 and parameters: {'n_estimators': 551, 'learning_rate': 0.01989592338540845, 'max_depth': 3, 'subsample': 0.7543394295194795, 'colsample_bytree': 0.8803453853396644, 'min_child_weight': 6, 'gamma': 1.6129758252611275, 'reg_lambda': 0.02189418522569902}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:12,548] Trial 103 finished with value: 24.246174416231643 and parameters: {'n_estimators': 533, 'learning_rate': 0.022901789597410373, 'max_depth': 3, 'subsample': 0.7446933533699712, 'colsample_bytree': 0.8570105264571711, 'min_child_weight': 6, 'gamma': 1.9336943985432264, 'reg_lambda': 0.043576370061933115}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:17,640] Trial 104 finished with value: 24.30421620012609 and parameters: {'n_estimators': 671, 'learning_rate': 0.013574649638705357, 'max_depth': 4, 'subsample': 0.7627052040309078, 'colsample_bytree': 0.9117815569582506, 'min_child_weight': 7, 'gamma': 0.44254355778164967, 'reg_lambda': 0.096544691458976}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:22,324] Trial 105 finished with value: 24.229335421219606 and parameters: {'n_estimators': 340, 'learning_rate': 0.01540608213413451, 'max_depth': 3, 'subsample': 0.7237285151990371, 'colsample_bytree': 0.8417750108135464, 'min_child_weight': 5, 'gamma': 2.6090483195463143, 'reg_lambda': 0.026158156206511202}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:26,850] Trial 106 finished with value: 24.27166218420204 and parameters: {'n_estimators': 338, 'learning_rate': 0.015422397344554622, 'max_depth': 4, 'subsample': 0.6927998698303995, 'colsample_bytree': 0.836728326277269, 'min_child_weight': 5, 'gamma': 2.9887293071942524, 'reg_lambda': 0.009679275982343824}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:28,375] Trial 107 finished with value: 24.2891691202043 and parameters: {'n_estimators': 207, 'learning_rate': 0.10937274772457892, 'max_depth': 3, 'subsample': 0.7214434309467953, 'colsample_bytree': 0.8124140022146065, 'min_child_weight': 5, 'gamma': 2.6062844252872996, 'reg_lambda': 0.002381849651129047}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:30,719] Trial 108 finished with value: 25.57931102170421 and parameters: {'n_estimators': 126, 'learning_rate': 0.012184818012427925, 'max_depth': 3, 'subsample': 0.6762449864066122, 'colsample_bytree': 0.7966554921654823, 'min_child_weight': 4, 'gamma': 2.41572536514184, 'reg_lambda': 0.0015701644661546943}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:37,832] Trial 109 finished with value: 24.63671219080915 and parameters: {'n_estimators': 392, 'learning_rate': 0.016694603124867306, 'max_depth': 10, 'subsample': 0.6571877928380717, 'colsample_bytree': 0.8269681884487524, 'min_child_weight': 10, 'gamma': 1.297675939286041, 'reg_lambda': 0.05170022834540982}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:44,080] Trial 110 finished with value: 24.861565094819905 and parameters: {'n_estimators': 419, 'learning_rate': 0.03842560400651197, 'max_depth': 11, 'subsample': 0.7844412359345808, 'colsample_bytree': 0.842217704553901, 'min_child_weight': 8, 'gamma': 2.8180755953476435, 'reg_lambda': 0.0010238841762013641}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:47,077] Trial 111 finished with value: 24.27403737158369 and parameters: {'n_estimators': 635, 'learning_rate': 0.03368688382530426, 'max_depth': 3, 'subsample': 0.7304519243028073, 'colsample_bytree': 0.8756105924811397, 'min_child_weight': 4, 'gamma': 2.2344054519970316, 'reg_lambda': 0.02842665592075083}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:49,860] Trial 112 finished with value: 24.272728888150336 and parameters: {'n_estimators': 237, 'learning_rate': 0.031641919025811524, 'max_depth': 3, 'subsample': 0.7100235620310656, 'colsample_bytree': 0.8983633522189673, 'min_child_weight': 6, 'gamma': 1.5313241904705182, 'reg_lambda': 0.02296069129959054}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:51,977] Trial 113 finished with value: 24.232593216012337 and parameters: {'n_estimators': 171, 'learning_rate': 0.04376970871756022, 'max_depth': 3, 'subsample': 0.7397390379896347, 'colsample_bytree': 0.7569494054444901, 'min_child_weight': 5, 'gamma': 1.1251169614988383, 'reg_lambda': 0.03636679454385929}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:55,137] Trial 114 finished with value: 24.217520680432262 and parameters: {'n_estimators': 271, 'learning_rate': 0.019793428222395527, 'max_depth': 3, 'subsample': 0.7662922631370562, 'colsample_bytree': 0.7771561041269837, 'min_child_weight': 6, 'gamma': 2.7491556851953467, 'reg_lambda': 0.009367101544675297}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:28:57,655] Trial 115 finished with value: 24.279760292645257 and parameters: {'n_estimators': 264, 'learning_rate': 0.02880276738275598, 'max_depth': 3, 'subsample': 0.5066586774964921, 'colsample_bytree': 0.7730351390811949, 'min_child_weight': 9, 'gamma': 3.197017392026999, 'reg_lambda': 0.006770996967018103}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:29:01,933] Trial 116 finished with value: 24.337031838732642 and parameters: {'n_estimators': 301, 'learning_rate': 0.010910420435875126, 'max_depth': 4, 'subsample': 0.7713173479951481, 'colsample_bytree': 0.7359331302138157, 'min_child_weight': 8, 'gamma': 2.76604078992429, 'reg_lambda': 0.009407152711428625}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:29:07,473] Trial 117 finished with value: 24.22654784825983 and parameters: {'n_estimators': 361, 'learning_rate': 0.017456508112064437, 'max_depth': 3, 'subsample': 0.546875772139456, 'colsample_bytree': 0.7441174570661411, 'min_child_weight': 9, 'gamma': 3.096619494869354, 'reg_lambda': 0.0058793339056691435}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:29:11,408] Trial 118 finished with value: 24.29682497279504 and parameters: {'n_estimators': 226, 'learning_rate': 0.01751095611390662, 'max_depth': 3, 'subsample': 0.7642155509700074, 'colsample_bytree': 0.7493610006773996, 'min_child_weight': 9, 'gamma': 3.2970469278518637, 'reg_lambda': 0.005614467304805712}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:29:17,114] Trial 119 finished with value: 24.262356613915344 and parameters: {'n_estimators': 369, 'learning_rate': 0.020921741129523035, 'max_depth': 4, 'subsample': 0.5991800873778617, 'colsample_bytree': 0.7155039484984244, 'min_child_weight': 9, 'gamma': 0.3075140704591706, 'reg_lambda': 0.003912171992183}. Best is trial 41 with value: 24.20458240140606.
# [I 2026-03-12 13:29:20,683] Trial 120 finished with value: 24.197560258229863 and parameters: {'n_estimators': 320, 'learning_rate': 0.0258602834015474, 'max_depth': 3, 'subsample': 0.7521121679345383, 'colsample_bytree': 0.7258504052347845, 'min_child_weight': 10, 'gamma': 0.9581187415542691, 'reg_lambda': 0.002042241468830314}. Best is trial 120 with value: 24.197560258229863.
# [I 2026-03-12 13:29:24,524] Trial 121 finished with value: 24.220740811685552 and parameters: {'n_estimators': 326, 'learning_rate': 0.027793074122782258, 'max_depth': 3, 'subsample': 0.5342709179185793, 'colsample_bytree': 0.7008877381866205, 'min_child_weight': 10, 'gamma': 3.0640113018724646, 'reg_lambda': 0.001990034516344348}. Best is trial 120 with value: 24.197560258229863.
# [I 2026-03-12 13:29:29,559] Trial 122 finished with value: 24.244559179651933 and parameters: {'n_estimators': 282, 'learning_rate': 0.025594648242897155, 'max_depth': 3, 'subsample': 0.5250800046570894, 'colsample_bytree': 0.697890625259165, 'min_child_weight': 10, 'gamma': 2.92261979265365, 'reg_lambda': 0.0013649104104196685}. Best is trial 120 with value: 24.197560258229863.
# [I 2026-03-12 13:29:34,547] Trial 123 finished with value: 24.249921380290626 and parameters: {'n_estimators': 313, 'learning_rate': 0.019138492263261257, 'max_depth': 3, 'subsample': 0.5700519091163532, 'colsample_bytree': 0.7342278233539541, 'min_child_weight': 10, 'gamma': 3.053045805619227, 'reg_lambda': 0.0022779066013184864}. Best is trial 120 with value: 24.197560258229863.
# [I 2026-03-12 13:29:38,733] Trial 124 finished with value: 24.210380513119656 and parameters: {'n_estimators': 327, 'learning_rate': 0.023565625807017945, 'max_depth': 3, 'subsample': 0.6236827636479259, 'colsample_bytree': 0.6848956892729992, 'min_child_weight': 10, 'gamma': 3.610789288037859, 'reg_lambda': 0.0018961455757903819}. Best is trial 120 with value: 24.197560258229863.
# [I 2026-03-12 13:29:42,707] Trial 125 finished with value: 24.244676267255596 and parameters: {'n_estimators': 325, 'learning_rate': 0.02303938375684402, 'max_depth': 3, 'subsample': 0.5400938759547573, 'colsample_bytree': 0.6855213220384001, 'min_child_weight': 10, 'gamma': 3.580792207554701, 'reg_lambda': 0.0018391508431076624}. Best is trial 120 with value: 24.197560258229863.
# [I 2026-03-12 13:29:46,196] Trial 126 finished with value: 24.26244536630787 and parameters: {'n_estimators': 402, 'learning_rate': 0.02832639397204193, 'max_depth': 3, 'subsample': 0.5539667692115557, 'colsample_bytree': 0.7033322884541223, 'min_child_weight': 10, 'gamma': 3.7905959042365187, 'reg_lambda': 0.0020163786965830444}. Best is trial 120 with value: 24.197560258229863.
# ...
# [I 2026-03-12 13:32:01,273] Trial 159 finished with value: 24.199168595771372 and parameters: {'n_estimators': 410, 'learning_rate': 0.030959876714131262, 'max_depth': 3, 'subsample': 0.8006596901642562, 'colsample_bytree': 0.7406705409737386, 'min_child_weight': 10, 'gamma': 2.186047457133715, 'reg_lambda': 0.011437617078757461}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:05,212] Trial 160 finished with value: 24.24927651396991 and parameters: {'n_estimators': 387, 'learning_rate': 0.03297627802207224, 'max_depth': 3, 'subsample': 0.8298701942694133, 'colsample_bytree': 0.724610323298116, 'min_child_weight': 10, 'gamma': 2.1444172289737247, 'reg_lambda': 0.017005497384887273}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:09,633] Trial 161 finished with value: 24.199629125231784 and parameters: {'n_estimators': 409, 'learning_rate': 0.02956215066247197, 'max_depth': 3, 'subsample': 0.801353983868313, 'colsample_bytree': 0.7454203318538957, 'min_child_weight': 10, 'gamma': 2.39251981704584, 'reg_lambda': 0.012371257459474936}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:13,819] Trial 162 finished with value: 24.198293114443853 and parameters: {'n_estimators': 466, 'learning_rate': 0.026758135205264436, 'max_depth': 3, 'subsample': 0.7986170217588598, 'colsample_bytree': 0.7402388719946916, 'min_child_weight': 10, 'gamma': 2.302528904058421, 'reg_lambda': 0.010308773644077212}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:17,124] Trial 163 finished with value: 24.218227110582195 and parameters: {'n_estimators': 464, 'learning_rate': 0.03155711110672665, 'max_depth': 3, 'subsample': 0.7744723183391209, 'colsample_bytree': 0.7304203282098847, 'min_child_weight': 10, 'gamma': 2.3142967890260393, 'reg_lambda': 0.00945559704359537}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:20,331] Trial 164 finished with value: 24.198021418143284 and parameters: {'n_estimators': 527, 'learning_rate': 0.027863671149250965, 'max_depth': 3, 'subsample': 0.7694625423130842, 'colsample_bytree': 0.7766975599802696, 'min_child_weight': 10, 'gamma': 2.3749512414353906, 'reg_lambda': 0.009980772738464379}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:23,458] Trial 165 finished with value: 24.23265199641276 and parameters: {'n_estimators': 524, 'learning_rate': 0.036153651765333215, 'max_depth': 3, 'subsample': 0.767770389143393, 'colsample_bytree': 0.7687516526574374, 'min_child_weight': 10, 'gamma': 2.3434746727640414, 'reg_lambda': 0.010585449710742515}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:26,181] Trial 166 finished with value: 24.243656092464832 and parameters: {'n_estimators': 499, 'learning_rate': 0.031201370522491414, 'max_depth': 3, 'subsample': 0.7892682707887818, 'colsample_bytree': 0.7781386532419898, 'min_child_weight': 10, 'gamma': 2.2547993571371934, 'reg_lambda': 0.00981234176616472}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:29,761] Trial 167 finished with value: 24.219615044550853 and parameters: {'n_estimators': 466, 'learning_rate': 0.0258169695725333, 'max_depth': 3, 'subsample': 0.7811706430010533, 'colsample_bytree': 0.7916514027177146, 'min_child_weight': 10, 'gamma': 2.188031089442774, 'reg_lambda': 0.012102758811807775}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:33,296] Trial 168 finished with value: 24.28282061402046 and parameters: {'n_estimators': 466, 'learning_rate': 0.02917740878109688, 'max_depth': 4, 'subsample': 0.7955738987651786, 'colsample_bytree': 0.7410943999037084, 'min_child_weight': 10, 'gamma': 2.419916853443879, 'reg_lambda': 0.008728602944215189}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:37,393] Trial 169 finished with value: 24.19941776581193 and parameters: {'n_estimators': 521, 'learning_rate': 0.02692111535058127, 'max_depth': 3, 'subsample': 0.7734292693398825, 'colsample_bytree': 0.7300038073756027, 'min_child_weight': 10, 'gamma': 1.998595842776687, 'reg_lambda': 0.012038809959113007}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:41,208] Trial 170 finished with value: 24.218398371010533 and parameters: {'n_estimators': 518, 'learning_rate': 0.02620622356732773, 'max_depth': 3, 'subsample': 0.8186134331008954, 'colsample_bytree': 0.7534030646811204, 'min_child_weight': 10, 'gamma': 2.0452658577947167, 'reg_lambda': 0.012679102804252364}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:45,840] Trial 171 finished with value: 24.195249058472722 and parameters: {'n_estimators': 573, 'learning_rate': 0.02791314246161409, 'max_depth': 3, 'subsample': 0.7714041436904304, 'colsample_bytree': 0.7282336452063081, 'min_child_weight': 10, 'gamma': 2.2919262825527715, 'reg_lambda': 0.018392419307890318}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:50,375] Trial 172 finished with value: 24.198505487592215 and parameters: {'n_estimators': 563, 'learning_rate': 0.0283557687990742, 'max_depth': 3, 'subsample': 0.764448317303827, 'colsample_bytree': 0.7162258623509205, 'min_child_weight': 10, 'gamma': 2.485874974215843, 'reg_lambda': 0.019002869435296558}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:53,873] Trial 173 finished with value: 24.19820319459005 and parameters: {'n_estimators': 557, 'learning_rate': 0.028711942336919077, 'max_depth': 3, 'subsample': 0.7591855088027698, 'colsample_bytree': 0.7154670113677085, 'min_child_weight': 10, 'gamma': 2.466868610252477, 'reg_lambda': 0.01687201076713225}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:32:57,460] Trial 174 finished with value: 24.202408976268952 and parameters: {'n_estimators': 542, 'learning_rate': 0.028639180506961806, 'max_depth': 3, 'subsample': 0.762906528072046, 'colsample_bytree': 0.7141251810190715, 'min_child_weight': 10, 'gamma': 2.4868942407993373, 'reg_lambda': 0.01819471162734767}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:33:00,625] Trial 175 finished with value: 24.197241275941156 and parameters: {'n_estimators': 570, 'learning_rate': 0.028567460674858356, 'max_depth': 3, 'subsample': 0.7592527431114944, 'colsample_bytree': 0.7122858422577634, 'min_child_weight': 10, 'gamma': 2.4413389434174784, 'reg_lambda': 0.019144506346607738}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:33:05,378] Trial 176 finished with value: 24.209005098318304 and parameters: {'n_estimators': 566, 'learning_rate': 0.02807813614025448, 'max_depth': 3, 'subsample': 0.7613506748402018, 'colsample_bytree': 0.7421439358044458, 'min_child_weight': 10, 'gamma': 2.361010055168498, 'reg_lambda': 0.019861670475099784}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:33:08,712] Trial 177 finished with value: 24.19536194701619 and parameters: {'n_estimators': 575, 'learning_rate': 0.02943618738558552, 'max_depth': 3, 'subsample': 0.7611956173353687, 'colsample_bytree': 0.7448220497473754, 'min_child_weight': 10, 'gamma': 2.209567069387403, 'reg_lambda': 0.018046459452813766}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:33:12,061] Trial 178 finished with value: 24.186404260846345 and parameters: {'n_estimators': 577, 'learning_rate': 0.028534633204666815, 'max_depth': 3, 'subsample': 0.761222321092823, 'colsample_bytree': 0.7404882467354392, 'min_child_weight': 10, 'gamma': 2.231508489136638, 'reg_lambda': 0.020340949945794554}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:33:15,044] Trial 179 finished with value: 24.207828613931838 and parameters: {'n_estimators': 579, 'learning_rate': 0.027273057848766054, 'max_depth': 3, 'subsample': 0.7630343593526188, 'colsample_bytree': 0.7617919844039592, 'min_child_weight': 10, 'gamma': 2.183879438340228, 'reg_lambda': 0.020310228508800415}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:33:19,601] Trial 180 finished with value: 24.672427410844502 and parameters: {'n_estimators': 565, 'learning_rate': 0.02873332914084937, 'max_depth': 9, 'subsample': 0.7615064467532096, 'colsample_bytree': 0.7529799322711144, 'min_child_weight': 10, 'gamma': 2.2322725735644244, 'reg_lambda': 0.019222245399646173}. Best is trial 146 with value: 24.184142395494746.
# [I 2026-03-12 13:33:22,539] Trial 181 finished with value: 24.180224790033495 and parameters: {'n_estimators': 589, 'learning_rate': 0.027575367379220953, 'max_depth': 3, 'subsample': 0.7726537404345527, 'colsample_bytree': 0.7290896702603269, 'min_child_weight': 10, 'gamma': 2.002042882257359, 'reg_lambda': 0.02559880835504206}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:26,568] Trial 182 finished with value: 24.196539205546795 and parameters: {'n_estimators': 575, 'learning_rate': 0.02724708478573095, 'max_depth': 3, 'subsample': 0.771092824819945, 'colsample_bytree': 0.7641982484355067, 'min_child_weight': 10, 'gamma': 2.159249258771854, 'reg_lambda': 0.02573734399883199}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:30,220] Trial 183 finished with value: 24.216083173496905 and parameters: {'n_estimators': 588, 'learning_rate': 0.029153642065305994, 'max_depth': 3, 'subsample': 0.7758779839503975, 'colsample_bytree': 0.764863082082551, 'min_child_weight': 10, 'gamma': 2.0133007417978055, 'reg_lambda': 0.02475431501427052}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:33,373] Trial 184 finished with value: 24.208684639413693 and parameters: {'n_estimators': 543, 'learning_rate': 0.031117933712950005, 'max_depth': 3, 'subsample': 0.7736124120407577, 'colsample_bytree': 0.7320186486305926, 'min_child_weight': 10, 'gamma': 2.1512335770356694, 'reg_lambda': 0.03065233122075593}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:37,662] Trial 185 finished with value: 24.19921487076176 and parameters: {'n_estimators': 629, 'learning_rate': 0.02657630652369185, 'max_depth': 3, 'subsample': 0.7553360973478647, 'colsample_bytree': 0.7482740643584392, 'min_child_weight': 10, 'gamma': 2.1427406897548837, 'reg_lambda': 0.025131326071914765}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:41,740] Trial 186 finished with value: 24.20405585066562 and parameters: {'n_estimators': 615, 'learning_rate': 0.03459439315166362, 'max_depth': 3, 'subsample': 0.7876282330772276, 'colsample_bytree': 0.7266054210008074, 'min_child_weight': 10, 'gamma': 2.267189075948017, 'reg_lambda': 0.025377335086049384}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:48,496] Trial 187 finished with value: 24.253266617057808 and parameters: {'n_estimators': 632, 'learning_rate': 0.03424219094817185, 'max_depth': 3, 'subsample': 0.7868945111269193, 'colsample_bytree': 0.7280174052175581, 'min_child_weight': 10, 'gamma': 2.28877604108877, 'reg_lambda': 0.023888398979526396}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:51,345] Trial 188 finished with value: 24.21055566232634 and parameters: {'n_estimators': 611, 'learning_rate': 0.030451056151440517, 'max_depth': 3, 'subsample': 0.7566403678307821, 'colsample_bytree': 0.7468379248456438, 'min_child_weight': 10, 'gamma': 2.033173581344687, 'reg_lambda': 0.036051212992616224}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:33:57,200] Trial 189 finished with value: 24.182225980004237 and parameters: {'n_estimators': 596, 'learning_rate': 0.026885593054021637, 'max_depth': 3, 'subsample': 0.7839223502204695, 'colsample_bytree': 0.7355011142551927, 'min_child_weight': 10, 'gamma': 2.4488123114203004, 'reg_lambda': 0.028704993829899845}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:34:06,840] Trial 190 finished with value: 24.18907163918485 and parameters: {'n_estimators': 593, 'learning_rate': 0.026714648139423, 'max_depth': 3, 'subsample': 0.7723569722901495, 'colsample_bytree': 0.737108847991096, 'min_child_weight': 10, 'gamma': 2.499451614128924, 'reg_lambda': 0.01775911110128017}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:34:16,103] Trial 191 finished with value: 24.195981048869076 and parameters: {'n_estimators': 586, 'learning_rate': 0.026328843761631332, 'max_depth': 3, 'subsample': 0.7783433432461109, 'colsample_bytree': 0.7356999257549475, 'min_child_weight': 10, 'gamma': 2.500246371253287, 'reg_lambda': 0.018135383521525734}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:34:24,620] Trial 192 finished with value: 24.20655064346752 and parameters: {'n_estimators': 596, 'learning_rate': 0.026703949844240786, 'max_depth': 3, 'subsample': 0.7735883730184961, 'colsample_bytree': 0.7387023831742795, 'min_child_weight': 10, 'gamma': 2.4401497592140617, 'reg_lambda': 0.02956601381312868}. Best is trial 181 with value: 24.180224790033495.
# [I 2026-03-12 13:34:32,371] Trial 193 finished with value: 24.179204666037528 and parameters: {'n_estimators': 563, 'learning_rate': 0.026614979221655455, 'max_depth': 3, 'subsample': 0.7800446224610866, 'colsample_bytree': 0.7507883565561777, 'min_child_weight': 10, 'gamma': 2.112604571901431, 'reg_lambda': 0.01953151968340612}. Best is trial 193 with value: 24.179204666037528.
# [I 2026-03-12 13:34:40,390] Trial 194 finished with value: 24.189551242509598 and parameters: {'n_estimators': 675, 'learning_rate': 0.02660970220501582, 'max_depth': 3, 'subsample': 0.7833441677907289, 'colsample_bytree': 0.7580323908427454, 'min_child_weight': 10, 'gamma': 2.101634465477106, 'reg_lambda': 0.01691508029483743}. Best is trial 193 with value: 24.179204666037528.
# [I 2026-03-12 13:34:49,292] Trial 195 finished with value: 24.2059362907608 and parameters: {'n_estimators': 655, 'learning_rate': 0.025758185308592682, 'max_depth': 3, 'subsample': 0.7539971309431484, 'colsample_bytree': 0.7536077434597509, 'min_child_weight': 10, 'gamma': 2.168612358266576, 'reg_lambda': 0.01831205240322141}. Best is trial 193 with value: 24.179204666037528.
# [I 2026-03-12 13:34:56,528] Trial 196 finished with value: 24.174009428052635 and parameters: {'n_estimators': 570, 'learning_rate': 0.026744671442215574, 'max_depth': 3, 'subsample': 0.7840648986336265, 'colsample_bytree': 0.7638671514450427, 'min_child_weight': 10, 'gamma': 1.9067605737313111, 'reg_lambda': 0.039829431758007725}. Best is trial 196 with value: 24.174009428052635.
# [I 2026-03-12 13:34:59,760] Trial 197 finished with value: 24.24315407145526 and parameters: {'n_estimators': 584, 'learning_rate': 0.03217069612073231, 'max_depth': 3, 'subsample': 0.7896808793473614, 'colsample_bytree': 0.7749539215670965, 'min_child_weight': 10, 'gamma': 1.9288017331142089, 'reg_lambda': 0.03912827368822178}. Best is trial 196 with value: 24.174009428052635.
# [I 2026-03-12 13:35:06,396] Trial 198 finished with value: 24.218580983144715 and parameters: {'n_estimators': 566, 'learning_rate': 0.02813324239827965, 'max_depth': 3, 'subsample': 0.781563202427219, 'colsample_bytree': 0.7631251330870386, 'min_child_weight': 10, 'gamma': 2.4907413588675995, 'reg_lambda': 0.021386391412842386}. Best is trial 196 with value: 24.174009428052635.
# [I 2026-03-12 13:35:15,547] Trial 199 finished with value: 24.218976563510903 and parameters: {'n_estimators': 682, 'learning_rate': 0.025209526989860176, 'max_depth': 3, 'subsample': 0.7693085961403896, 'colsample_bytree': 0.7819927581051886, 'min_child_weight': 10, 'gamma': 2.3238878492832287, 'reg_lambda': 0.017530219889739976}. Best is trial 196 with value: 24.174009428052635.
# Best trial parameters: {'n_estimators': 570, 'learning_rate': 0.026744671442215574, 'max_depth': 3, 'subsample': 0.7840648986336265, 'colsample_bytree': 0.7638671514450427, 'min_child_weight': 10, 'gamma': 1.9067605737313111, 'reg_lambda': 0.039829431758007725}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# Get the exact number of trees where it peaked
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7638671514450427, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=1.9067605737313111, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.026744671442215574,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=278, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# saving best model
joblib.dump(best_model, model_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source\\SavedResults\\Results_IE_NOXasNO2\\xgboost_model_IE_NOXasNO2.pkl']

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 20.6979
# MAE:  12.0129
# R2:   0.6315

# %%
# For Comparrison a naive non ML just guessing that tomorrow's pollutant will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 20.6979
# Naive Baseline RMSE: 24.6250

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title(f"SHAP Feature Importance: What drives {POLLUTANT} Pollution?")
plt.tight_layout()
plt.savefig(output_dir / f"{RUN_ID}_SHAP_Feature_importance.png", bbox_inches='tight')
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.title(f"Feature Importance of {POLLUTANT}")
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
plt.savefig(output_dir / f"{RUN_ID}_Feature_Importance.png", bbox_inches='tight')

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")


# folder for these prediction plots
pred_plot_dir = output_dir / "Predict_vs_Actual_Plots"
pred_plot_dir.mkdir(parents=True, exist_ok=True)

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

station_metrics_list = [] 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])

    station_metrics_list.append({ # add evalutation to list
        'Station': station,
        'RMSE': round(st_rmse, 3),
        'MAE': round(st_mae, 3),
        'R2': round(st_r2, 3)
    })
    
    print(f"Samplingpoint {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label=f'Actual {POLLUTANT}', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label=f'Predicted {POLLUTANT}', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted {POLLUTANT}\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel(f'{POLLUTANT} ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    clean_station_name = str(station).replace(".", "_").replace("/", "_")
    file_name = f"{COUNTRY_CODE}_{POLLUTANT}_{clean_station_name}_predict.png"
    plt.savefig(pred_plot_dir / file_name, dpi=150)

    plt.show()
    plt.close()


# list to df to csv
metrics_df = pd.DataFrame(station_metrics_list)
csv_filename = output_dir / f"{COUNTRY_CODE}_{POLLUTANT}_Every_Station_Metrics.csv"
metrics_df.to_csv(csv_filename, index=False)
# Out:
# RMSE: 20.6979
# MAE:  12.0129
# R2:   0.6315
# Samplingpoint IE/SPO.IE.IE001APSample2_9 -> RMSE: 20.79 | MAE: 13.61 | R2: 0.35
# Samplingpoint IE/SPO.IE.IE0028ASample1_9 -> RMSE: 13.75 | MAE: 9.10 | R2: 0.34
# Samplingpoint IE/SPO.IE.IE0111ASample1_9 -> RMSE: 3.07 | MAE: 2.17 | R2: 0.17
# Samplingpoint IE/SPO.IE.IE0140ASample1_9 -> RMSE: 10.12 | MAE: 6.51 | R2: 0.17
# Samplingpoint IE/SPO.IE.IE0030DSample1_9 -> RMSE: 30.22 | MAE: 20.04 | R2: 0.26
# Samplingpoint IE/SPO.IE.IE007CPSample2_9 -> RMSE: 10.50 | MAE: 6.06 | R2: 0.31
# Samplingpoint IE/SPO.IE.IE005APSample2_9 -> RMSE: 44.84 | MAE: 32.16 | R2: 0.26
# Samplingpoint IE/SPO.IE.IE0131ASample1_9 -> RMSE: 35.53 | MAE: 26.05 | R2: 0.33
# Samplingpoint IE/SPO.IE.IE0147ASample1_9 -> RMSE: 6.55 | MAE: 3.72 | R2: 0.28
# Samplingpoint IE/SPO.IE.IE006APSample1_9 -> RMSE: 36.33 | MAE: 25.74 | R2: 0.42
# Samplingpoint IE/SPO.IE.IE0118ASample1_9 -> RMSE: 9.57 | MAE: 4.58 | R2: 0.28
# Samplingpoint IE/SPO.IE.IE012CKSample2_9 -> RMSE: 11.71 | MAE: 8.15 | R2: 0.41
# Samplingpoint IE/SPO.IE.IE013CKSample2_9 -> RMSE: 32.10 | MAE: 22.85 | R2: 0.37
# Samplingpoint IE/SPO.IE.IE001CMSample1_9 -> RMSE: 8.48 | MAE: 5.01 | R2: 0.38
# Samplingpoint IE/SPO.IE.IE005CPSample2_9 -> RMSE: 10.34 | MAE: 5.46 | R2: 0.31
# Samplingpoint IE/SPO.IE.IE004APSample1_9 -> RMSE: 19.18 | MAE: 14.03 | R2: 0.34
# Samplingpoint IE/SPO.IE.IE010LKSample2_9 -> RMSE: 13.92 | MAE: 9.96 | R2: 0.31
# Samplingpoint IE/SPO.IE.IE001BPSample1_9 -> RMSE: 25.41 | MAE: 15.50 | R2: 0.33
# Samplingpoint IE/SPO.IE.IE028DSample2_9 -> RMSE: 25.33 | MAE: 18.54 | R2: 0.40
# Samplingpoint IE/SPO.IE.IE002CMSample1_9 -> RMSE: 9.75 | MAE: 6.31 | R2: 0.30
# Samplingpoint IE/SPO.IE.IE007GYSample2_9 -> RMSE: 14.47 | MAE: 9.80 | R2: 0.33
# Samplingpoint IE/SPO.IE.IE001LMSample1_9 -> RMSE: 14.94 | MAE: 9.55 | R2: 0.35
# Samplingpoint IE/SPO.IE.IE0132ASample1_9 -> RMSE: 13.20 | MAE: 8.50 | R2: 0.33
# Samplingpoint IE/SPO.IE.IE0036ASample1_9 -> RMSE: 16.87 | MAE: 10.13 | R2: 0.40
# Samplingpoint IE/SPO.IE.IE009GYSample1_9 -> RMSE: 23.29 | MAE: 16.55 | R2: 0.19
# Samplingpoint IE/SPO.IE.IE027DSample2_9 -> RMSE: 13.19 | MAE: 9.25 | R2: 0.22
# Samplingpoint IE/SPO.IE.IE0098ASample1_9 -> RMSE: 21.48 | MAE: 13.41 | R2: 0.45
# Samplingpoint IE/SPO.IE.IE008CPSample1_9 -> RMSE: 31.19 | MAE: 21.78 | R2: 0.36
# Samplingpoint IE/SPO.IE.IE0136ASample1_9 -> RMSE: 15.04 | MAE: 10.90 | R2: 0.28
# Samplingpoint IE/SPO.IE.IE004BPSample2_9 -> RMSE: 8.04 | MAE: 4.51 | R2: 0.21
# Samplingpoint IE/SPO.IE.IE0090ASample1_9 -> RMSE: 2.72 | MAE: 2.02 | R2: -3.54
# Samplingpoint IE/SPO.IE.IE002BPSample1_9 -> RMSE: 8.48 | MAE: 6.33 | R2: -0.02
# Samplingpoint IE/SPO.IE.IE001WDSample1_9 -> RMSE: 15.44 | MAE: 9.69 | R2: 0.33
# Samplingpoint IE/SPO.IE.IE005OYSample2_9 -> RMSE: 7.41 | MAE: 4.75 | R2: 0.38
# Samplingpoint IE/SPO.IE.IE009DPSample1_9 -> RMSE: 15.95 | MAE: 11.34 | R2: 0.35
# Samplingpoint IE/SPO.IE.IE002SOSample1_9 -> RMSE: 38.21 | MAE: 25.39 | R2: 0.25
# Samplingpoint IE/SPO.IE.IE0029DSample1_9 -> RMSE: 42.09 | MAE: 31.39 | R2: 0.11
