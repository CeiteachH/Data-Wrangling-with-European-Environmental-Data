# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os
import joblib
from pathlib import Path

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
POLLUTANT = "PM2.5"

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
RESULTS_SAVE_FOLDER = os.getenv("RESULTS_SAVE_FOLDER")

# %%
# reading in data
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
# saving results
RUN_ID = f"{COUNTRY_CODE}_{POLLUTANT}"

output_dir = Path(RESULTS_SAVE_FOLDER) / f"Results_{RUN_ID}"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# saving model
model_filename = output_dir / f"xgboost_model_{COUNTRY_CODE}_{POLLUTANT}.pkl"

# %%
def log_stat(name, value): # save statistics as a test file
    with open(output_dir / "data_processing_log.txt", "a") as f:
        f.write(f"{name}: {value}\n")

with open(output_dir / "data_processing_log.txt", "w") as f: # clear log if it exists to start fresh
    f.write(f"Processing Log for {RUN_ID}\n")

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#               Samplingpoint      Start  Value
# 0  AL/SPO-AL0201A_06001_100 2013-01-01    NaN
# 1  AL/SPO-AL0201A_06001_100 2013-01-02  19.00
# 2  AL/SPO-AL0201A_06001_100 2013-01-03  26.73
# 3  AL/SPO-AL0201A_06001_100 2013-01-04  13.19
# 4  AL/SPO-AL0201A_06001_100 2013-01-05  22.62
# 5  AL/SPO-AL0201A_06001_100 2013-01-06  52.44
# 6  AL/SPO-AL0201A_06001_100 2013-01-07  35.92
# 7  AL/SPO-AL0201A_06001_100 2013-01-08   5.37
# 8  AL/SPO-AL0201A_06001_100 2013-01-09  28.36
# 9  AL/SPO-AL0201A_06001_100 2013-01-10  23.46

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (14052, 11)
#        Start             Samplingpoint  Value  DayOfWeek  Month  DayOfYear  \
# 0 2013-01-01  AL/SPO-AL0201A_06001_100    NaN          1      1          1
# 1 2013-01-02  AL/SPO-AL0201A_06001_100  19.00          2      1          2
# 2 2013-01-03  AL/SPO-AL0201A_06001_100  26.73          3      1          3
# 3 2013-01-04  AL/SPO-AL0201A_06001_100  13.19          4      1          4
# 4 2013-01-05  AL/SPO-AL0201A_06001_100  22.62          5      1          5
# 5 2013-01-06  AL/SPO-AL0201A_06001_100  52.44          6      1          6
# 6 2013-01-07  AL/SPO-AL0201A_06001_100  35.92          0      1          7
# 7 2013-01-08  AL/SPO-AL0201A_06001_100   5.37          1      1          8
# 8 2013-01-09  AL/SPO-AL0201A_06001_100  28.36          2      1          9
# 9 2013-01-10  AL/SPO-AL0201A_06001_100  23.46          3      1         10
#
#    IsWeekend  Lag_1  Lag_7  Rolling_Mean_7D  Target
# 0          0    NaN    NaN              NaN   19.00
# 1          0    NaN    NaN              NaN   26.73
# 2          0  19.00    NaN              NaN   13.19
# 3          0  26.73    NaN              NaN   22.62
# 4          1  13.19    NaN        20.385000   52.44
# 5          1  22.62    NaN        26.796000   35.92
# 6          0  52.44    NaN        28.316667    5.37
# 7          0  35.92    NaN        25.038571   28.36
# 8          0   5.37  19.00        26.375714   23.46
# 9          0  28.36  26.73        25.908571   94.56

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start             Samplingpoint  Value  DayOfWeek  Month  DayOfYear  \
# 0 2013-01-01  AL/SPO-AL0201A_06001_100    NaN          1      1          1
# 1 2013-01-02  AL/SPO-AL0201A_06001_100  19.00          2      1          2
# 2 2013-01-03  AL/SPO-AL0201A_06001_100  26.73          3      1          3
# 3 2013-01-04  AL/SPO-AL0201A_06001_100  13.19          4      1          4
# 4 2013-01-05  AL/SPO-AL0201A_06001_100  22.62          5      1          5
# 5 2013-01-06  AL/SPO-AL0201A_06001_100  52.44          6      1          6
# 6 2013-01-07  AL/SPO-AL0201A_06001_100  35.92          0      1          7
# 7 2013-01-08  AL/SPO-AL0201A_06001_100   5.37          1      1          8
# 8 2013-01-09  AL/SPO-AL0201A_06001_100  28.36          2      1          9
# 9 2013-01-10  AL/SPO-AL0201A_06001_100  23.46          3      1         10
#
#    IsWeekend  Lag_1  Lag_7  Rolling_Mean_7D  Target
# 0          0    NaN    NaN              NaN   19.00
# 1          0    NaN    NaN              NaN   26.73
# 2          0  19.00    NaN              NaN   13.19
# 3          0  26.73    NaN              NaN   22.62
# 4          1  13.19    NaN        20.385000   52.44
# 5          1  22.62    NaN        26.796000   35.92
# 6          0  52.44    NaN        28.316667    5.37
# 7          0  35.92    NaN        25.038571   28.36
# 8          0   5.37  19.00        26.375714   23.46
# 9          0  28.36  26.73        25.908571   94.56
# Start                0
# Samplingpoint        0
# Value              111
# DayOfWeek            0
# Month                0
# DayOfYear            0
# IsWeekend            0
# Lag_1              203
# Lag_7              521
# Rolling_Mean_7D    275
# Target               0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (4622, 9), Val shape: (6, 9), Test shape: (1802, 9)

# %%
# save features 
feature_names = list(X_train.columns)
features_filename = output_dir / f"xgboost_features_{COUNTRY_CODE}_{POLLUTANT}.pkl"
joblib.dump(feature_names, features_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_PM2.5\\xgboost_features_AL_PM2.5.pkl']

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 16:07:05,871] A new study created in memory with name: no-name-4bdf4b2a-a88e-4671-974a-2b55adf275d4
# [I 2026-03-12 16:07:09,745] Trial 0 finished with value: 13.305902145434155 and parameters: {'n_estimators': 351, 'learning_rate': 0.02116881090327045, 'max_depth': 5, 'subsample': 0.8234945788042178, 'colsample_bytree': 0.7734021593738742, 'min_child_weight': 6, 'gamma': 0.6700789976290894, 'reg_lambda': 0.09342385624710994}. Best is trial 0 with value: 13.305902145434155.
# [I 2026-03-12 16:07:12,607] Trial 1 finished with value: 13.181781343803625 and parameters: {'n_estimators': 533, 'learning_rate': 0.016997618607797554, 'max_depth': 5, 'subsample': 0.7768214196726709, 'colsample_bytree': 0.9404950494996429, 'min_child_weight': 5, 'gamma': 3.9330836141600285, 'reg_lambda': 0.6635328749258076}. Best is trial 1 with value: 13.181781343803625.
# [I 2026-03-12 16:07:13,853] Trial 2 finished with value: 13.454041033717434 and parameters: {'n_estimators': 255, 'learning_rate': 0.15513571443662535, 'max_depth': 9, 'subsample': 0.5687418718628316, 'colsample_bytree': 0.5645761950449504, 'min_child_weight': 5, 'gamma': 0.4949895394451287, 'reg_lambda': 7.089540506626054}. Best is trial 1 with value: 13.181781343803625.
# [I 2026-03-12 16:07:19,485] Trial 3 finished with value: 13.195160934904683 and parameters: {'n_estimators': 1101, 'learning_rate': 0.007820277219201451, 'max_depth': 11, 'subsample': 0.8370857298419163, 'colsample_bytree': 0.5280245583552934, 'min_child_weight': 10, 'gamma': 4.049554057363806, 'reg_lambda': 0.42649862388504606}. Best is trial 1 with value: 13.181781343803625.
# [I 2026-03-12 16:07:21,869] Trial 4 finished with value: 12.865889679072541 and parameters: {'n_estimators': 796, 'learning_rate': 0.0060157656810633856, 'max_depth': 3, 'subsample': 0.9567658377994646, 'colsample_bytree': 0.5678605840587528, 'min_child_weight': 3, 'gamma': 4.523859565318152, 'reg_lambda': 0.006232311988909958}. Best is trial 4 with value: 12.865889679072541.
# [I 2026-03-12 16:07:24,022] Trial 5 pruned.
# [I 2026-03-12 16:07:24,414] Trial 6 pruned.
# [I 2026-03-12 16:07:24,834] Trial 7 pruned.
# [I 2026-03-12 16:07:29,354] Trial 8 pruned.
# [I 2026-03-12 16:07:30,195] Trial 9 finished with value: 13.026781814806746 and parameters: {'n_estimators': 561, 'learning_rate': 0.03239709893122405, 'max_depth': 4, 'subsample': 0.89134038036028, 'colsample_bytree': 0.8411763467523632, 'min_child_weight': 6, 'gamma': 0.77326631788318, 'reg_lambda': 0.33565077349076977}. Best is trial 4 with value: 12.865889679072541.
# [I 2026-03-12 16:07:33,294] Trial 10 finished with value: 12.934441839318254 and parameters: {'n_estimators': 799, 'learning_rate': 0.008784818405854869, 'max_depth': 3, 'subsample': 0.9947147456217335, 'colsample_bytree': 0.6902970036500321, 'min_child_weight': 3, 'gamma': 4.997958631395929, 'reg_lambda': 0.0020518211207058677}. Best is trial 4 with value: 12.865889679072541.
# [I 2026-03-12 16:07:35,920] Trial 11 finished with value: 12.965659780477134 and parameters: {'n_estimators': 810, 'learning_rate': 0.009211380185564584, 'max_depth': 3, 'subsample': 0.9862444228203121, 'colsample_bytree': 0.6662205261982436, 'min_child_weight': 3, 'gamma': 4.821695965822682, 'reg_lambda': 0.001411115953814428}. Best is trial 4 with value: 12.865889679072541.
# [I 2026-03-12 16:07:40,436] Trial 12 pruned.
# [I 2026-03-12 16:07:41,911] Trial 13 finished with value: 12.955129899734997 and parameters: {'n_estimators': 824, 'learning_rate': 0.010022476495628827, 'max_depth': 3, 'subsample': 0.651791556732296, 'colsample_bytree': 0.6416792658191008, 'min_child_weight': 1, 'gamma': 1.819306123945747, 'reg_lambda': 0.009928738972365741}. Best is trial 4 with value: 12.865889679072541.
# [I 2026-03-12 16:07:42,834] Trial 14 pruned.
# [I 2026-03-12 16:07:44,845] Trial 15 finished with value: 12.825805945167684 and parameters: {'n_estimators': 722, 'learning_rate': 0.0107104055532052, 'max_depth': 3, 'subsample': 0.9110844123537665, 'colsample_bytree': 0.6069318861081459, 'min_child_weight': 4, 'gamma': 4.414103252180132, 'reg_lambda': 0.03935857911042928}. Best is trial 15 with value: 12.825805945167684.
# [I 2026-03-12 16:07:45,684] Trial 16 pruned.
# [I 2026-03-12 16:07:45,970] Trial 17 pruned.
# [I 2026-03-12 16:07:47,645] Trial 18 pruned.
# [I 2026-03-12 16:07:49,513] Trial 19 pruned.
# [I 2026-03-12 16:07:50,435] Trial 20 pruned.
# [I 2026-03-12 16:07:51,333] Trial 21 pruned.
# [I 2026-03-12 16:07:51,807] Trial 22 pruned.
# [I 2026-03-12 16:07:54,407] Trial 23 pruned.
# [I 2026-03-12 16:07:56,782] Trial 24 pruned.
# [I 2026-03-12 16:07:59,437] Trial 25 pruned.
# [I 2026-03-12 16:08:00,501] Trial 26 pruned.
# [I 2026-03-12 16:08:01,384] Trial 27 pruned.
# [I 2026-03-12 16:08:02,048] Trial 28 pruned.
# [I 2026-03-12 16:08:03,715] Trial 29 pruned.
# [I 2026-03-12 16:08:05,385] Trial 30 pruned.
# [I 2026-03-12 16:08:07,254] Trial 31 finished with value: 12.96510344504908 and parameters: {'n_estimators': 835, 'learning_rate': 0.009307457081178172, 'max_depth': 3, 'subsample': 0.6832253674454826, 'colsample_bytree': 0.6415920203712888, 'min_child_weight': 1, 'gamma': 1.1417538615715874, 'reg_lambda': 0.011155389184314522}. Best is trial 15 with value: 12.825805945167684.
# [I 2026-03-12 16:08:12,280] Trial 32 pruned.
# [I 2026-03-12 16:08:14,031] Trial 33 pruned.
# [I 2026-03-12 16:08:15,764] Trial 34 pruned.
# [I 2026-03-12 16:08:16,948] Trial 35 pruned.
# [I 2026-03-12 16:08:23,520] Trial 36 pruned.
# [I 2026-03-12 16:08:23,735] Trial 37 pruned.
# [I 2026-03-12 16:08:24,435] Trial 38 pruned.
# [I 2026-03-12 16:08:26,313] Trial 39 pruned.
# [I 2026-03-12 16:08:28,905] Trial 40 pruned.
# [I 2026-03-12 16:08:32,744] Trial 41 pruned.
# [I 2026-03-12 16:08:34,773] Trial 42 pruned.
# [I 2026-03-12 16:08:36,670] Trial 43 pruned.
# [I 2026-03-12 16:08:37,001] Trial 44 pruned.
# [I 2026-03-12 16:08:37,504] Trial 45 pruned.
# [I 2026-03-12 16:08:38,251] Trial 46 pruned.
# [I 2026-03-12 16:08:40,374] Trial 47 pruned.
# [I 2026-03-12 16:08:41,217] Trial 48 pruned.
# [I 2026-03-12 16:08:43,963] Trial 49 pruned.
# [I 2026-03-12 16:08:44,869] Trial 50 pruned.
# [I 2026-03-12 16:08:47,286] Trial 51 pruned.
# [I 2026-03-12 16:08:49,257] Trial 52 pruned.
# [I 2026-03-12 16:08:50,860] Trial 53 pruned.
# [I 2026-03-12 16:08:51,483] Trial 54 pruned.
# [I 2026-03-12 16:08:53,171] Trial 55 pruned.
# [I 2026-03-12 16:08:54,920] Trial 56 pruned.
# [I 2026-03-12 16:08:57,411] Trial 57 pruned.
# [I 2026-03-12 16:08:59,280] Trial 58 pruned.
# [I 2026-03-12 16:08:59,783] Trial 59 finished with value: 12.423394460929975 and parameters: {'n_estimators': 506, 'learning_rate': 0.13306784094760749, 'max_depth': 3, 'subsample': 0.6637440700615823, 'colsample_bytree': 0.7054179185059445, 'min_child_weight': 1, 'gamma': 4.596308746920205, 'reg_lambda': 0.020343105086808335}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:09:00,439] Trial 60 pruned.
# [I 2026-03-12 16:09:00,899] Trial 61 pruned.
# [I 2026-03-12 16:09:02,577] Trial 62 pruned.
# [I 2026-03-12 16:09:03,056] Trial 63 pruned.
# [I 2026-03-12 16:09:04,342] Trial 64 finished with value: 12.931667224926006 and parameters: {'n_estimators': 786, 'learning_rate': 0.0207190909667417, 'max_depth': 3, 'subsample': 0.9778506427639653, 'colsample_bytree': 0.6329479021609818, 'min_child_weight': 1, 'gamma': 4.54920781605765, 'reg_lambda': 0.04810762751201025}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:09:05,307] Trial 65 pruned.
# [I 2026-03-12 16:09:05,733] Trial 66 pruned.
# [I 2026-03-12 16:09:06,461] Trial 67 pruned.
# [I 2026-03-12 16:09:09,684] Trial 68 pruned.
# [I 2026-03-12 16:09:11,593] Trial 69 pruned.
# [I 2026-03-12 16:09:13,304] Trial 70 pruned.
# [I 2026-03-12 16:09:16,425] Trial 71 pruned.
# [I 2026-03-12 16:09:20,615] Trial 72 pruned.
# [I 2026-03-12 16:09:28,873] Trial 73 pruned.
# [I 2026-03-12 16:09:30,824] Trial 74 pruned.
# [I 2026-03-12 16:09:31,451] Trial 75 pruned.
# [I 2026-03-12 16:09:33,416] Trial 76 pruned.
# [I 2026-03-12 16:09:34,745] Trial 77 pruned.
# [I 2026-03-12 16:09:39,272] Trial 78 pruned.
# [I 2026-03-12 16:09:39,996] Trial 79 pruned.
# [I 2026-03-12 16:09:40,780] Trial 80 pruned.
# [I 2026-03-12 16:09:41,209] Trial 81 pruned.
# [I 2026-03-12 16:09:41,671] Trial 82 pruned.
# [I 2026-03-12 16:09:42,909] Trial 83 pruned.
# [I 2026-03-12 16:09:43,822] Trial 84 pruned.
# [I 2026-03-12 16:09:44,907] Trial 85 pruned.
# [I 2026-03-12 16:09:47,334] Trial 86 pruned.
# [I 2026-03-12 16:09:47,758] Trial 87 pruned.
# [I 2026-03-12 16:09:48,551] Trial 88 pruned.
# [I 2026-03-12 16:09:52,783] Trial 89 pruned.
# [I 2026-03-12 16:09:55,196] Trial 90 pruned.
# [I 2026-03-12 16:09:57,806] Trial 91 pruned.
# [I 2026-03-12 16:09:58,594] Trial 92 pruned.
# [I 2026-03-12 16:09:59,378] Trial 93 pruned.
# [I 2026-03-12 16:10:00,431] Trial 94 pruned.
# [I 2026-03-12 16:10:01,411] Trial 95 pruned.
# [I 2026-03-12 16:10:03,603] Trial 96 pruned.
# [I 2026-03-12 16:10:03,956] Trial 97 pruned.
# [I 2026-03-12 16:10:04,897] Trial 98 pruned.
# [I 2026-03-12 16:10:06,337] Trial 99 pruned.
# [I 2026-03-12 16:10:08,402] Trial 100 pruned.
# [I 2026-03-12 16:10:10,888] Trial 101 pruned.
# [I 2026-03-12 16:10:13,653] Trial 102 pruned.
# [I 2026-03-12 16:10:14,317] Trial 103 pruned.
# [I 2026-03-12 16:10:16,368] Trial 104 pruned.
# [I 2026-03-12 16:10:16,998] Trial 105 pruned.
# [I 2026-03-12 16:10:17,999] Trial 106 pruned.
# [I 2026-03-12 16:10:22,471] Trial 107 pruned.
# [I 2026-03-12 16:10:23,753] Trial 108 pruned.
# [I 2026-03-12 16:10:26,262] Trial 109 finished with value: 12.948618021556266 and parameters: {'n_estimators': 621, 'learning_rate': 0.006605171763432129, 'max_depth': 3, 'subsample': 0.9539379476278232, 'colsample_bytree': 0.6002316088646584, 'min_child_weight': 2, 'gamma': 4.559860506416122, 'reg_lambda': 0.010690787791041973}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:10:34,731] Trial 110 pruned.
# [I 2026-03-12 16:10:39,325] Trial 111 pruned.
# [I 2026-03-12 16:10:42,966] Trial 112 finished with value: 12.902885911732303 and parameters: {'n_estimators': 701, 'learning_rate': 0.006858058570351901, 'max_depth': 3, 'subsample': 0.9094396334061431, 'colsample_bytree': 0.611035405760407, 'min_child_weight': 2, 'gamma': 1.5879345435577337, 'reg_lambda': 0.016436367707692384}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:10:45,718] Trial 113 pruned.
# [I 2026-03-12 16:10:48,524] Trial 114 finished with value: 12.770428220930832 and parameters: {'n_estimators': 833, 'learning_rate': 0.012888295448017244, 'max_depth': 3, 'subsample': 0.9835020756110242, 'colsample_bytree': 0.6177345036923206, 'min_child_weight': 3, 'gamma': 1.6285327827068479, 'reg_lambda': 0.01675377617327154}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:10:48,936] Trial 115 pruned.
# [I 2026-03-12 16:10:50,274] Trial 116 pruned.
# [I 2026-03-12 16:10:54,582] Trial 117 finished with value: 12.920831819510694 and parameters: {'n_estimators': 859, 'learning_rate': 0.005695884849602108, 'max_depth': 3, 'subsample': 0.9623627198710297, 'colsample_bytree': 0.5622044457735627, 'min_child_weight': 3, 'gamma': 1.7067815726109294, 'reg_lambda': 0.008280646114999653}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:10:57,408] Trial 118 finished with value: 12.930030631628062 and parameters: {'n_estimators': 865, 'learning_rate': 0.00576910105923682, 'max_depth': 3, 'subsample': 0.9646923777747544, 'colsample_bytree': 0.5669758449691976, 'min_child_weight': 3, 'gamma': 1.5956785323951561, 'reg_lambda': 0.008682972923495798}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:10:59,920] Trial 119 pruned.
# [I 2026-03-12 16:11:02,386] Trial 120 finished with value: 12.92281260068812 and parameters: {'n_estimators': 904, 'learning_rate': 0.006126727915838874, 'max_depth': 3, 'subsample': 0.9675471195320141, 'colsample_bytree': 0.5807373865211451, 'min_child_weight': 3, 'gamma': 1.6027814512732144, 'reg_lambda': 0.012191340720443535}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:11:05,099] Trial 121 pruned.
# [I 2026-03-12 16:11:06,400] Trial 122 pruned.
# [I 2026-03-12 16:11:08,464] Trial 123 pruned.
# [I 2026-03-12 16:11:10,135] Trial 124 pruned.
# [I 2026-03-12 16:11:12,723] Trial 125 finished with value: 12.696576033892933 and parameters: {'n_estimators': 998, 'learning_rate': 0.0064519988352833586, 'max_depth': 3, 'subsample': 0.9800565028258437, 'colsample_bytree': 0.5941871750638198, 'min_child_weight': 1, 'gamma': 1.9026476810686412, 'reg_lambda': 0.011716518213646483}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:11:15,359] Trial 126 finished with value: 12.763958026769034 and parameters: {'n_estimators': 933, 'learning_rate': 0.006322419672819299, 'max_depth': 3, 'subsample': 0.9795539602192559, 'colsample_bytree': 0.5974532444362227, 'min_child_weight': 3, 'gamma': 1.6879323195521523, 'reg_lambda': 0.010432454180014395}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:11:17,602] Trial 127 pruned.
# [I 2026-03-12 16:11:19,442] Trial 128 pruned.
# [I 2026-03-12 16:11:22,733] Trial 129 finished with value: 12.842323614920083 and parameters: {'n_estimators': 926, 'learning_rate': 0.005570496374609955, 'max_depth': 3, 'subsample': 0.9773981344551412, 'colsample_bytree': 0.598772517750725, 'min_child_weight': 3, 'gamma': 2.097705474947798, 'reg_lambda': 0.012478189947414979}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:11:30,895] Trial 130 pruned.
# [I 2026-03-12 16:11:33,534] Trial 131 pruned.
# [I 2026-03-12 16:11:37,036] Trial 132 pruned.
# [I 2026-03-12 16:11:40,584] Trial 133 pruned.
# [I 2026-03-12 16:11:43,102] Trial 134 pruned.
# [I 2026-03-12 16:11:46,870] Trial 135 finished with value: 12.843636156009792 and parameters: {'n_estimators': 968, 'learning_rate': 0.006001413593472121, 'max_depth': 3, 'subsample': 0.9451902578022254, 'colsample_bytree': 0.6093906600742209, 'min_child_weight': 3, 'gamma': 1.2783236451563584, 'reg_lambda': 0.00723885417374379}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:11:50,137] Trial 136 pruned.
# [I 2026-03-12 16:11:53,735] Trial 137 finished with value: 12.783951932818711 and parameters: {'n_estimators': 1001, 'learning_rate': 0.0060783618633075956, 'max_depth': 3, 'subsample': 0.9884424030663587, 'colsample_bytree': 0.5800299807973184, 'min_child_weight': 3, 'gamma': 1.2233479657080073, 'reg_lambda': 0.03039154739267517}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:11:56,603] Trial 138 pruned.
# [I 2026-03-12 16:11:59,678] Trial 139 pruned.
# [I 2026-03-12 16:12:10,921] Trial 140 pruned.
# [I 2026-03-12 16:12:14,318] Trial 141 finished with value: 12.850871876951974 and parameters: {'n_estimators': 1092, 'learning_rate': 0.006965995123325609, 'max_depth': 3, 'subsample': 0.9798314021900777, 'colsample_bytree': 0.5617940341789679, 'min_child_weight': 3, 'gamma': 1.4327024650344864, 'reg_lambda': 0.026053421126409775}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:12:16,905] Trial 142 pruned.
# [I 2026-03-12 16:12:19,562] Trial 143 pruned.
# [I 2026-03-12 16:12:22,543] Trial 144 finished with value: 12.81811081816079 and parameters: {'n_estimators': 911, 'learning_rate': 0.005576101020142981, 'max_depth': 3, 'subsample': 0.9857213099501642, 'colsample_bytree': 0.5823799213470555, 'min_child_weight': 3, 'gamma': 1.215083565103312, 'reg_lambda': 0.016553057159920125}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:12:25,999] Trial 145 pruned.
# [I 2026-03-12 16:12:28,527] Trial 146 pruned.
# [I 2026-03-12 16:12:35,052] Trial 147 pruned.
# [I 2026-03-12 16:12:37,478] Trial 148 pruned.
# [I 2026-03-12 16:12:41,340] Trial 149 finished with value: 12.832005211429292 and parameters: {'n_estimators': 1084, 'learning_rate': 0.005632007185905721, 'max_depth': 3, 'subsample': 0.9829641980375354, 'colsample_bytree': 0.5927117061049054, 'min_child_weight': 3, 'gamma': 1.0403416419764593, 'reg_lambda': 0.023457186395006484}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:12:44,973] Trial 150 pruned.
# [I 2026-03-12 16:12:47,811] Trial 151 pruned.
# [I 2026-03-12 16:12:49,446] Trial 152 pruned.
# [I 2026-03-12 16:12:51,249] Trial 153 pruned.
# [I 2026-03-12 16:12:53,606] Trial 154 pruned.
# [I 2026-03-12 16:12:55,416] Trial 155 pruned.
# [I 2026-03-12 16:12:58,071] Trial 156 finished with value: 12.746381906805901 and parameters: {'n_estimators': 947, 'learning_rate': 0.006826474103582974, 'max_depth': 3, 'subsample': 0.9902208683767219, 'colsample_bytree': 0.5949570593264412, 'min_child_weight': 3, 'gamma': 1.5782031749456211, 'reg_lambda': 0.005201827205495003}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:12:59,032] Trial 157 pruned.
# [I 2026-03-12 16:13:01,658] Trial 158 finished with value: 12.859629814031 and parameters: {'n_estimators': 1104, 'learning_rate': 0.007201348316477663, 'max_depth': 3, 'subsample': 0.999726000616635, 'colsample_bytree': 0.6111988230876263, 'min_child_weight': 3, 'gamma': 1.1860026362395077, 'reg_lambda': 0.022226396605701127}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:13:03,527] Trial 159 pruned.
# [I 2026-03-12 16:13:04,713] Trial 160 pruned.
# [I 2026-03-12 16:13:07,875] Trial 161 finished with value: 12.74075842920425 and parameters: {'n_estimators': 1020, 'learning_rate': 0.006358564140173569, 'max_depth': 3, 'subsample': 0.9826411856162686, 'colsample_bytree': 0.5823169648457461, 'min_child_weight': 3, 'gamma': 0.8351674271616398, 'reg_lambda': 0.015147323276379718}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:13:10,891] Trial 162 finished with value: 12.75356035481916 and parameters: {'n_estimators': 1026, 'learning_rate': 0.006513254784978941, 'max_depth': 3, 'subsample': 0.9819021725289945, 'colsample_bytree': 0.5926293374220649, 'min_child_weight': 3, 'gamma': 0.8660782155031224, 'reg_lambda': 0.016222659144309575}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:13:13,438] Trial 163 pruned.
# [I 2026-03-12 16:13:16,764] Trial 164 pruned.
# [I 2026-03-12 16:13:18,937] Trial 165 pruned.
# [I 2026-03-12 16:13:21,001] Trial 166 pruned.
# [I 2026-03-12 16:13:23,608] Trial 167 pruned.
# [I 2026-03-12 16:13:26,696] Trial 168 pruned.
# [I 2026-03-12 16:13:27,723] Trial 169 pruned.
# [I 2026-03-12 16:13:30,523] Trial 170 pruned.
# [I 2026-03-12 16:13:33,367] Trial 171 pruned.
# [I 2026-03-12 16:13:37,118] Trial 172 finished with value: 12.73645043034188 and parameters: {'n_estimators': 1051, 'learning_rate': 0.005419597965047587, 'max_depth': 3, 'subsample': 0.9848419742517374, 'colsample_bytree': 0.5806898824548774, 'min_child_weight': 3, 'gamma': 0.8086703609502119, 'reg_lambda': 0.005861597724876665}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:13:40,023] Trial 173 finished with value: 12.777417918277767 and parameters: {'n_estimators': 1044, 'learning_rate': 0.00609933163631888, 'max_depth': 3, 'subsample': 0.988091248063544, 'colsample_bytree': 0.5862910075308911, 'min_child_weight': 3, 'gamma': 0.4588330488009321, 'reg_lambda': 0.004306065993799714}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:13:42,926] Trial 174 pruned.
# [I 2026-03-12 16:13:44,537] Trial 175 pruned.
# [I 2026-03-12 16:13:47,089] Trial 176 pruned.
# [I 2026-03-12 16:13:50,497] Trial 177 pruned.
# [I 2026-03-12 16:13:52,915] Trial 178 pruned.
# [I 2026-03-12 16:13:55,620] Trial 179 pruned.
# [I 2026-03-12 16:13:59,162] Trial 180 finished with value: 12.772849135051757 and parameters: {'n_estimators': 1038, 'learning_rate': 0.005960789281683367, 'max_depth': 3, 'subsample': 0.9713403667244617, 'colsample_bytree': 0.5675357029345258, 'min_child_weight': 4, 'gamma': 1.2593683677730456, 'reg_lambda': 0.006624958799797899}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:14:03,733] Trial 181 pruned.
# [I 2026-03-12 16:14:09,102] Trial 182 pruned.
# [I 2026-03-12 16:14:16,177] Trial 183 pruned.
# [I 2026-03-12 16:14:20,228] Trial 184 pruned.
# [I 2026-03-12 16:14:21,044] Trial 185 pruned.
# [I 2026-03-12 16:14:24,605] Trial 186 pruned.
# [I 2026-03-12 16:14:26,910] Trial 187 pruned.
# [I 2026-03-12 16:14:30,228] Trial 188 pruned.
# [I 2026-03-12 16:14:31,467] Trial 189 pruned.
# [I 2026-03-12 16:14:35,193] Trial 190 pruned.
# [I 2026-03-12 16:14:36,500] Trial 191 pruned.
# [I 2026-03-12 16:14:39,986] Trial 192 finished with value: 12.719364457194196 and parameters: {'n_estimators': 1008, 'learning_rate': 0.006539472408749289, 'max_depth': 3, 'subsample': 0.9400818164865541, 'colsample_bytree': 0.6057148859638749, 'min_child_weight': 2, 'gamma': 1.5246245454697755, 'reg_lambda': 0.004675282093991677}. Best is trial 59 with value: 12.423394460929975.
# [I 2026-03-12 16:14:41,369] Trial 193 pruned.
# [I 2026-03-12 16:14:43,954] Trial 194 pruned.
# [I 2026-03-12 16:14:45,810] Trial 195 pruned.
# [I 2026-03-12 16:14:47,680] Trial 196 pruned.
# [I 2026-03-12 16:14:49,443] Trial 197 pruned.
# [I 2026-03-12 16:14:51,422] Trial 198 pruned.
# [I 2026-03-12 16:14:53,495] Trial 199 pruned.
# Best trial parameters: {'n_estimators': 506, 'learning_rate': 0.13306784094760749, 'max_depth': 3, 'subsample': 0.6637440700615823, 'colsample_bytree': 0.7054179185059445, 'min_child_weight': 1, 'gamma': 4.596308746920205, 'reg_lambda': 0.020343105086808335}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# Get the exact number of trees where it peaked
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7054179185059445, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=4.596308746920205, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.13306784094760749,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=21, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# saving best model
joblib.dump(best_model, model_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_PM2.5\\xgboost_model_AL_PM2.5.pkl']

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 13.2968
# MAE:  7.4378
# R2:   0.3229

# %%
log_stat(f"{POLLUTANT} RMSE: ", rmse)
log_stat(f"{POLLUTANT} MAE: ",  mae)
log_stat(f"{POLLUTANT} R2: ",   r2)

# %%
# For Comparrison a naive non ML just guessing that tomorrow's pollutant will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 13.2968
# Naive Baseline RMSE: 15.3708

# %%
log_stat(f"{POLLUTANT}Naive Baseline RMSE: ", naive_rmse)

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title(f"SHAP Feature Importance: What drives {POLLUTANT} Pollution?")
plt.tight_layout()
plt.savefig(output_dir / f"{RUN_ID}_SHAP_Feature_importance.png", bbox_inches='tight')
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.title(f"Feature Importance of {POLLUTANT}")
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
plt.savefig(output_dir / f"{RUN_ID}_Feature_Importance.png", bbox_inches='tight')

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")


# folder for these prediction plots
pred_plot_dir = output_dir / "Predict_vs_Actual_Plots"
pred_plot_dir.mkdir(parents=True, exist_ok=True)

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

station_metrics_list = [] 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])

    station_metrics_list.append({ # add evalutation to list
        'Station': station,
        'RMSE': round(st_rmse, 3),
        'MAE': round(st_mae, 3),
        'R2': round(st_r2, 3)
    })
    
    print(f"Samplingpoint {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label=f'Actual {POLLUTANT}', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label=f'Predicted {POLLUTANT}', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted {POLLUTANT}\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel(f'{POLLUTANT} ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    clean_station_name = str(station).replace(".", "_").replace("/", "_")
    file_name = f"{COUNTRY_CODE}_{POLLUTANT}_{clean_station_name}_predict.png"
    plt.savefig(pred_plot_dir / file_name, dpi=150)

    plt.show()
    plt.close()


# list to df to csv
metrics_df = pd.DataFrame(station_metrics_list)
csv_filename = output_dir / f"{COUNTRY_CODE}_{POLLUTANT}_Every_Station_Metrics.csv"
metrics_df.to_csv(csv_filename, index=False)
# Out:
# RMSE: 13.2968
# MAE:  7.4378
# R2:   0.3229
# Samplingpoint AL/SPO-AL0203A_06001_100 -> RMSE: 20.77 | MAE: 11.10 | R2: 0.30
# Samplingpoint AL/SPO-AL0206A_06001_100 -> RMSE: 9.56 | MAE: 6.28 | R2: 0.40
# Samplingpoint AL/SPO-AL0205A_06001_100 -> RMSE: 8.88 | MAE: 6.15 | R2: 0.30
# Samplingpoint AL/SPO-AL0208A_06001_100 -> RMSE: 8.99 | MAE: 5.84 | R2: 0.22
