# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os
import joblib
from pathlib import Path

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
POLLUTANT = "O3"

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
RESULTS_SAVE_FOLDER = os.getenv("RESULTS_SAVE_FOLDER")

# %%
# reading in data
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
# saving results
RUN_ID = f"{COUNTRY_CODE}_{POLLUTANT}"

output_dir = Path(RESULTS_SAVE_FOLDER) / f"Results_{RUN_ID}"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# saving model
model_filename = output_dir / f"xgboost_model_{COUNTRY_CODE}_{POLLUTANT}.pkl"

# %%
def log_stat(name, value): # save statistics as a test file
    with open(output_dir / "data_processing_log.txt", "a") as f:
        f.write(f"{name}: {value}\n")

with open(output_dir / "data_processing_log.txt", "w") as f: # clear log if it exists to start fresh
    f.write(f"Processing Log for {RUN_ID}\n")

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#               Samplingpoint      Start      Value
# 0  AL/SPO-AL0201A_00007_100 2013-01-01  16.555217
# 1  AL/SPO-AL0201A_00007_100 2013-01-02  24.195000
# 2  AL/SPO-AL0201A_00007_100 2013-01-03  17.837292
# 3  AL/SPO-AL0201A_00007_100 2013-01-04  21.872500
# 4  AL/SPO-AL0201A_00007_100 2013-01-05  13.536458
# 5  AL/SPO-AL0201A_00007_100 2013-01-06  34.046875
# 6  AL/SPO-AL0201A_00007_100 2013-01-07  32.977083
# 7  AL/SPO-AL0201A_00007_100 2013-01-08  31.198958
# 8  AL/SPO-AL0201A_00007_100 2013-01-09  24.702917
# 9  AL/SPO-AL0201A_00007_100 2013-01-10  23.630208

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (17971, 11)
#        Start             Samplingpoint      Value  DayOfWeek  Month  \
# 0 2013-01-01  AL/SPO-AL0201A_00007_100  16.555217          1      1
# 1 2013-01-02  AL/SPO-AL0201A_00007_100  24.195000          2      1
# 2 2013-01-03  AL/SPO-AL0201A_00007_100  17.837292          3      1
# 3 2013-01-04  AL/SPO-AL0201A_00007_100  21.872500          4      1
# 4 2013-01-05  AL/SPO-AL0201A_00007_100  13.536458          5      1
# 5 2013-01-06  AL/SPO-AL0201A_00007_100  34.046875          6      1
# 6 2013-01-07  AL/SPO-AL0201A_00007_100  32.977083          0      1
# 7 2013-01-08  AL/SPO-AL0201A_00007_100  31.198958          1      1
# 8 2013-01-09  AL/SPO-AL0201A_00007_100  24.702917          2      1
# 9 2013-01-10  AL/SPO-AL0201A_00007_100  23.630208          3      1
#
#    DayOfYear  IsWeekend      Lag_1      Lag_7  Rolling_Mean_7D     Target
# 0          1          0        NaN        NaN              NaN  24.195000
# 1          2          0  16.555217        NaN              NaN  17.837292
# 2          3          0  24.195000        NaN              NaN  21.872500
# 3          4          0  17.837292        NaN        20.115002  13.536458
# 4          5          1  21.872500        NaN        18.799293  34.046875
# 5          6          1  13.536458        NaN        21.340557  32.977083
# 6          7          0  34.046875        NaN        23.002918  31.198958
# 7          8          0  32.977083  16.555217        25.094881  24.702917
# 8          9          0  31.198958  24.195000        25.167440  23.630208
# 9         10          0  24.702917  17.837292        25.995000  24.677917

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start             Samplingpoint      Value  DayOfWeek  Month  \
# 0 2013-01-01  AL/SPO-AL0201A_00007_100  16.555217          1      1
# 1 2013-01-02  AL/SPO-AL0201A_00007_100  24.195000          2      1
# 2 2013-01-03  AL/SPO-AL0201A_00007_100  17.837292          3      1
# 3 2013-01-04  AL/SPO-AL0201A_00007_100  21.872500          4      1
# 4 2013-01-05  AL/SPO-AL0201A_00007_100  13.536458          5      1
# 5 2013-01-06  AL/SPO-AL0201A_00007_100  34.046875          6      1
# 6 2013-01-07  AL/SPO-AL0201A_00007_100  32.977083          0      1
# 7 2013-01-08  AL/SPO-AL0201A_00007_100  31.198958          1      1
# 8 2013-01-09  AL/SPO-AL0201A_00007_100  24.702917          2      1
# 9 2013-01-10  AL/SPO-AL0201A_00007_100  23.630208          3      1
#
#    DayOfYear  IsWeekend      Lag_1      Lag_7  Rolling_Mean_7D     Target
# 0          1          0        NaN        NaN              NaN  24.195000
# 1          2          0  16.555217        NaN              NaN  17.837292
# 2          3          0  24.195000        NaN              NaN  21.872500
# 3          4          0  17.837292        NaN        20.115002  13.536458
# 4          5          1  21.872500        NaN        18.799293  34.046875
# 5          6          1  13.536458        NaN        21.340557  32.977083
# 6          7          0  34.046875        NaN        23.002918  31.198958
# 7          8          0  32.977083  16.555217        25.094881  24.702917
# 8          9          0  31.198958  24.195000        25.167440  23.630208
# 9         10          0  24.702917  17.837292        25.995000  24.677917
# Start                0
# Samplingpoint        0
# Value              116
# DayOfWeek            0
# Month                0
# DayOfYear            0
# IsWeekend            0
# Lag_1              215
# Lag_7              629
# Rolling_Mean_7D    351
# Target               0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (7025, 9), Val shape: (97, 9), Test shape: (2156, 9)

# %%
# save features 
feature_names = list(X_train.columns)
features_filename = output_dir / f"xgboost_features_{COUNTRY_CODE}_{POLLUTANT}.pkl"
joblib.dump(feature_names, features_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_O3\\xgboost_features_AL_O3.pkl']

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 16:55:07,391] A new study created in memory with name: no-name-c0ca9252-051e-4491-bfdb-7c48f6f4bf83
# [I 2026-03-12 16:55:10,573] Trial 0 finished with value: 10.810131748048029 and parameters: {'n_estimators': 911, 'learning_rate': 0.048520929512138745, 'max_depth': 6, 'subsample': 0.7054014033187386, 'colsample_bytree': 0.524037819460926, 'min_child_weight': 4, 'gamma': 3.0045671340975137, 'reg_lambda': 0.017201027640431233}. Best is trial 0 with value: 10.810131748048029.
# [I 2026-03-12 16:55:12,420] Trial 1 finished with value: 10.175214885607494 and parameters: {'n_estimators': 1127, 'learning_rate': 0.04778832368835753, 'max_depth': 5, 'subsample': 0.7438208943234192, 'colsample_bytree': 0.5828917210133723, 'min_child_weight': 8, 'gamma': 4.45958675507272, 'reg_lambda': 0.12309668672345787}. Best is trial 1 with value: 10.175214885607494.
# [I 2026-03-12 16:55:16,557] Trial 2 finished with value: 10.507731430224927 and parameters: {'n_estimators': 493, 'learning_rate': 0.0302949114590526, 'max_depth': 9, 'subsample': 0.9375405677574749, 'colsample_bytree': 0.8645257753278222, 'min_child_weight': 10, 'gamma': 4.9950921121139364, 'reg_lambda': 0.001372206639074261}. Best is trial 1 with value: 10.175214885607494.
# [I 2026-03-12 16:55:17,130] Trial 3 finished with value: 10.061781772842922 and parameters: {'n_estimators': 239, 'learning_rate': 0.1205438149186848, 'max_depth': 4, 'subsample': 0.6997069480252891, 'colsample_bytree': 0.888677786801526, 'min_child_weight': 4, 'gamma': 1.8606895516527222, 'reg_lambda': 0.11688439222870514}. Best is trial 3 with value: 10.061781772842922.
# [I 2026-03-12 16:55:18,040] Trial 4 finished with value: 10.452657966761803 and parameters: {'n_estimators': 330, 'learning_rate': 0.05371431251100734, 'max_depth': 5, 'subsample': 0.7393917191426675, 'colsample_bytree': 0.6362819265325812, 'min_child_weight': 6, 'gamma': 3.0507545933998776, 'reg_lambda': 0.002037562463389026}. Best is trial 3 with value: 10.061781772842922.
# [I 2026-03-12 16:55:30,110] Trial 5 pruned.
# [I 2026-03-12 16:55:34,978] Trial 6 finished with value: 10.325442323864166 and parameters: {'n_estimators': 1132, 'learning_rate': 0.006404876042485688, 'max_depth': 3, 'subsample': 0.7593924442093194, 'colsample_bytree': 0.8238888761447917, 'min_child_weight': 10, 'gamma': 1.3570059636102867, 'reg_lambda': 0.0011713562669842259}. Best is trial 3 with value: 10.061781772842922.
# [I 2026-03-12 16:55:40,175] Trial 7 finished with value: 10.461020536270398 and parameters: {'n_estimators': 1188, 'learning_rate': 0.020718013538220514, 'max_depth': 10, 'subsample': 0.5099551003652614, 'colsample_bytree': 0.9692923130799569, 'min_child_weight': 5, 'gamma': 0.32683573352955186, 'reg_lambda': 0.06205990134828678}. Best is trial 3 with value: 10.061781772842922.
# [I 2026-03-12 16:55:40,957] Trial 8 pruned.
# [I 2026-03-12 16:55:52,670] Trial 9 finished with value: 11.602094965458956 and parameters: {'n_estimators': 945, 'learning_rate': 0.0051730426385111095, 'max_depth': 7, 'subsample': 0.8534876325504812, 'colsample_bytree': 0.96941399183328, 'min_child_weight': 1, 'gamma': 2.0359955494072484, 'reg_lambda': 0.0015317103454906252}. Best is trial 3 with value: 10.061781772842922.
# [I 2026-03-12 16:55:55,894] Trial 10 pruned.
# [I 2026-03-12 16:55:56,743] Trial 11 pruned.
# [I 2026-03-12 16:55:57,525] Trial 12 pruned.
# [I 2026-03-12 16:56:00,091] Trial 13 finished with value: 9.973256756331503 and parameters: {'n_estimators': 676, 'learning_rate': 0.013359783130297277, 'max_depth': 4, 'subsample': 0.6647885386650987, 'colsample_bytree': 0.613795384046303, 'min_child_weight': 8, 'gamma': 1.236800588888999, 'reg_lambda': 0.09060759279996984}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:02,780] Trial 14 finished with value: 10.252734574264599 and parameters: {'n_estimators': 653, 'learning_rate': 0.012536849925878708, 'max_depth': 3, 'subsample': 0.6404370571572443, 'colsample_bytree': 0.7387439165514713, 'min_child_weight': 3, 'gamma': 1.1706562716092739, 'reg_lambda': 0.03017907193452739}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:05,282] Trial 15 finished with value: 10.25063866523635 and parameters: {'n_estimators': 761, 'learning_rate': 0.013131786888752911, 'max_depth': 4, 'subsample': 0.5596089017502349, 'colsample_bytree': 0.7890095058225082, 'min_child_weight': 8, 'gamma': 1.1983531038556463, 'reg_lambda': 0.4587127519331206}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:07,755] Trial 16 pruned.
# [I 2026-03-12 16:56:09,477] Trial 17 finished with value: 10.400403022293615 and parameters: {'n_estimators': 512, 'learning_rate': 0.02226667375013649, 'max_depth': 4, 'subsample': 0.9954737915074627, 'colsample_bytree': 0.6439532872575636, 'min_child_weight': 3, 'gamma': 0.7060573922924482, 'reg_lambda': 0.04999974820648146}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:15,897] Trial 18 pruned.
# [I 2026-03-12 16:56:17,985] Trial 19 finished with value: 10.137865641179747 and parameters: {'n_estimators': 368, 'learning_rate': 0.017945348773559567, 'max_depth': 4, 'subsample': 0.8153621229778371, 'colsample_bytree': 0.9071709393988535, 'min_child_weight': 7, 'gamma': 1.5391675060206425, 'reg_lambda': 1.0245920207176598}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:18,989] Trial 20 pruned.
# [I 2026-03-12 16:56:21,101] Trial 21 finished with value: 10.204822769497776 and parameters: {'n_estimators': 353, 'learning_rate': 0.018740090537253402, 'max_depth': 4, 'subsample': 0.8043810494302063, 'colsample_bytree': 0.9134674973668141, 'min_child_weight': 7, 'gamma': 1.663317230489703, 'reg_lambda': 1.059616389304345}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:22,555] Trial 22 finished with value: 10.316462673825699 and parameters: {'n_estimators': 279, 'learning_rate': 0.03452421235805623, 'max_depth': 4, 'subsample': 0.7977451732657626, 'colsample_bytree': 0.9107086072055613, 'min_child_weight': 7, 'gamma': 2.642395581112509, 'reg_lambda': 0.11520034386281594}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:24,450] Trial 23 finished with value: 10.90968677489423 and parameters: {'n_estimators': 207, 'learning_rate': 0.0164316302652592, 'max_depth': 5, 'subsample': 0.8870360921482037, 'colsample_bytree': 0.994024916354697, 'min_child_weight': 9, 'gamma': 1.4330990078607049, 'reg_lambda': 9.293854697356126}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:26,578] Trial 24 pruned.
# [I 2026-03-12 16:56:28,078] Trial 25 finished with value: 10.366399855526137 and parameters: {'n_estimators': 590, 'learning_rate': 0.028899803676594674, 'max_depth': 4, 'subsample': 0.6947748005471269, 'colsample_bytree': 0.8155321616462875, 'min_child_weight': 4, 'gamma': 1.7185484136274527, 'reg_lambda': 1.566027843455169}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:31,089] Trial 26 pruned.
# [I 2026-03-12 16:56:40,538] Trial 27 pruned.
# [I 2026-03-12 16:56:41,959] Trial 28 pruned.
# [I 2026-03-12 16:56:45,054] Trial 29 pruned.
# [I 2026-03-12 16:56:49,171] Trial 30 finished with value: 10.441167032203493 and parameters: {'n_estimators': 587, 'learning_rate': 0.009314419212640855, 'max_depth': 3, 'subsample': 0.6729489194953286, 'colsample_bytree': 0.841443243152867, 'min_child_weight': 7, 'gamma': 3.3881194779740857, 'reg_lambda': 0.004615213093442809}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:56:51,052] Trial 31 pruned.
# [I 2026-03-12 16:56:51,816] Trial 32 pruned.
# [I 2026-03-12 16:56:52,864] Trial 33 pruned.
# [I 2026-03-12 16:56:53,948] Trial 34 pruned.
# [I 2026-03-12 16:56:55,958] Trial 35 pruned.
# [I 2026-03-12 16:56:56,640] Trial 36 pruned.
# [I 2026-03-12 16:56:57,268] Trial 37 pruned.
# [I 2026-03-12 16:57:04,447] Trial 38 pruned.
# [I 2026-03-12 16:57:09,088] Trial 39 pruned.
# [I 2026-03-12 16:57:11,559] Trial 40 pruned.
# [I 2026-03-12 16:57:14,190] Trial 41 finished with value: 10.148511453396262 and parameters: {'n_estimators': 384, 'learning_rate': 0.019008283772051736, 'max_depth': 4, 'subsample': 0.810522039092691, 'colsample_bytree': 0.9491380517836888, 'min_child_weight': 7, 'gamma': 1.6743396565990458, 'reg_lambda': 1.1601569812367762}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:16,010] Trial 42 finished with value: 10.218791357601338 and parameters: {'n_estimators': 381, 'learning_rate': 0.02010358075836303, 'max_depth': 4, 'subsample': 0.8719294546876916, 'colsample_bytree': 0.9800665136152432, 'min_child_weight': 5, 'gamma': 2.022210024408634, 'reg_lambda': 0.3230983643343463}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:22,789] Trial 43 pruned.
# [I 2026-03-12 16:57:23,742] Trial 44 finished with value: 10.410803300768066 and parameters: {'n_estimators': 178, 'learning_rate': 0.031072172926882316, 'max_depth': 3, 'subsample': 0.7323272358661519, 'colsample_bytree': 0.8517727070837623, 'min_child_weight': 8, 'gamma': 1.4630814766131408, 'reg_lambda': 6.133058885027981}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:25,140] Trial 45 pruned.
# [I 2026-03-12 16:57:27,708] Trial 46 finished with value: 10.124042540513205 and parameters: {'n_estimators': 336, 'learning_rate': 0.014290055627358269, 'max_depth': 5, 'subsample': 0.7826575016602009, 'colsample_bytree': 0.9368973444340803, 'min_child_weight': 9, 'gamma': 2.0912672346864327, 'reg_lambda': 0.03487919530810927}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:30,540] Trial 47 finished with value: 10.062129811967385 and parameters: {'n_estimators': 569, 'learning_rate': 0.014224626560815279, 'max_depth': 5, 'subsample': 0.8227374157157479, 'colsample_bytree': 0.9339637642880447, 'min_child_weight': 9, 'gamma': 2.209818317468402, 'reg_lambda': 0.021150280895982674}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:34,406] Trial 48 pruned.
# [I 2026-03-12 16:57:37,257] Trial 49 pruned.
# [I 2026-03-12 16:57:43,701] Trial 50 pruned.
# [I 2026-03-12 16:57:45,962] Trial 51 finished with value: 10.301813852763607 and parameters: {'n_estimators': 336, 'learning_rate': 0.018433915730585625, 'max_depth': 3, 'subsample': 0.8091059446934487, 'colsample_bytree': 0.9427495729817174, 'min_child_weight': 8, 'gamma': 1.7104410644224055, 'reg_lambda': 0.01041015448119758}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:49,340] Trial 52 finished with value: 10.12885812696445 and parameters: {'n_estimators': 476, 'learning_rate': 0.01429128229845923, 'max_depth': 4, 'subsample': 0.820181927586422, 'colsample_bytree': 0.9971193431026666, 'min_child_weight': 9, 'gamma': 1.887689292730819, 'reg_lambda': 0.016829929503017014}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:52,584] Trial 53 finished with value: 10.191581107139257 and parameters: {'n_estimators': 490, 'learning_rate': 0.01449526057842919, 'max_depth': 4, 'subsample': 0.8284254063979446, 'colsample_bytree': 0.9981497484516698, 'min_child_weight': 9, 'gamma': 1.8778827160769265, 'reg_lambda': 0.018110904935228905}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:55,623] Trial 54 finished with value: 10.32896735431519 and parameters: {'n_estimators': 549, 'learning_rate': 0.01100512334448985, 'max_depth': 3, 'subsample': 0.7837675626102554, 'colsample_bytree': 0.9017563971766007, 'min_child_weight': 10, 'gamma': 2.8650418220545415, 'reg_lambda': 0.031072890064421183}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:57:57,778] Trial 55 pruned.
# [I 2026-03-12 16:58:06,079] Trial 56 pruned.
# [I 2026-03-12 16:58:06,937] Trial 57 pruned.
# [I 2026-03-12 16:58:08,896] Trial 58 pruned.
# [I 2026-03-12 16:58:10,013] Trial 59 pruned.
# [I 2026-03-12 16:58:13,457] Trial 60 pruned.
# [I 2026-03-12 16:58:15,258] Trial 61 finished with value: 10.022227656761995 and parameters: {'n_estimators': 407, 'learning_rate': 0.018580482192587504, 'max_depth': 4, 'subsample': 0.8138272624233415, 'colsample_bytree': 0.9549762942354919, 'min_child_weight': 7, 'gamma': 1.5306358451904747, 'reg_lambda': 0.06095030194204219}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:58:17,150] Trial 62 finished with value: 10.193066659140515 and parameters: {'n_estimators': 510, 'learning_rate': 0.017323567893626032, 'max_depth': 4, 'subsample': 0.8478185905491995, 'colsample_bytree': 0.9600600309431611, 'min_child_weight': 7, 'gamma': 1.4858248930256999, 'reg_lambda': 0.06005367992188508}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:58:18,950] Trial 63 finished with value: 10.234459684960422 and parameters: {'n_estimators': 436, 'learning_rate': 0.023228968149913303, 'max_depth': 4, 'subsample': 0.7935047762378499, 'colsample_bytree': 0.9340290129902956, 'min_child_weight': 3, 'gamma': 1.9127356848152626, 'reg_lambda': 0.03773894555989899}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:58:21,277] Trial 64 pruned.
# [I 2026-03-12 16:58:22,631] Trial 65 pruned.
# [I 2026-03-12 16:58:25,412] Trial 66 pruned.
# [I 2026-03-12 16:58:26,885] Trial 67 finished with value: 10.088117397803753 and parameters: {'n_estimators': 570, 'learning_rate': 0.02796512026656822, 'max_depth': 3, 'subsample': 0.690736132906465, 'colsample_bytree': 0.9810600030023279, 'min_child_weight': 8, 'gamma': 2.4798706365398377, 'reg_lambda': 0.004945266971234392}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:58:28,080] Trial 68 finished with value: 10.085203453541906 and parameters: {'n_estimators': 712, 'learning_rate': 0.03301324994340657, 'max_depth': 3, 'subsample': 0.6869963270660797, 'colsample_bytree': 0.9851534265606354, 'min_child_weight': 8, 'gamma': 2.3850283838429247, 'reg_lambda': 0.0022098527314399156}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:58:29,351] Trial 69 finished with value: 10.206615465879896 and parameters: {'n_estimators': 700, 'learning_rate': 0.02685189595533961, 'max_depth': 3, 'subsample': 0.6571437756744976, 'colsample_bytree': 0.9819591944131986, 'min_child_weight': 8, 'gamma': 2.553112449946326, 'reg_lambda': 0.0021815278881090767}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:58:30,425] Trial 70 pruned.
# [I 2026-03-12 16:58:30,877] Trial 71 finished with value: 10.091745399514327 and parameters: {'n_estimators': 659, 'learning_rate': 0.1590648471214491, 'max_depth': 3, 'subsample': 0.6932240131567662, 'colsample_bytree': 0.9992882423983701, 'min_child_weight': 9, 'gamma': 3.182378406614509, 'reg_lambda': 0.0011225680377105753}. Best is trial 13 with value: 9.973256756331503.
# [I 2026-03-12 16:58:31,405] Trial 72 pruned.
# [I 2026-03-12 16:58:31,934] Trial 73 finished with value: 9.931471794936535 and parameters: {'n_estimators': 808, 'learning_rate': 0.11165697298547171, 'max_depth': 3, 'subsample': 0.6898251826416926, 'colsample_bytree': 0.9638385994867423, 'min_child_weight': 8, 'gamma': 2.267955959083698, 'reg_lambda': 0.001033963023761475}. Best is trial 73 with value: 9.931471794936535.
# [I 2026-03-12 16:58:32,571] Trial 74 finished with value: 9.956436992969426 and parameters: {'n_estimators': 751, 'learning_rate': 0.10504097795329959, 'max_depth': 3, 'subsample': 0.6892516314408935, 'colsample_bytree': 0.9670980209520667, 'min_child_weight': 8, 'gamma': 2.3422449619850925, 'reg_lambda': 0.0010979849740065683}. Best is trial 73 with value: 9.931471794936535.
# [I 2026-03-12 16:58:33,265] Trial 75 finished with value: 9.507978796494323 and parameters: {'n_estimators': 802, 'learning_rate': 0.09719232029278012, 'max_depth': 3, 'subsample': 0.6347906390662192, 'colsample_bytree': 0.9536860045706191, 'min_child_weight': 8, 'gamma': 2.409523504106821, 'reg_lambda': 0.0014823066944299023}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:33,966] Trial 76 finished with value: 10.152770485319309 and parameters: {'n_estimators': 805, 'learning_rate': 0.10513727300085485, 'max_depth': 3, 'subsample': 0.592553000789174, 'colsample_bytree': 0.9587276001261994, 'min_child_weight': 7, 'gamma': 2.270998798209173, 'reg_lambda': 0.001003713351172189}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:34,682] Trial 77 finished with value: 10.103918127692005 and parameters: {'n_estimators': 827, 'learning_rate': 0.08431200397052316, 'max_depth': 3, 'subsample': 0.6629126189873286, 'colsample_bytree': 0.9469722636666836, 'min_child_weight': 8, 'gamma': 2.8065668623606284, 'reg_lambda': 0.0013687452936023245}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:35,237] Trial 78 finished with value: 9.944506823215464 and parameters: {'n_estimators': 741, 'learning_rate': 0.12080646997793018, 'max_depth': 3, 'subsample': 0.6339321066862937, 'colsample_bytree': 0.9217273908418824, 'min_child_weight': 4, 'gamma': 2.415584895732762, 'reg_lambda': 0.0027327029157470694}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:36,039] Trial 79 pruned.
# [I 2026-03-12 16:58:36,640] Trial 80 finished with value: 10.308259260824606 and parameters: {'n_estimators': 759, 'learning_rate': 0.13087234953445814, 'max_depth': 3, 'subsample': 0.6253484625478358, 'colsample_bytree': 0.8918592998704613, 'min_child_weight': 4, 'gamma': 2.2422746180142985, 'reg_lambda': 0.0014588318080674307}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:37,387] Trial 81 finished with value: 9.829791204301497 and parameters: {'n_estimators': 732, 'learning_rate': 0.09554538734982657, 'max_depth': 3, 'subsample': 0.5966530714976147, 'colsample_bytree': 0.9601030200938234, 'min_child_weight': 5, 'gamma': 2.438554252950254, 'reg_lambda': 0.0026724265763939997}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:38,099] Trial 82 finished with value: 9.974848249204603 and parameters: {'n_estimators': 800, 'learning_rate': 0.08979355226967359, 'max_depth': 3, 'subsample': 0.5954939398224433, 'colsample_bytree': 0.9628087021602698, 'min_child_weight': 5, 'gamma': 2.386602585734377, 'reg_lambda': 0.0018581519293651165}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:38,960] Trial 83 finished with value: 9.77455912062367 and parameters: {'n_estimators': 828, 'learning_rate': 0.09870874489778189, 'max_depth': 3, 'subsample': 0.5574312250845793, 'colsample_bytree': 0.9672877830948813, 'min_child_weight': 5, 'gamma': 2.4889190210181007, 'reg_lambda': 0.001680148554639536}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:39,812] Trial 84 finished with value: 9.915808806587222 and parameters: {'n_estimators': 821, 'learning_rate': 0.09542382591663319, 'max_depth': 3, 'subsample': 0.5423470295113884, 'colsample_bytree': 0.9670982063789778, 'min_child_weight': 5, 'gamma': 2.6641638716472764, 'reg_lambda': 0.0025464510631746334}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:40,415] Trial 85 pruned.
# [I 2026-03-12 16:58:41,104] Trial 86 finished with value: 10.343588640242237 and parameters: {'n_estimators': 801, 'learning_rate': 0.07682543455147998, 'max_depth': 3, 'subsample': 0.5008065181764617, 'colsample_bytree': 0.9689317716147617, 'min_child_weight': 5, 'gamma': 2.716541065975888, 'reg_lambda': 0.0018228277173699533}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:41,738] Trial 87 finished with value: 10.009110542747747 and parameters: {'n_estimators': 918, 'learning_rate': 0.09510600388701235, 'max_depth': 3, 'subsample': 0.5697872442105518, 'colsample_bytree': 0.951129318388068, 'min_child_weight': 5, 'gamma': 2.5650723619214477, 'reg_lambda': 0.004290068062783136}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:42,594] Trial 88 pruned.
# [I 2026-03-12 16:58:43,243] Trial 89 finished with value: 10.030285483984589 and parameters: {'n_estimators': 967, 'learning_rate': 0.11545185056912947, 'max_depth': 3, 'subsample': 0.597285141442215, 'colsample_bytree': 0.965298732621047, 'min_child_weight': 5, 'gamma': 3.1044562429239844, 'reg_lambda': 0.0022312990600474795}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:43,810] Trial 90 pruned.
# [I 2026-03-12 16:58:44,440] Trial 91 finished with value: 9.995807518652537 and parameters: {'n_estimators': 895, 'learning_rate': 0.09738026122446548, 'max_depth': 3, 'subsample': 0.562564017940541, 'colsample_bytree': 0.9482769615071969, 'min_child_weight': 5, 'gamma': 2.629899450666119, 'reg_lambda': 0.004804028142326047}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:44,960] Trial 92 finished with value: 10.090020707703369 and parameters: {'n_estimators': 874, 'learning_rate': 0.0995280464299795, 'max_depth': 3, 'subsample': 0.5210663563184178, 'colsample_bytree': 0.9452559788447792, 'min_child_weight': 5, 'gamma': 2.3766224775992977, 'reg_lambda': 0.0017365375903939373}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:45,532] Trial 93 pruned.
# [I 2026-03-12 16:58:46,141] Trial 94 finished with value: 10.170839832458961 and parameters: {'n_estimators': 730, 'learning_rate': 0.06989943813114834, 'max_depth': 3, 'subsample': 0.5626615074053435, 'colsample_bytree': 0.9129332353730678, 'min_child_weight': 4, 'gamma': 2.9753925649033692, 'reg_lambda': 0.005352119311313619}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:46,613] Trial 95 finished with value: 9.893580998186234 and parameters: {'n_estimators': 670, 'learning_rate': 0.12708871399983435, 'max_depth': 3, 'subsample': 0.633098119286737, 'colsample_bytree': 0.9715667303670437, 'min_child_weight': 5, 'gamma': 2.3225776496903663, 'reg_lambda': 0.0010533515837826376}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:47,181] Trial 96 pruned.
# [I 2026-03-12 16:58:47,620] Trial 97 pruned.
# [I 2026-03-12 16:58:48,215] Trial 98 pruned.
# [I 2026-03-12 16:58:48,730] Trial 99 pruned.
# [I 2026-03-12 16:58:49,156] Trial 100 pruned.
# [I 2026-03-12 16:58:49,844] Trial 101 finished with value: 9.574234360893206 and parameters: {'n_estimators': 844, 'learning_rate': 0.09875293216105621, 'max_depth': 3, 'subsample': 0.5552567409262493, 'colsample_bytree': 0.9309977695498789, 'min_child_weight': 5, 'gamma': 2.583064114881836, 'reg_lambda': 0.0037676242265187133}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:50,420] Trial 102 finished with value: 10.06765144165388 and parameters: {'n_estimators': 814, 'learning_rate': 0.08877264956238544, 'max_depth': 3, 'subsample': 0.5491874725803474, 'colsample_bytree': 0.9296177504297967, 'min_child_weight': 5, 'gamma': 2.3154288721225234, 'reg_lambda': 0.0025057163711635307}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:51,072] Trial 103 pruned.
# [I 2026-03-12 16:58:51,626] Trial 104 pruned.
# [I 2026-03-12 16:58:52,357] Trial 105 pruned.
# [I 2026-03-12 16:58:53,077] Trial 106 pruned.
# [I 2026-03-12 16:58:53,708] Trial 107 finished with value: 10.084111591325982 and parameters: {'n_estimators': 684, 'learning_rate': 0.08066112056721593, 'max_depth': 3, 'subsample': 0.5268790054629402, 'colsample_bytree': 0.9914346157384962, 'min_child_weight': 4, 'gamma': 2.6013856970933125, 'reg_lambda': 0.0014679743469523804}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:58:54,769] Trial 108 pruned.
# [I 2026-03-12 16:58:55,594] Trial 109 pruned.
# [I 2026-03-12 16:59:01,353] Trial 110 pruned.
# [I 2026-03-12 16:59:02,122] Trial 111 finished with value: 10.080675143565879 and parameters: {'n_estimators': 899, 'learning_rate': 0.09482977405199954, 'max_depth': 3, 'subsample': 0.5626859144513479, 'colsample_bytree': 0.946558012080834, 'min_child_weight': 5, 'gamma': 2.635884639960554, 'reg_lambda': 0.004351841218922713}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:02,749] Trial 112 finished with value: 10.14636290866084 and parameters: {'n_estimators': 877, 'learning_rate': 0.11072088015137987, 'max_depth': 3, 'subsample': 0.6044897763779589, 'colsample_bytree': 0.9612781731926633, 'min_child_weight': 5, 'gamma': 2.3613696211992066, 'reg_lambda': 0.0018718894184851524}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:03,355] Trial 113 finished with value: 10.118646413164901 and parameters: {'n_estimators': 762, 'learning_rate': 0.0993265896953062, 'max_depth': 3, 'subsample': 0.5915609776358169, 'colsample_bytree': 0.9312973278320374, 'min_child_weight': 4, 'gamma': 2.4927343609589396, 'reg_lambda': 0.008143517057500639}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:04,028] Trial 114 pruned.
# [I 2026-03-12 16:59:04,802] Trial 115 finished with value: 10.018414022315607 and parameters: {'n_estimators': 673, 'learning_rate': 0.08220689875237742, 'max_depth': 3, 'subsample': 0.5833275646066839, 'colsample_bytree': 0.9497547265842314, 'min_child_weight': 6, 'gamma': 2.3023317512689077, 'reg_lambda': 0.001231004266322222}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:05,481] Trial 116 pruned.
# [I 2026-03-12 16:59:06,085] Trial 117 pruned.
# [I 2026-03-12 16:59:07,344] Trial 118 pruned.
# [I 2026-03-12 16:59:08,376] Trial 119 finished with value: 10.141115059188934 and parameters: {'n_estimators': 627, 'learning_rate': 0.06315414784713187, 'max_depth': 3, 'subsample': 0.5739808055159827, 'colsample_bytree': 0.9418797286708305, 'min_child_weight': 4, 'gamma': 1.9350883311513596, 'reg_lambda': 0.0056137880329766585}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:09,497] Trial 120 pruned.
# [I 2026-03-12 16:59:10,113] Trial 121 finished with value: 10.18350001296629 and parameters: {'n_estimators': 914, 'learning_rate': 0.09335644359611076, 'max_depth': 3, 'subsample': 0.5559705074652597, 'colsample_bytree': 0.9516230001329178, 'min_child_weight': 5, 'gamma': 2.6146761943822856, 'reg_lambda': 0.009212751445269016}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:10,647] Trial 122 finished with value: 10.353835428415028 and parameters: {'n_estimators': 868, 'learning_rate': 0.10781799387009805, 'max_depth': 3, 'subsample': 0.6196784267005662, 'colsample_bytree': 0.9755482913428932, 'min_child_weight': 5, 'gamma': 2.5233156455403725, 'reg_lambda': 0.0025508760462299787}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:11,618] Trial 123 finished with value: 10.033153175100846 and parameters: {'n_estimators': 990, 'learning_rate': 0.04537945103647495, 'max_depth': 3, 'subsample': 0.5682573607225156, 'colsample_bytree': 0.9537986548829677, 'min_child_weight': 5, 'gamma': 2.2303114944783173, 'reg_lambda': 0.00431546372147837}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:12,210] Trial 124 finished with value: 10.016151423288072 and parameters: {'n_estimators': 922, 'learning_rate': 0.09640420345646215, 'max_depth': 3, 'subsample': 0.5451528863275222, 'colsample_bytree': 0.9666945051758352, 'min_child_weight': 6, 'gamma': 2.41017741080928, 'reg_lambda': 0.0016239046045004664}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:14,655] Trial 125 pruned.
# [I 2026-03-12 16:59:15,477] Trial 126 finished with value: 9.938462058996285 and parameters: {'n_estimators': 816, 'learning_rate': 0.11797056388022818, 'max_depth': 3, 'subsample': 0.5885300564352263, 'colsample_bytree': 0.9297751340402548, 'min_child_weight': 5, 'gamma': 4.484765510253652, 'reg_lambda': 0.0020553578882835833}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:16,192] Trial 127 finished with value: 10.116545055805993 and parameters: {'n_estimators': 814, 'learning_rate': 0.11462561537005192, 'max_depth': 3, 'subsample': 0.5951311434426299, 'colsample_bytree': 0.9190122156664483, 'min_child_weight': 5, 'gamma': 4.121917738738545, 'reg_lambda': 0.0019099645271102319}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:17,000] Trial 128 pruned.
# [I 2026-03-12 16:59:17,571] Trial 129 pruned.
# [I 2026-03-12 16:59:18,313] Trial 130 finished with value: 9.973123571922509 and parameters: {'n_estimators': 774, 'learning_rate': 0.10441606200002132, 'max_depth': 3, 'subsample': 0.6105148651233048, 'colsample_bytree': 0.987268090796136, 'min_child_weight': 8, 'gamma': 0.7654353593360255, 'reg_lambda': 0.002023753520716379}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:19,139] Trial 131 finished with value: 10.23129641173346 and parameters: {'n_estimators': 773, 'learning_rate': 0.1028647674440435, 'max_depth': 3, 'subsample': 0.6096540731649395, 'colsample_bytree': 0.9848926043164303, 'min_child_weight': 8, 'gamma': 0.6130805259802544, 'reg_lambda': 0.002263072878493781}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:19,924] Trial 132 pruned.
# [I 2026-03-12 16:59:20,621] Trial 133 pruned.
# [I 2026-03-12 16:59:21,204] Trial 134 pruned.
# [I 2026-03-12 16:59:21,874] Trial 135 finished with value: 10.171682569531136 and parameters: {'n_estimators': 799, 'learning_rate': 0.10506907690664403, 'max_depth': 3, 'subsample': 0.5907872871793926, 'colsample_bytree': 0.9792997882625118, 'min_child_weight': 5, 'gamma': 0.8690799628126624, 'reg_lambda': 0.0036142282775639034}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:23,136] Trial 136 finished with value: 10.179376259143387 and parameters: {'n_estimators': 750, 'learning_rate': 0.08748599870841187, 'max_depth': 4, 'subsample': 0.7099074798467047, 'colsample_bytree': 0.9582583074931136, 'min_child_weight': 7, 'gamma': 3.4520564587058407, 'reg_lambda': 0.001000408066047429}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:24,003] Trial 137 finished with value: 9.94648015394934 and parameters: {'n_estimators': 648, 'learning_rate': 0.0697256771199677, 'max_depth': 3, 'subsample': 0.5195755723557844, 'colsample_bytree': 0.9900329317774144, 'min_child_weight': 8, 'gamma': 1.785128907591199, 'reg_lambda': 0.001667804368044524}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:24,809] Trial 138 finished with value: 10.099229035983019 and parameters: {'n_estimators': 645, 'learning_rate': 0.05907967827709261, 'max_depth': 3, 'subsample': 0.9831551376301825, 'colsample_bytree': 0.9895664420547982, 'min_child_weight': 8, 'gamma': 1.3605535491419936, 'reg_lambda': 0.0016238091069664734}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:25,650] Trial 139 finished with value: 9.902142102370954 and parameters: {'n_estimators': 698, 'learning_rate': 0.07024543429022029, 'max_depth': 3, 'subsample': 0.5093401392049343, 'colsample_bytree': 0.9995666879943872, 'min_child_weight': 8, 'gamma': 1.1787405367729251, 'reg_lambda': 0.001385026488731872}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:26,328] Trial 140 pruned.
# [I 2026-03-12 16:59:26,921] Trial 141 finished with value: 10.040317586054243 and parameters: {'n_estimators': 615, 'learning_rate': 0.07501089859116486, 'max_depth': 3, 'subsample': 0.5106095422266991, 'colsample_bytree': 0.9898009299296163, 'min_child_weight': 8, 'gamma': 0.48309324120711183, 'reg_lambda': 0.0017981400421144527}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:27,497] Trial 142 finished with value: 9.732163041102547 and parameters: {'n_estimators': 662, 'learning_rate': 0.10673238861427325, 'max_depth': 3, 'subsample': 0.5002953955915749, 'colsample_bytree': 0.9767926472325926, 'min_child_weight': 8, 'gamma': 1.1877367694649927, 'reg_lambda': 0.0022162916399559346}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:29,328] Trial 143 pruned.
# [I 2026-03-12 16:59:30,545] Trial 144 pruned.
# [I 2026-03-12 16:59:31,412] Trial 145 finished with value: 10.087096800274072 and parameters: {'n_estimators': 674, 'learning_rate': 0.14218244597954352, 'max_depth': 3, 'subsample': 0.5275956566995812, 'colsample_bytree': 0.9906886553529299, 'min_child_weight': 8, 'gamma': 1.148522672301875, 'reg_lambda': 0.0011756686247065935}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:32,090] Trial 146 pruned.
# [I 2026-03-12 16:59:32,580] Trial 147 finished with value: 9.745556322308312 and parameters: {'n_estimators': 694, 'learning_rate': 0.13120793361934607, 'max_depth': 3, 'subsample': 0.5189472549096042, 'colsample_bytree': 0.9991511209255552, 'min_child_weight': 7, 'gamma': 0.9606016362442058, 'reg_lambda': 0.002158289104655655}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:33,095] Trial 148 pruned.
# [I 2026-03-12 16:59:33,672] Trial 149 pruned.
# [I 2026-03-12 16:59:34,680] Trial 150 finished with value: 9.72119644766808 and parameters: {'n_estimators': 724, 'learning_rate': 0.10572982489771517, 'max_depth': 3, 'subsample': 0.539084996591804, 'colsample_bytree': 0.9870564104976918, 'min_child_weight': 9, 'gamma': 4.762380390354142, 'reg_lambda': 0.00202757737884343}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:35,332] Trial 151 pruned.
# [I 2026-03-12 16:59:35,857] Trial 152 finished with value: 9.907962235335313 and parameters: {'n_estimators': 705, 'learning_rate': 0.12569716428690192, 'max_depth': 3, 'subsample': 0.5196132535675211, 'colsample_bytree': 0.9678583973651298, 'min_child_weight': 9, 'gamma': 4.731320949943973, 'reg_lambda': 0.0014142113590834594}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:36,479] Trial 153 finished with value: 9.670554558186597 and parameters: {'n_estimators': 663, 'learning_rate': 0.12535861956792224, 'max_depth': 3, 'subsample': 0.5201629245178878, 'colsample_bytree': 0.9680090057014953, 'min_child_weight': 9, 'gamma': 4.71536250258924, 'reg_lambda': 0.001246397198728795}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:37,049] Trial 154 pruned.
# [I 2026-03-12 16:59:37,613] Trial 155 finished with value: 9.791971844862811 and parameters: {'n_estimators': 704, 'learning_rate': 0.17139842566342814, 'max_depth': 3, 'subsample': 0.5383405234838567, 'colsample_bytree': 0.9603628967636832, 'min_child_weight': 10, 'gamma': 4.641991924172816, 'reg_lambda': 0.0012781731085379992}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:38,291] Trial 156 finished with value: 9.77909281932371 and parameters: {'n_estimators': 711, 'learning_rate': 0.1797969304630384, 'max_depth': 3, 'subsample': 0.5356495476520471, 'colsample_bytree': 0.9594206024740537, 'min_child_weight': 10, 'gamma': 4.979362672034969, 'reg_lambda': 0.001241197781788718}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:39,077] Trial 157 pruned.
# [I 2026-03-12 16:59:39,882] Trial 158 pruned.
# [I 2026-03-12 16:59:40,446] Trial 159 pruned.
# [I 2026-03-12 16:59:40,935] Trial 160 pruned.
# [I 2026-03-12 16:59:41,782] Trial 161 finished with value: 9.519165661483493 and parameters: {'n_estimators': 726, 'learning_rate': 0.16915617836296715, 'max_depth': 3, 'subsample': 0.5366701309173326, 'colsample_bytree': 0.9319176712485755, 'min_child_weight': 9, 'gamma': 4.627223296000435, 'reg_lambda': 0.0026617250109900437}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:42,486] Trial 162 pruned.
# [I 2026-03-12 16:59:43,279] Trial 163 pruned.
# [I 2026-03-12 16:59:43,722] Trial 164 pruned.
# [I 2026-03-12 16:59:44,367] Trial 165 finished with value: 9.653821332464117 and parameters: {'n_estimators': 720, 'learning_rate': 0.13082274849104847, 'max_depth': 3, 'subsample': 0.5282861192581773, 'colsample_bytree': 0.9782108595455591, 'min_child_weight': 10, 'gamma': 4.999887923501072, 'reg_lambda': 0.0018444172311632894}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:45,036] Trial 166 finished with value: 10.002828908759813 and parameters: {'n_estimators': 728, 'learning_rate': 0.12907151730563068, 'max_depth': 3, 'subsample': 0.5265637386820659, 'colsample_bytree': 0.9774091025452304, 'min_child_weight': 10, 'gamma': 4.923822548529942, 'reg_lambda': 0.001733989679287525}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:45,595] Trial 167 pruned.
# [I 2026-03-12 16:59:46,311] Trial 168 finished with value: 9.639935814859635 and parameters: {'n_estimators': 683, 'learning_rate': 0.1493435701907168, 'max_depth': 4, 'subsample': 0.5383795306233338, 'colsample_bytree': 0.9995222808903546, 'min_child_weight': 10, 'gamma': 4.885778665330332, 'reg_lambda': 0.0032617190391300414}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:46,910] Trial 169 pruned.
# [I 2026-03-12 16:59:47,595] Trial 170 pruned.
# [I 2026-03-12 16:59:48,020] Trial 171 pruned.
# [I 2026-03-12 16:59:48,646] Trial 172 finished with value: 9.623604868501731 and parameters: {'n_estimators': 686, 'learning_rate': 0.15530953824027371, 'max_depth': 3, 'subsample': 0.5087567284140048, 'colsample_bytree': 0.9549540401311778, 'min_child_weight': 10, 'gamma': 4.749543600563765, 'reg_lambda': 0.0019368277697983064}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:49,327] Trial 173 pruned.
# [I 2026-03-12 16:59:49,879] Trial 174 finished with value: 9.880741377765633 and parameters: {'n_estimators': 709, 'learning_rate': 0.15701446295047794, 'max_depth': 3, 'subsample': 0.5183141812466106, 'colsample_bytree': 0.9806769236659735, 'min_child_weight': 10, 'gamma': 4.790471290517305, 'reg_lambda': 0.003004373205788052}. Best is trial 75 with value: 9.507978796494323.
# [I 2026-03-12 16:59:50,359] Trial 175 pruned.
# [I 2026-03-12 16:59:50,933] Trial 176 finished with value: 9.198442271356035 and parameters: {'n_estimators': 691, 'learning_rate': 0.16363095349025314, 'max_depth': 3, 'subsample': 0.532033513204551, 'colsample_bytree': 0.9853981521738472, 'min_child_weight': 10, 'gamma': 4.900351316593803, 'reg_lambda': 0.003562374988418478}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 16:59:51,503] Trial 177 pruned.
# [I 2026-03-12 16:59:52,113] Trial 178 finished with value: 9.497809803449421 and parameters: {'n_estimators': 673, 'learning_rate': 0.1990576469823218, 'max_depth': 4, 'subsample': 0.5342023266030111, 'colsample_bytree': 0.9793615702824259, 'min_child_weight': 10, 'gamma': 4.879063729889283, 'reg_lambda': 0.003143968886124644}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 16:59:52,587] Trial 179 pruned.
# [I 2026-03-12 16:59:53,167] Trial 180 pruned.
# [I 2026-03-12 16:59:53,786] Trial 181 pruned.
# [I 2026-03-12 16:59:54,669] Trial 182 pruned.
# [I 2026-03-12 16:59:55,151] Trial 183 pruned.
# [I 2026-03-12 16:59:55,665] Trial 184 pruned.
# [I 2026-03-12 16:59:56,151] Trial 185 pruned.
# [I 2026-03-12 16:59:56,650] Trial 186 pruned.
# [I 2026-03-12 16:59:57,228] Trial 187 pruned.
# [I 2026-03-12 16:59:57,715] Trial 188 finished with value: 9.995218745573917 and parameters: {'n_estimators': 669, 'learning_rate': 0.1385885093969416, 'max_depth': 3, 'subsample': 0.5241277047381414, 'colsample_bytree': 0.986016286441649, 'min_child_weight': 9, 'gamma': 4.162337006765268, 'reg_lambda': 0.0020170837975226467}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 16:59:58,156] Trial 189 pruned.
# [I 2026-03-12 16:59:58,598] Trial 190 pruned.
# [I 2026-03-12 16:59:59,333] Trial 191 finished with value: 9.91576991441483 and parameters: {'n_estimators': 697, 'learning_rate': 0.12517211393086136, 'max_depth': 3, 'subsample': 0.5197947901161818, 'colsample_bytree': 0.9646359104978477, 'min_child_weight': 9, 'gamma': 4.721460679684993, 'reg_lambda': 0.0014474726893633225}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 16:59:59,818] Trial 192 pruned.
# [I 2026-03-12 17:00:00,511] Trial 193 finished with value: 9.93449535234195 and parameters: {'n_estimators': 654, 'learning_rate': 0.12605570731715907, 'max_depth': 3, 'subsample': 0.520579181723369, 'colsample_bytree': 0.9691695313217074, 'min_child_weight': 9, 'gamma': 4.643888607611871, 'reg_lambda': 0.00207615235417001}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 17:00:01,089] Trial 194 finished with value: 9.997847987781647 and parameters: {'n_estimators': 758, 'learning_rate': 0.17420827228456526, 'max_depth': 3, 'subsample': 0.5403559911726855, 'colsample_bytree': 0.9827219114163269, 'min_child_weight': 9, 'gamma': 4.875356474639087, 'reg_lambda': 0.0012045957643535322}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 17:00:01,835] Trial 195 pruned.
# [I 2026-03-12 17:00:02,363] Trial 196 finished with value: 9.90015278271053 and parameters: {'n_estimators': 702, 'learning_rate': 0.11731254936750324, 'max_depth': 3, 'subsample': 0.5307376137905387, 'colsample_bytree': 0.9989922188466835, 'min_child_weight': 10, 'gamma': 4.716447730414603, 'reg_lambda': 0.0023497817571593487}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 17:00:02,848] Trial 197 finished with value: 10.024534636242844 and parameters: {'n_estimators': 737, 'learning_rate': 0.11523680709254562, 'max_depth': 3, 'subsample': 0.5541428555737512, 'colsample_bytree': 0.9984276011046792, 'min_child_weight': 10, 'gamma': 4.534251169310435, 'reg_lambda': 0.0023634663825275923}. Best is trial 176 with value: 9.198442271356035.
# [I 2026-03-12 17:00:03,359] Trial 198 pruned.
# [I 2026-03-12 17:00:03,787] Trial 199 pruned.
# Best trial parameters: {'n_estimators': 691, 'learning_rate': 0.16363095349025314, 'max_depth': 3, 'subsample': 0.532033513204551, 'colsample_bytree': 0.9853981521738472, 'min_child_weight': 10, 'gamma': 4.900351316593803, 'reg_lambda': 0.003562374988418478}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# Get the exact number of trees where it peaked
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9853981521738472, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=4.900351316593803, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.16363095349025314,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=103, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# saving best model
joblib.dump(best_model, model_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_O3\\xgboost_model_AL_O3.pkl']

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 9.4178
# MAE:  7.0908
# R2:   0.7546

# %%
log_stat(f"{POLLUTANT} RMSE: ", rmse)
log_stat(f"{POLLUTANT} MAE: ",  mae)
log_stat(f"{POLLUTANT} R2: ",   r2)

# %%
# For Comparrison a naive non ML just guessing that tomorrow's pollutant will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 9.4178
# Naive Baseline RMSE: 9.9238

# %%
log_stat(f"{POLLUTANT}Naive Baseline RMSE: ", naive_rmse)

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title(f"SHAP Feature Importance: What drives {POLLUTANT} Pollution?")
plt.tight_layout()
plt.savefig(output_dir / f"{RUN_ID}_SHAP_Feature_importance.png", bbox_inches='tight')
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.title(f"Feature Importance of {POLLUTANT}")
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
plt.savefig(output_dir / f"{RUN_ID}_Feature_Importance.png", bbox_inches='tight')

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")


# folder for these prediction plots
pred_plot_dir = output_dir / "Predict_vs_Actual_Plots"
pred_plot_dir.mkdir(parents=True, exist_ok=True)

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

station_metrics_list = [] 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])

    station_metrics_list.append({ # add evalutation to list
        'Station': station,
        'RMSE': round(st_rmse, 3),
        'MAE': round(st_mae, 3),
        'R2': round(st_r2, 3)
    })
    
    print(f"Samplingpoint {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label=f'Actual {POLLUTANT}', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label=f'Predicted {POLLUTANT}', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted {POLLUTANT}\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel(f'{POLLUTANT} ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    clean_station_name = str(station).replace(".", "_").replace("/", "_")
    file_name = f"{COUNTRY_CODE}_{POLLUTANT}_{clean_station_name}_predict.png"
    plt.savefig(pred_plot_dir / file_name, dpi=150)

    plt.show()
    plt.close()


# list to df to csv
metrics_df = pd.DataFrame(station_metrics_list)
csv_filename = output_dir / f"{COUNTRY_CODE}_{POLLUTANT}_Every_Station_Metrics.csv"
metrics_df.to_csv(csv_filename, index=False)
# Out:
# RMSE: 9.4178
# MAE:  7.0908
# R2:   0.7546
# Samplingpoint AL/SPO-AL0203A_00007_100 -> RMSE: 10.29 | MAE: 7.98 | R2: 0.64
# Samplingpoint AL/SPO-AL0206A_00007_100 -> RMSE: 8.84 | MAE: 6.58 | R2: 0.83
# Samplingpoint AL/SPO-AL0207A_00007_100 -> RMSE: 9.19 | MAE: 7.12 | R2: 0.81
# Samplingpoint AL/SPO-AL0205A_00007_100 -> RMSE: 8.76 | MAE: 6.43 | R2: 0.63
# Samplingpoint AL/SPO-AL0208A_00007_100 -> RMSE: 9.74 | MAE: 7.18 | R2: 0.52
