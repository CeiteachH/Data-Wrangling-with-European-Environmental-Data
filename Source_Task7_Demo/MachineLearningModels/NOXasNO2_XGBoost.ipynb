# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os
import joblib
from pathlib import Path

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
POLLUTANT = "NOXasNO2"

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
RESULTS_SAVE_FOLDER = os.getenv("RESULTS_SAVE_FOLDER")

# %%
# reading in data
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
# saving results
RUN_ID = f"{COUNTRY_CODE}_{POLLUTANT}"

output_dir = Path(RESULTS_SAVE_FOLDER) / f"Results_{RUN_ID}"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# saving model
model_filename = output_dir / f"xgboost_model_{COUNTRY_CODE}_{POLLUTANT}.pkl"

# %%
def log_stat(name, value): # save statistics as a test file
    with open(output_dir / "data_processing_log.txt", "a") as f:
        f.write(f"{name}: {value}\n")

with open(output_dir / "data_processing_log.txt", "w") as f: # clear log if it exists to start fresh
    f.write(f"Processing Log for {RUN_ID}\n")

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#               Samplingpoint      Start      Value
# 0  AL/SPO-AL0203A_00009_100 2015-01-01  22.259779
# 1  AL/SPO-AL0203A_00009_100 2015-01-02  42.292770
# 2  AL/SPO-AL0203A_00009_100 2015-01-03  54.644078
# 3  AL/SPO-AL0203A_00009_100 2015-01-04  26.254864
# 4  AL/SPO-AL0203A_00009_100 2015-01-05  16.319299
# 5  AL/SPO-AL0203A_00009_100 2015-01-06  24.676605
# 6  AL/SPO-AL0203A_00009_100 2015-01-07  37.663117
# 7  AL/SPO-AL0203A_00009_100 2015-01-08  43.826786
# 8  AL/SPO-AL0203A_00009_100 2015-01-09  42.580091
# 9  AL/SPO-AL0203A_00009_100 2015-01-10  40.737589

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (16068, 11)
#        Start             Samplingpoint      Value  DayOfWeek  Month  \
# 0 2015-01-01  AL/SPO-AL0203A_00009_100  22.259779          3      1
# 1 2015-01-02  AL/SPO-AL0203A_00009_100  42.292770          4      1
# 2 2015-01-03  AL/SPO-AL0203A_00009_100  54.644078          5      1
# 3 2015-01-04  AL/SPO-AL0203A_00009_100  26.254864          6      1
# 4 2015-01-05  AL/SPO-AL0203A_00009_100  16.319299          0      1
# 5 2015-01-06  AL/SPO-AL0203A_00009_100  24.676605          1      1
# 6 2015-01-07  AL/SPO-AL0203A_00009_100  37.663117          2      1
# 7 2015-01-08  AL/SPO-AL0203A_00009_100  43.826786          3      1
# 8 2015-01-09  AL/SPO-AL0203A_00009_100  42.580091          4      1
# 9 2015-01-10  AL/SPO-AL0203A_00009_100  40.737589          5      1
#
#    DayOfYear  IsWeekend      Lag_1      Lag_7  Rolling_Mean_7D     Target
# 0          1          0        NaN        NaN              NaN  42.292770
# 1          2          0  22.259779        NaN              NaN  54.644078
# 2          3          1  42.292770        NaN              NaN  26.254864
# 3          4          1  54.644078        NaN        36.362872  16.319299
# 4          5          0  26.254864        NaN        32.354158  24.676605
# 5          6          0  16.319299        NaN        31.074566  37.663117
# 6          7          0  24.676605        NaN        32.015787  43.826786
# 7          8          0  37.663117  22.259779        35.096788  42.580091
# 8          9          0  43.826786  42.292770        35.137834  40.737589
# 9         10          1  42.580091  54.644078        33.151193  23.127098

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start             Samplingpoint      Value  DayOfWeek  Month  \
# 0 2015-01-01  AL/SPO-AL0203A_00009_100  22.259779          3      1
# 1 2015-01-02  AL/SPO-AL0203A_00009_100  42.292770          4      1
# 2 2015-01-03  AL/SPO-AL0203A_00009_100  54.644078          5      1
# 3 2015-01-04  AL/SPO-AL0203A_00009_100  26.254864          6      1
# 4 2015-01-05  AL/SPO-AL0203A_00009_100  16.319299          0      1
# 5 2015-01-06  AL/SPO-AL0203A_00009_100  24.676605          1      1
# 6 2015-01-07  AL/SPO-AL0203A_00009_100  37.663117          2      1
# 7 2015-01-08  AL/SPO-AL0203A_00009_100  43.826786          3      1
# 8 2015-01-09  AL/SPO-AL0203A_00009_100  42.580091          4      1
# 9 2015-01-10  AL/SPO-AL0203A_00009_100  40.737589          5      1
#
#    DayOfYear  IsWeekend      Lag_1      Lag_7  Rolling_Mean_7D     Target
# 0          1          0        NaN        NaN              NaN  42.292770
# 1          2          0  22.259779        NaN              NaN  54.644078
# 2          3          1  42.292770        NaN              NaN  26.254864
# 3          4          1  54.644078        NaN        36.362872  16.319299
# 4          5          0  26.254864        NaN        32.354158  24.676605
# 5          6          0  16.319299        NaN        31.074566  37.663117
# 6          7          0  24.676605        NaN        32.015787  43.826786
# 7          8          0  37.663117  22.259779        35.096788  42.580091
# 8          9          0  43.826786  42.292770        35.137834  40.737589
# 9         10          1  42.580091  54.644078        33.151193  23.127098
# Start                0
# Samplingpoint        0
# Value               98
# DayOfWeek            0
# Month                0
# DayOfYear            0
# IsWeekend            0
# Lag_1              185
# Lag_7              530
# Rolling_Mean_7D    283
# Target               0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (5699, 9), Val shape: (46, 9), Test shape: (2253, 9)

# %%
# save features 
feature_names = list(X_train.columns)
features_filename = output_dir / f"xgboost_features_{COUNTRY_CODE}_{POLLUTANT}.pkl"
joblib.dump(feature_names, features_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_NOXasNO2\\xgboost_features_AL_NOXasNO2.pkl']

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 16:45:50,924] A new study created in memory with name: no-name-4a5c3345-9cd6-49fb-9f05-5fc7298c7fce
# [I 2026-03-12 16:45:52,205] Trial 0 finished with value: 10.264296321828665 and parameters: {'n_estimators': 632, 'learning_rate': 0.04590370321684215, 'max_depth': 5, 'subsample': 0.6654023569033164, 'colsample_bytree': 0.638272753290928, 'min_child_weight': 5, 'gamma': 1.1563692372231593, 'reg_lambda': 0.004274617193631039}. Best is trial 0 with value: 10.264296321828665.
# [I 2026-03-12 16:45:54,080] Trial 1 finished with value: 10.510455476173142 and parameters: {'n_estimators': 617, 'learning_rate': 0.05963275716973637, 'max_depth': 12, 'subsample': 0.5260137802756559, 'colsample_bytree': 0.712200552195646, 'min_child_weight': 4, 'gamma': 1.9466187038150622, 'reg_lambda': 0.020473371986944294}. Best is trial 0 with value: 10.264296321828665.
# [I 2026-03-12 16:45:54,673] Trial 2 finished with value: 10.715723481363405 and parameters: {'n_estimators': 956, 'learning_rate': 0.1788742533414217, 'max_depth': 8, 'subsample': 0.5219904710746529, 'colsample_bytree': 0.8414813690777196, 'min_child_weight': 1, 'gamma': 1.2155936412956936, 'reg_lambda': 4.312242564091031}. Best is trial 0 with value: 10.264296321828665.
# [I 2026-03-12 16:45:54,981] Trial 3 finished with value: 10.610246619085387 and parameters: {'n_estimators': 188, 'learning_rate': 0.17984801923038082, 'max_depth': 6, 'subsample': 0.5362814650728309, 'colsample_bytree': 0.6372485978310487, 'min_child_weight': 10, 'gamma': 0.053655445797466395, 'reg_lambda': 0.6247780056908868}. Best is trial 0 with value: 10.264296321828665.
# [I 2026-03-12 16:45:55,761] Trial 4 finished with value: 10.707114457428712 and parameters: {'n_estimators': 443, 'learning_rate': 0.09727992646469293, 'max_depth': 9, 'subsample': 0.5737642777594508, 'colsample_bytree': 0.7592490409930981, 'min_child_weight': 4, 'gamma': 2.7983877783883804, 'reg_lambda': 0.15058602554401665}. Best is trial 0 with value: 10.264296321828665.
# [I 2026-03-12 16:45:56,208] Trial 5 finished with value: 10.483840815828925 and parameters: {'n_estimators': 952, 'learning_rate': 0.1892980703768429, 'max_depth': 8, 'subsample': 0.9572950006825021, 'colsample_bytree': 0.7762644829721405, 'min_child_weight': 5, 'gamma': 1.303768848421785, 'reg_lambda': 7.502590178620779}. Best is trial 0 with value: 10.264296321828665.
# [I 2026-03-12 16:45:57,725] Trial 6 finished with value: 10.061293755066231 and parameters: {'n_estimators': 630, 'learning_rate': 0.019521359561731996, 'max_depth': 5, 'subsample': 0.5502169194500521, 'colsample_bytree': 0.9465385030972128, 'min_child_weight': 4, 'gamma': 4.249892702514201, 'reg_lambda': 7.579384158329583}. Best is trial 6 with value: 10.061293755066231.
# [I 2026-03-12 16:45:58,310] Trial 7 finished with value: 9.82802443787804 and parameters: {'n_estimators': 1186, 'learning_rate': 0.040631087477099856, 'max_depth': 4, 'subsample': 0.7929055852288531, 'colsample_bytree': 0.9049945045620467, 'min_child_weight': 9, 'gamma': 2.1380764355151776, 'reg_lambda': 0.25822891342010107}. Best is trial 7 with value: 9.82802443787804.
# [I 2026-03-12 16:45:59,966] Trial 8 pruned.
# [I 2026-03-12 16:46:00,454] Trial 9 finished with value: 10.125839428681806 and parameters: {'n_estimators': 537, 'learning_rate': 0.13083325340075583, 'max_depth': 5, 'subsample': 0.510745002741028, 'colsample_bytree': 0.7076168898775608, 'min_child_weight': 6, 'gamma': 3.419222865085691, 'reg_lambda': 0.1529931444390793}. Best is trial 7 with value: 9.82802443787804.
# [I 2026-03-12 16:46:03,946] Trial 10 finished with value: 9.766270999379234 and parameters: {'n_estimators': 1187, 'learning_rate': 0.005114749631567471, 'max_depth': 3, 'subsample': 0.8573635411505073, 'colsample_bytree': 0.9998118515351, 'min_child_weight': 10, 'gamma': 2.9682742546200025, 'reg_lambda': 0.001144153344348137}. Best is trial 10 with value: 9.766270999379234.
# [I 2026-03-12 16:46:07,819] Trial 11 finished with value: 9.769404937893542 and parameters: {'n_estimators': 1179, 'learning_rate': 0.005477011083288796, 'max_depth': 3, 'subsample': 0.8563347522679271, 'colsample_bytree': 0.9999171290163194, 'min_child_weight': 10, 'gamma': 2.9989748808166192, 'reg_lambda': 0.0024966137196556814}. Best is trial 10 with value: 9.766270999379234.
# [I 2026-03-12 16:46:13,400] Trial 12 finished with value: 9.76870268573759 and parameters: {'n_estimators': 1158, 'learning_rate': 0.005036313062241343, 'max_depth': 3, 'subsample': 0.8662773811234005, 'colsample_bytree': 0.9961650689804517, 'min_child_weight': 8, 'gamma': 3.248748746044504, 'reg_lambda': 0.0010212486473194816}. Best is trial 10 with value: 9.766270999379234.
# [I 2026-03-12 16:46:18,934] Trial 13 finished with value: 9.763110867020664 and parameters: {'n_estimators': 932, 'learning_rate': 0.005033743983371325, 'max_depth': 3, 'subsample': 0.906453715178393, 'colsample_bytree': 0.8465629922234991, 'min_child_weight': 8, 'gamma': 3.616382698449109, 'reg_lambda': 0.0011073401307779662}. Best is trial 13 with value: 9.763110867020664.
# [I 2026-03-12 16:46:20,487] Trial 14 pruned.
# [I 2026-03-12 16:46:22,844] Trial 15 pruned.
# [I 2026-03-12 16:46:26,034] Trial 16 pruned.
# [I 2026-03-12 16:46:27,714] Trial 17 pruned.
# [I 2026-03-12 16:46:34,618] Trial 18 pruned.
# [I 2026-03-12 16:46:36,003] Trial 19 finished with value: 9.874618712087452 and parameters: {'n_estimators': 806, 'learning_rate': 0.01755546360016725, 'max_depth': 4, 'subsample': 0.8956717152402522, 'colsample_bytree': 0.8078505696764081, 'min_child_weight': 10, 'gamma': 3.629759852101467, 'reg_lambda': 0.006884437381939644}. Best is trial 13 with value: 9.763110867020664.
# [I 2026-03-12 16:46:37,902] Trial 20 pruned.
# [I 2026-03-12 16:46:41,162] Trial 21 finished with value: 9.761706393899146 and parameters: {'n_estimators': 1128, 'learning_rate': 0.005629530968205843, 'max_depth': 3, 'subsample': 0.8524485369040136, 'colsample_bytree': 0.9629204453994097, 'min_child_weight': 8, 'gamma': 3.1141432095836152, 'reg_lambda': 0.0017871614072741881}. Best is trial 21 with value: 9.761706393899146.
# [I 2026-03-12 16:46:43,921] Trial 22 finished with value: 9.748903789393713 and parameters: {'n_estimators': 1088, 'learning_rate': 0.008058760178893265, 'max_depth': 3, 'subsample': 0.8157494490488733, 'colsample_bytree': 0.959196154983378, 'min_child_weight': 7, 'gamma': 2.788738610928054, 'reg_lambda': 0.0031672032631643006}. Best is trial 22 with value: 9.748903789393713.
# [I 2026-03-12 16:46:45,213] Trial 23 pruned.
# [I 2026-03-12 16:46:48,506] Trial 24 finished with value: 9.757222994271046 and parameters: {'n_estimators': 769, 'learning_rate': 0.00734599975979602, 'max_depth': 3, 'subsample': 0.7371794698692009, 'colsample_bytree': 0.9463455843114749, 'min_child_weight': 6, 'gamma': 3.849902027885015, 'reg_lambda': 0.013482752512210495}. Best is trial 22 with value: 9.748903789393713.
# [I 2026-03-12 16:46:50,719] Trial 25 pruned.
# [I 2026-03-12 16:46:54,459] Trial 26 pruned.
# [I 2026-03-12 16:46:56,936] Trial 27 pruned.
# [I 2026-03-12 16:47:00,014] Trial 28 finished with value: 9.74769487474427 and parameters: {'n_estimators': 1007, 'learning_rate': 0.009738577325940394, 'max_depth': 3, 'subsample': 0.614978058654535, 'colsample_bytree': 0.9692426049996986, 'min_child_weight': 3, 'gamma': 2.5453572510068003, 'reg_lambda': 0.003923261384351917}. Best is trial 28 with value: 9.74769487474427.
# [I 2026-03-12 16:47:01,647] Trial 29 pruned.
# [I 2026-03-12 16:47:03,251] Trial 30 pruned.
# [I 2026-03-12 16:47:07,439] Trial 31 finished with value: 9.729825022679044 and parameters: {'n_estimators': 1102, 'learning_rate': 0.0066760643556669315, 'max_depth': 3, 'subsample': 0.6243146090261665, 'colsample_bytree': 0.9689060299117259, 'min_child_weight': 5, 'gamma': 2.315264026919668, 'reg_lambda': 0.002271713877017994}. Best is trial 31 with value: 9.729825022679044.
# [I 2026-03-12 16:47:10,915] Trial 32 finished with value: 9.736716164365784 and parameters: {'n_estimators': 1088, 'learning_rate': 0.007360614335470876, 'max_depth': 3, 'subsample': 0.6392616974794091, 'colsample_bytree': 0.975310090650237, 'min_child_weight': 5, 'gamma': 2.144679578380864, 'reg_lambda': 0.005451324896244045}. Best is trial 31 with value: 9.729825022679044.
# [I 2026-03-12 16:47:13,908] Trial 33 pruned.
# [I 2026-03-12 16:47:15,959] Trial 34 pruned.
# [I 2026-03-12 16:47:18,719] Trial 35 pruned.
# [I 2026-03-12 16:47:20,813] Trial 36 finished with value: 9.720996152205513 and parameters: {'n_estimators': 1114, 'learning_rate': 0.024159049341812393, 'max_depth': 3, 'subsample': 0.5599980384243779, 'colsample_bytree': 0.691970193243011, 'min_child_weight': 5, 'gamma': 2.079148801020118, 'reg_lambda': 0.0056275273323146005}. Best is trial 36 with value: 9.720996152205513.
# [I 2026-03-12 16:47:22,006] Trial 37 pruned.
# [I 2026-03-12 16:47:23,334] Trial 38 pruned.
# [I 2026-03-12 16:47:23,921] Trial 39 pruned.
# [I 2026-03-12 16:47:24,466] Trial 40 pruned.
# [I 2026-03-12 16:47:28,051] Trial 41 finished with value: 9.75136812677899 and parameters: {'n_estimators': 1091, 'learning_rate': 0.006407736920780511, 'max_depth': 3, 'subsample': 0.6139863246850096, 'colsample_bytree': 0.7463890499757831, 'min_child_weight': 4, 'gamma': 2.721003583090311, 'reg_lambda': 0.0020604647865407276}. Best is trial 36 with value: 9.720996152205513.
# [I 2026-03-12 16:47:29,301] Trial 42 pruned.
# [I 2026-03-12 16:47:31,432] Trial 43 finished with value: 9.723450169282042 and parameters: {'n_estimators': 1026, 'learning_rate': 0.01189139235053879, 'max_depth': 3, 'subsample': 0.6342087719185285, 'colsample_bytree': 0.9846665407188984, 'min_child_weight': 3, 'gamma': 2.4096181001790637, 'reg_lambda': 0.0017481778504220094}. Best is trial 36 with value: 9.720996152205513.
# [I 2026-03-12 16:47:32,611] Trial 44 pruned.
# [I 2026-03-12 16:47:33,633] Trial 45 pruned.
# [I 2026-03-12 16:47:35,504] Trial 46 pruned.
# [I 2026-03-12 16:47:36,241] Trial 47 pruned.
# [I 2026-03-12 16:47:37,568] Trial 48 finished with value: 9.698757306738232 and parameters: {'n_estimators': 844, 'learning_rate': 0.01753629205297568, 'max_depth': 3, 'subsample': 0.6263934274691192, 'colsample_bytree': 0.9808196617450099, 'min_child_weight': 4, 'gamma': 1.138824497428781, 'reg_lambda': 0.0015573200078404657}. Best is trial 48 with value: 9.698757306738232.
# [I 2026-03-12 16:47:39,141] Trial 49 pruned.
# [I 2026-03-12 16:47:39,877] Trial 50 pruned.
# [I 2026-03-12 16:47:40,910] Trial 51 finished with value: 9.67866409079196 and parameters: {'n_estimators': 1062, 'learning_rate': 0.021968264484830843, 'max_depth': 3, 'subsample': 0.7061610568901557, 'colsample_bytree': 0.9814212802230851, 'min_child_weight': 4, 'gamma': 2.013107330229622, 'reg_lambda': 0.002314576886293574}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:42,057] Trial 52 finished with value: 9.70349527631125 and parameters: {'n_estimators': 831, 'learning_rate': 0.030761035578393915, 'max_depth': 3, 'subsample': 0.7115202726541293, 'colsample_bytree': 0.9866836996407377, 'min_child_weight': 4, 'gamma': 2.0036938085568177, 'reg_lambda': 0.0023414175499123593}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:44,120] Trial 53 finished with value: 9.713186268995758 and parameters: {'n_estimators': 809, 'learning_rate': 0.030894296774370722, 'max_depth': 3, 'subsample': 0.7068989975577834, 'colsample_bytree': 0.9884436462624676, 'min_child_weight': 4, 'gamma': 0.8344576959796985, 'reg_lambda': 0.00100833571388305}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:44,575] Trial 54 pruned.
# [I 2026-03-12 16:47:45,064] Trial 55 pruned.
# [I 2026-03-12 16:47:46,912] Trial 56 pruned.
# [I 2026-03-12 16:47:47,586] Trial 57 pruned.
# [I 2026-03-12 16:47:48,611] Trial 58 finished with value: 9.711248702367442 and parameters: {'n_estimators': 581, 'learning_rate': 0.02984801716851296, 'max_depth': 3, 'subsample': 0.7115545439072948, 'colsample_bytree': 0.8983342873820939, 'min_child_weight': 4, 'gamma': 0.11793608947600198, 'reg_lambda': 0.0014770794826360109}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:49,713] Trial 59 pruned.
# [I 2026-03-12 16:47:50,594] Trial 60 pruned.
# [I 2026-03-12 16:47:52,037] Trial 61 pruned.
# [I 2026-03-12 16:47:52,705] Trial 62 pruned.
# [I 2026-03-12 16:47:53,633] Trial 63 finished with value: 9.703131899841859 and parameters: {'n_estimators': 395, 'learning_rate': 0.028493376029616158, 'max_depth': 3, 'subsample': 0.7004772117427761, 'colsample_bytree': 0.9809113934436638, 'min_child_weight': 3, 'gamma': 0.7495680427034205, 'reg_lambda': 0.0014146922078407827}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:54,102] Trial 64 pruned.
# [I 2026-03-12 16:47:55,043] Trial 65 finished with value: 9.710697223903681 and parameters: {'n_estimators': 402, 'learning_rate': 0.022216205820679336, 'max_depth': 3, 'subsample': 0.7013602774008103, 'colsample_bytree': 0.9332163795451632, 'min_child_weight': 2, 'gamma': 0.8403251257709041, 'reg_lambda': 0.003429558374121853}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:55,749] Trial 66 finished with value: 9.692662118202069 and parameters: {'n_estimators': 418, 'learning_rate': 0.04803058915602397, 'max_depth': 3, 'subsample': 0.7040571337093917, 'colsample_bytree': 0.9254584841458646, 'min_child_weight': 2, 'gamma': 0.6885820833924032, 'reg_lambda': 0.0032784005451916513}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:56,016] Trial 67 pruned.
# [I 2026-03-12 16:47:56,556] Trial 68 pruned.
# [I 2026-03-12 16:47:57,014] Trial 69 pruned.
# [I 2026-03-12 16:47:57,720] Trial 70 finished with value: 9.720357890346179 and parameters: {'n_estimators': 414, 'learning_rate': 0.04541300697166698, 'max_depth': 3, 'subsample': 0.7416364414613892, 'colsample_bytree': 0.9381033805066542, 'min_child_weight': 2, 'gamma': 1.0585534671875276, 'reg_lambda': 0.0035494156637208636}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:47:58,202] Trial 71 pruned.
# [I 2026-03-12 16:47:58,606] Trial 72 pruned.
# [I 2026-03-12 16:48:00,358] Trial 73 finished with value: 9.730667251996056 and parameters: {'n_estimators': 491, 'learning_rate': 0.018152385849954027, 'max_depth': 3, 'subsample': 0.7271505155888884, 'colsample_bytree': 0.9435600054151968, 'min_child_weight': 3, 'gamma': 0.4480115416605233, 'reg_lambda': 0.0013799472526367824}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:48:00,974] Trial 74 pruned.
# [I 2026-03-12 16:48:01,784] Trial 75 pruned.
# [I 2026-03-12 16:48:02,689] Trial 76 finished with value: 9.70156331355366 and parameters: {'n_estimators': 597, 'learning_rate': 0.03907376804314626, 'max_depth': 3, 'subsample': 0.7497613096225837, 'colsample_bytree': 0.9695309075187235, 'min_child_weight': 3, 'gamma': 0.6815794110205889, 'reg_lambda': 0.00401199448421471}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:48:03,222] Trial 77 pruned.
# [I 2026-03-12 16:48:03,472] Trial 78 pruned.
# [I 2026-03-12 16:48:04,206] Trial 79 pruned.
# [I 2026-03-12 16:48:09,419] Trial 80 pruned.
# [I 2026-03-12 16:48:10,071] Trial 81 pruned.
# [I 2026-03-12 16:48:10,818] Trial 82 pruned.
# [I 2026-03-12 16:48:12,622] Trial 83 finished with value: 9.726980231516201 and parameters: {'n_estimators': 459, 'learning_rate': 0.03235070043841659, 'max_depth': 3, 'subsample': 0.7788817068443459, 'colsample_bytree': 0.9978628212392578, 'min_child_weight': 3, 'gamma': 0.7162559459101097, 'reg_lambda': 0.002095556715303507}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:48:15,345] Trial 84 finished with value: 9.710128647848684 and parameters: {'n_estimators': 756, 'learning_rate': 0.013743361023600305, 'max_depth': 3, 'subsample': 0.7172124897832488, 'colsample_bytree': 0.9129678506528401, 'min_child_weight': 2, 'gamma': 0.928224853343214, 'reg_lambda': 0.0017097366540006066}. Best is trial 51 with value: 9.67866409079196.
# [I 2026-03-12 16:48:16,037] Trial 85 pruned.
# [I 2026-03-12 16:48:16,774] Trial 86 pruned.
# [I 2026-03-12 16:48:17,364] Trial 87 pruned.
# [I 2026-03-12 16:48:18,053] Trial 88 finished with value: 9.673117186789018 and parameters: {'n_estimators': 343, 'learning_rate': 0.03958820207169714, 'max_depth': 3, 'subsample': 0.7352931770372384, 'colsample_bytree': 0.9360445896042244, 'min_child_weight': 3, 'gamma': 1.5206534020964066, 'reg_lambda': 0.002744138312593729}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:18,686] Trial 89 pruned.
# [I 2026-03-12 16:48:19,300] Trial 90 finished with value: 9.720737352144868 and parameters: {'n_estimators': 338, 'learning_rate': 0.05502974979078064, 'max_depth': 3, 'subsample': 0.7344383918384936, 'colsample_bytree': 0.9438861769123617, 'min_child_weight': 2, 'gamma': 1.2712775280120927, 'reg_lambda': 0.0038855660332643475}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:19,804] Trial 91 pruned.
# [I 2026-03-12 16:48:20,391] Trial 92 pruned.
# [I 2026-03-12 16:48:22,076] Trial 93 finished with value: 9.677179052394328 and parameters: {'n_estimators': 906, 'learning_rate': 0.017235490844359692, 'max_depth': 3, 'subsample': 0.6596455056701942, 'colsample_bytree': 0.9297542562861676, 'min_child_weight': 2, 'gamma': 0.32830964059015266, 'reg_lambda': 0.0012228513804034206}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:25,644] Trial 94 finished with value: 9.69328026666637 and parameters: {'n_estimators': 855, 'learning_rate': 0.016013904438742718, 'max_depth': 3, 'subsample': 0.6689890235185564, 'colsample_bytree': 0.9627277614612338, 'min_child_weight': 2, 'gamma': 0.2986025378051278, 'reg_lambda': 0.0012062385535744097}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:26,804] Trial 95 pruned.
# [I 2026-03-12 16:48:29,536] Trial 96 finished with value: 9.696835492171953 and parameters: {'n_estimators': 853, 'learning_rate': 0.015691013080876948, 'max_depth': 3, 'subsample': 0.6646863472093592, 'colsample_bytree': 0.9788573992252856, 'min_child_weight': 2, 'gamma': 0.5824472177826574, 'reg_lambda': 0.0017286971224967536}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:31,149] Trial 97 pruned.
# [I 2026-03-12 16:48:33,877] Trial 98 finished with value: 9.708926260098044 and parameters: {'n_estimators': 856, 'learning_rate': 0.018075579833251018, 'max_depth': 3, 'subsample': 0.6288664786007709, 'colsample_bytree': 0.9518830368411444, 'min_child_weight': 1, 'gamma': 0.6241751042425181, 'reg_lambda': 0.0024062092598485427}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:35,892] Trial 99 pruned.
# [I 2026-03-12 16:48:37,000] Trial 100 pruned.
# [I 2026-03-12 16:48:37,950] Trial 101 pruned.
# [I 2026-03-12 16:48:39,908] Trial 102 finished with value: 9.688019998668429 and parameters: {'n_estimators': 837, 'learning_rate': 0.018605985742920588, 'max_depth': 3, 'subsample': 0.6257728883944338, 'colsample_bytree': 0.9660180915684478, 'min_child_weight': 1, 'gamma': 0.2537568476736404, 'reg_lambda': 0.001688593415081254}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:41,724] Trial 103 finished with value: 9.781683372796047 and parameters: {'n_estimators': 831, 'learning_rate': 0.020492225174553905, 'max_depth': 3, 'subsample': 0.6806220819386984, 'colsample_bytree': 0.9999811053731316, 'min_child_weight': 2, 'gamma': 0.012930839863993349, 'reg_lambda': 4.9871712662777155}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:42,265] Trial 104 pruned.
# [I 2026-03-12 16:48:42,850] Trial 105 pruned.
# [I 2026-03-12 16:48:43,465] Trial 106 finished with value: 9.682563978346792 and parameters: {'n_estimators': 870, 'learning_rate': 0.05052714379326714, 'max_depth': 3, 'subsample': 0.6876342019248536, 'colsample_bytree': 0.9264539385561542, 'min_child_weight': 2, 'gamma': 0.2965330278429603, 'reg_lambda': 0.0011639406870595944}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:43,721] Trial 107 pruned.
# [I 2026-03-12 16:48:45,688] Trial 108 pruned.
# [I 2026-03-12 16:48:46,285] Trial 109 pruned.
# [I 2026-03-12 16:48:46,669] Trial 110 pruned.
# [I 2026-03-12 16:48:47,407] Trial 111 pruned.
# [I 2026-03-12 16:48:48,119] Trial 112 pruned.
# [I 2026-03-12 16:48:48,572] Trial 113 pruned.
# [I 2026-03-12 16:48:48,978] Trial 114 pruned.
# [I 2026-03-12 16:48:49,572] Trial 115 pruned.
# [I 2026-03-12 16:48:50,090] Trial 116 pruned.
# [I 2026-03-12 16:48:51,766] Trial 117 pruned.
# [I 2026-03-12 16:48:53,203] Trial 118 finished with value: 9.698838697676345 and parameters: {'n_estimators': 879, 'learning_rate': 0.027027409376060532, 'max_depth': 3, 'subsample': 0.6507617297516195, 'colsample_bytree': 0.9537789252192393, 'min_child_weight': 3, 'gamma': 0.05332684332669607, 'reg_lambda': 0.001961502630801788}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:54,005] Trial 119 pruned.
# [I 2026-03-12 16:48:54,697] Trial 120 pruned.
# [I 2026-03-12 16:48:55,546] Trial 121 pruned.
# [I 2026-03-12 16:48:57,276] Trial 122 finished with value: 9.687920428979393 and parameters: {'n_estimators': 901, 'learning_rate': 0.024578563439990084, 'max_depth': 3, 'subsample': 0.7026967411481331, 'colsample_bytree': 0.9908810200012858, 'min_child_weight': 3, 'gamma': 0.19603483290358092, 'reg_lambda': 0.0017068802762675982}. Best is trial 88 with value: 9.673117186789018.
# [I 2026-03-12 16:48:59,838] Trial 123 finished with value: 9.669352830722298 and parameters: {'n_estimators': 895, 'learning_rate': 0.023682550770855904, 'max_depth': 3, 'subsample': 0.7045877088123375, 'colsample_bytree': 0.9997300894254487, 'min_child_weight': 3, 'gamma': 0.16979275406048616, 'reg_lambda': 0.0011786213048036232}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:01,713] Trial 124 finished with value: 9.692092365106245 and parameters: {'n_estimators': 908, 'learning_rate': 0.023645700078804302, 'max_depth': 3, 'subsample': 0.7259078097608664, 'colsample_bytree': 0.9991341108936991, 'min_child_weight': 3, 'gamma': 0.232537634213331, 'reg_lambda': 0.0011994278864304166}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:03,617] Trial 125 finished with value: 9.698210222391511 and parameters: {'n_estimators': 893, 'learning_rate': 0.02269185340765325, 'max_depth': 3, 'subsample': 0.6612491345160928, 'colsample_bytree': 0.9974199783559915, 'min_child_weight': 3, 'gamma': 0.17997739932557735, 'reg_lambda': 0.0011613868217186635}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:04,789] Trial 126 finished with value: 9.768940295100716 and parameters: {'n_estimators': 1014, 'learning_rate': 0.022667868657906497, 'max_depth': 3, 'subsample': 0.9622841574566746, 'colsample_bytree': 0.9988236390291935, 'min_child_weight': 2, 'gamma': 0.19577839291627783, 'reg_lambda': 0.0011845491723940422}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:06,331] Trial 127 finished with value: 9.68271967522378 and parameters: {'n_estimators': 917, 'learning_rate': 0.024201240480820427, 'max_depth': 3, 'subsample': 0.7268337354770925, 'colsample_bytree': 0.9916062415920421, 'min_child_weight': 3, 'gamma': 0.32036116729975084, 'reg_lambda': 0.0015904660377191314}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:07,297] Trial 128 pruned.
# [I 2026-03-12 16:49:07,792] Trial 129 pruned.
# [I 2026-03-12 16:49:08,372] Trial 130 pruned.
# [I 2026-03-12 16:49:09,024] Trial 131 pruned.
# [I 2026-03-12 16:49:10,214] Trial 132 pruned.
# [I 2026-03-12 16:49:11,284] Trial 133 pruned.
# [I 2026-03-12 16:49:12,983] Trial 134 pruned.
# [I 2026-03-12 16:49:14,189] Trial 135 pruned.
# [I 2026-03-12 16:49:14,925] Trial 136 pruned.
# [I 2026-03-12 16:49:16,617] Trial 137 pruned.
# [I 2026-03-12 16:49:17,568] Trial 138 pruned.
# [I 2026-03-12 16:49:19,262] Trial 139 pruned.
# [I 2026-03-12 16:49:20,202] Trial 140 pruned.
# [I 2026-03-12 16:49:20,647] Trial 141 pruned.
# [I 2026-03-12 16:49:21,576] Trial 142 pruned.
# [I 2026-03-12 16:49:22,127] Trial 143 pruned.
# [I 2026-03-12 16:49:22,677] Trial 144 pruned.
# [I 2026-03-12 16:49:23,738] Trial 145 pruned.
# [I 2026-03-12 16:49:26,330] Trial 146 finished with value: 9.702621434616415 and parameters: {'n_estimators': 847, 'learning_rate': 0.02685834121908004, 'max_depth': 3, 'subsample': 0.6805229739981467, 'colsample_bytree': 0.9039720886051065, 'min_child_weight': 3, 'gamma': 0.3829745124590991, 'reg_lambda': 0.0019034771460760076}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:29,286] Trial 147 pruned.
# [I 2026-03-12 16:49:30,578] Trial 148 finished with value: 9.702331946482184 and parameters: {'n_estimators': 1029, 'learning_rate': 0.031022056051143273, 'max_depth': 3, 'subsample': 0.7251984100651268, 'colsample_bytree': 0.9207113174701144, 'min_child_weight': 3, 'gamma': 4.730844656902171, 'reg_lambda': 0.0010103359993546125}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:31,919] Trial 149 pruned.
# [I 2026-03-12 16:49:33,941] Trial 150 pruned.
# [I 2026-03-12 16:49:35,576] Trial 151 pruned.
# [I 2026-03-12 16:49:38,046] Trial 152 pruned.
# [I 2026-03-12 16:49:38,764] Trial 153 pruned.
# [I 2026-03-12 16:49:39,735] Trial 154 pruned.
# [I 2026-03-12 16:49:40,099] Trial 155 pruned.
# [I 2026-03-12 16:49:40,815] Trial 156 pruned.
# [I 2026-03-12 16:49:41,193] Trial 157 pruned.
# [I 2026-03-12 16:49:41,878] Trial 158 pruned.
# [I 2026-03-12 16:49:42,623] Trial 159 pruned.
# [I 2026-03-12 16:49:43,370] Trial 160 pruned.
# [I 2026-03-12 16:49:44,424] Trial 161 finished with value: 9.714025991506784 and parameters: {'n_estimators': 1007, 'learning_rate': 0.028130767416511705, 'max_depth': 3, 'subsample': 0.7233136549877455, 'colsample_bytree': 0.9176222511087976, 'min_child_weight': 3, 'gamma': 2.654611056660564, 'reg_lambda': 0.0010608094481399282}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:45,382] Trial 162 pruned.
# [I 2026-03-12 16:49:47,338] Trial 163 pruned.
# [I 2026-03-12 16:49:48,077] Trial 164 pruned.
# [I 2026-03-12 16:49:48,827] Trial 165 pruned.
# [I 2026-03-12 16:49:50,898] Trial 166 pruned.
# [I 2026-03-12 16:49:51,832] Trial 167 finished with value: 9.670560401487753 and parameters: {'n_estimators': 907, 'learning_rate': 0.03949352092754328, 'max_depth': 3, 'subsample': 0.7374470501479855, 'colsample_bytree': 0.9138379691223305, 'min_child_weight': 6, 'gamma': 0.6306893313410441, 'reg_lambda': 0.0020792306140441806}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:52,228] Trial 168 pruned.
# [I 2026-03-12 16:49:52,876] Trial 169 pruned.
# [I 2026-03-12 16:49:53,577] Trial 170 pruned.
# [I 2026-03-12 16:49:54,626] Trial 171 finished with value: 9.68519934170422 and parameters: {'n_estimators': 953, 'learning_rate': 0.04781791209630196, 'max_depth': 3, 'subsample': 0.7362347055983983, 'colsample_bytree': 0.9131040318802683, 'min_child_weight': 3, 'gamma': 0.38401811109253275, 'reg_lambda': 0.0013569210965372616}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:56,817] Trial 172 finished with value: 9.70476070190318 and parameters: {'n_estimators': 934, 'learning_rate': 0.04659066894252849, 'max_depth': 3, 'subsample': 0.7336492299009815, 'colsample_bytree': 0.938608014941707, 'min_child_weight': 6, 'gamma': 0.41893653037204115, 'reg_lambda': 0.0015464491922687884}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:49:57,614] Trial 173 pruned.
# [I 2026-03-12 16:49:58,303] Trial 174 pruned.
# [I 2026-03-12 16:49:58,800] Trial 175 pruned.
# [I 2026-03-12 16:49:59,266] Trial 176 pruned.
# [I 2026-03-12 16:50:00,156] Trial 177 pruned.
# [I 2026-03-12 16:50:01,228] Trial 178 pruned.
# [I 2026-03-12 16:50:03,012] Trial 179 pruned.
# [I 2026-03-12 16:50:04,201] Trial 180 pruned.
# [I 2026-03-12 16:50:06,821] Trial 181 finished with value: 9.692724414102054 and parameters: {'n_estimators': 1055, 'learning_rate': 0.026691672329585834, 'max_depth': 3, 'subsample': 0.7239520515668078, 'colsample_bytree': 0.9191491796588238, 'min_child_weight': 3, 'gamma': 4.593936225705789, 'reg_lambda': 0.0010453215031825873}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:50:08,911] Trial 182 pruned.
# [I 2026-03-12 16:50:10,224] Trial 183 pruned.
# [I 2026-03-12 16:50:13,797] Trial 184 finished with value: 9.699277807700193 and parameters: {'n_estimators': 1146, 'learning_rate': 0.021785796573702228, 'max_depth': 3, 'subsample': 0.659255763956787, 'colsample_bytree': 0.9121075748362779, 'min_child_weight': 3, 'gamma': 1.5258692425701785, 'reg_lambda': 0.001416511207710907}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:50:14,578] Trial 185 pruned.
# [I 2026-03-12 16:50:16,847] Trial 186 finished with value: 9.708553642483237 and parameters: {'n_estimators': 1068, 'learning_rate': 0.024559281172737202, 'max_depth': 3, 'subsample': 0.6551953991760596, 'colsample_bytree': 0.9295389739191552, 'min_child_weight': 2, 'gamma': 0.24480258328116727, 'reg_lambda': 0.0016850215983466813}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:50:17,559] Trial 187 pruned.
# [I 2026-03-12 16:50:18,309] Trial 188 pruned.
# [I 2026-03-12 16:50:19,126] Trial 189 pruned.
# [I 2026-03-12 16:50:21,757] Trial 190 pruned.
# [I 2026-03-12 16:50:22,768] Trial 191 pruned.
# [I 2026-03-12 16:50:23,585] Trial 192 finished with value: 9.696173290590924 and parameters: {'n_estimators': 863, 'learning_rate': 0.049805648496903325, 'max_depth': 3, 'subsample': 0.7261737674914087, 'colsample_bytree': 0.977371659667147, 'min_child_weight': 3, 'gamma': 0.5526029740466551, 'reg_lambda': 0.0017410669356190762}. Best is trial 123 with value: 9.669352830722298.
# [I 2026-03-12 16:50:23,934] Trial 193 pruned.
# [I 2026-03-12 16:50:24,217] Trial 194 pruned.
# [I 2026-03-12 16:50:24,569] Trial 195 pruned.
# [I 2026-03-12 16:50:24,923] Trial 196 pruned.
# [I 2026-03-12 16:50:26,022] Trial 197 pruned.
# [I 2026-03-12 16:50:27,222] Trial 198 pruned.
# [I 2026-03-12 16:50:29,321] Trial 199 finished with value: 9.673553300369425 and parameters: {'n_estimators': 1044, 'learning_rate': 0.046984415929136415, 'max_depth': 3, 'subsample': 0.6217420347090119, 'colsample_bytree': 0.9512227182345014, 'min_child_weight': 6, 'gamma': 0.4885501287616558, 'reg_lambda': 0.002383803769205532}. Best is trial 123 with value: 9.669352830722298.
# Best trial parameters: {'n_estimators': 895, 'learning_rate': 0.023682550770855904, 'max_depth': 3, 'subsample': 0.7045877088123375, 'colsample_bytree': 0.9997300894254487, 'min_child_weight': 3, 'gamma': 0.16979275406048616, 'reg_lambda': 0.0011786213048036232}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# Get the exact number of trees where it peaked
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9997300894254487, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.16979275406048616, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.023682550770855904,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=178, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# saving best model
joblib.dump(best_model, model_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_NOXasNO2\\xgboost_model_AL_NOXasNO2.pkl']

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 51.5902
# MAE:  10.1867
# R2:   0.1842

# %%
log_stat(f"{POLLUTANT} RMSE: ", rmse)
log_stat(f"{POLLUTANT} MAE: ",  mae)
log_stat(f"{POLLUTANT} R2: ",   r2)

# %%
# For Comparrison a naive non ML just guessing that tomorrow's pollutant will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 51.5902
# Naive Baseline RMSE: 72.3062

# %%
log_stat(f"{POLLUTANT}Naive Baseline RMSE: ", naive_rmse)

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title(f"SHAP Feature Importance: What drives {POLLUTANT} Pollution?")
plt.tight_layout()
plt.savefig(output_dir / f"{RUN_ID}_SHAP_Feature_importance.png", bbox_inches='tight')
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.title(f"Feature Importance of {POLLUTANT}")
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
plt.savefig(output_dir / f"{RUN_ID}_Feature_Importance.png", bbox_inches='tight')

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")


# folder for these prediction plots
pred_plot_dir = output_dir / "Predict_vs_Actual_Plots"
pred_plot_dir.mkdir(parents=True, exist_ok=True)

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

station_metrics_list = [] 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])

    station_metrics_list.append({ # add evalutation to list
        'Station': station,
        'RMSE': round(st_rmse, 3),
        'MAE': round(st_mae, 3),
        'R2': round(st_r2, 3)
    })
    
    print(f"Samplingpoint {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label=f'Actual {POLLUTANT}', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label=f'Predicted {POLLUTANT}', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted {POLLUTANT}\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel(f'{POLLUTANT} ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    clean_station_name = str(station).replace(".", "_").replace("/", "_")
    file_name = f"{COUNTRY_CODE}_{POLLUTANT}_{clean_station_name}_predict.png"
    plt.savefig(pred_plot_dir / file_name, dpi=150)

    plt.show()
    plt.close()


# list to df to csv
metrics_df = pd.DataFrame(station_metrics_list)
csv_filename = output_dir / f"{COUNTRY_CODE}_{POLLUTANT}_Every_Station_Metrics.csv"
metrics_df.to_csv(csv_filename, index=False)
# Out:
# RMSE: 51.5902
# MAE:  10.1867
# R2:   0.1842
# Samplingpoint AL/SPO-AL0203A_00009_100 -> RMSE: 7.26 | MAE: 5.35 | R2: 0.55
# Samplingpoint AL/SPO-AL0206A_00009_100 -> RMSE: 5.12 | MAE: 3.68 | R2: 0.62
# Samplingpoint AL/SPO-AL0207A_00009_100 -> RMSE: 21.41 | MAE: 13.73 | R2: 0.61
# Samplingpoint AL/SPO-AL0205A_00009_100 -> RMSE: 111.02 | MAE: 21.58 | R2: 0.00
# Samplingpoint AL/SPO-AL0208A_00009_100 -> RMSE: 7.42 | MAE: 5.56 | R2: 0.55
