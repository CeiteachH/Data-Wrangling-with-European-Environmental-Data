# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os
import joblib
from pathlib import Path

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
POLLUTANT = "PM10"

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
RESULTS_SAVE_FOLDER = os.getenv("RESULTS_SAVE_FOLDER")

# %%
# reading in data
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
# saving results
RUN_ID = f"{COUNTRY_CODE}_{POLLUTANT}"

output_dir = Path(RESULTS_SAVE_FOLDER) / f"Results_{RUN_ID}"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# saving model
model_filename = output_dir / f"xgboost_model_{COUNTRY_CODE}_{POLLUTANT}.pkl"

# %%
def log_stat(name, value): # save statistics as a test file
    with open(output_dir / "data_processing_log.txt", "a") as f:
        f.write(f"{name}: {value}\n")

with open(output_dir / "data_processing_log.txt", "w") as f: # clear log if it exists to start fresh
    f.write(f"Processing Log for {RUN_ID}\n")

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#               Samplingpoint      Start  Value
# 0  AL/SPO-AL0201A_00005_100 2013-01-01    NaN
# 1  AL/SPO-AL0201A_00005_100 2013-01-02  21.94
# 2  AL/SPO-AL0201A_00005_100 2013-01-03  31.18
# 3  AL/SPO-AL0201A_00005_100 2013-01-04  16.66
# 4  AL/SPO-AL0201A_00005_100 2013-01-05  27.60
# 5  AL/SPO-AL0201A_00005_100 2013-01-06  86.14
# 6  AL/SPO-AL0201A_00005_100 2013-01-07  46.02
# 7  AL/SPO-AL0201A_00005_100 2013-01-08  12.22
# 8  AL/SPO-AL0201A_00005_100 2013-01-09  36.72
# 9  AL/SPO-AL0201A_00005_100 2013-01-10  27.54

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (14052, 11)
#        Start             Samplingpoint  Value  DayOfWeek  Month  DayOfYear  \
# 0 2013-01-01  AL/SPO-AL0201A_00005_100    NaN          1      1          1
# 1 2013-01-02  AL/SPO-AL0201A_00005_100  21.94          2      1          2
# 2 2013-01-03  AL/SPO-AL0201A_00005_100  31.18          3      1          3
# 3 2013-01-04  AL/SPO-AL0201A_00005_100  16.66          4      1          4
# 4 2013-01-05  AL/SPO-AL0201A_00005_100  27.60          5      1          5
# 5 2013-01-06  AL/SPO-AL0201A_00005_100  86.14          6      1          6
# 6 2013-01-07  AL/SPO-AL0201A_00005_100  46.02          0      1          7
# 7 2013-01-08  AL/SPO-AL0201A_00005_100  12.22          1      1          8
# 8 2013-01-09  AL/SPO-AL0201A_00005_100  36.72          2      1          9
# 9 2013-01-10  AL/SPO-AL0201A_00005_100  27.54          3      1         10
#
#    IsWeekend  Lag_1  Lag_7  Rolling_Mean_7D  Target
# 0          0    NaN    NaN              NaN   21.94
# 1          0    NaN    NaN              NaN   31.18
# 2          0  21.94    NaN              NaN   16.66
# 3          0  31.18    NaN              NaN   27.60
# 4          1  16.66    NaN        24.345000   86.14
# 5          1  27.60    NaN        36.704000   46.02
# 6          0  86.14    NaN        38.256667   12.22
# 7          0  46.02    NaN        34.537143   36.72
# 8          0  12.22  21.94        36.648571   27.54
# 9          0  36.72  31.18        36.128571  112.75

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start             Samplingpoint  Value  DayOfWeek  Month  DayOfYear  \
# 0 2013-01-01  AL/SPO-AL0201A_00005_100    NaN          1      1          1
# 1 2013-01-02  AL/SPO-AL0201A_00005_100  21.94          2      1          2
# 2 2013-01-03  AL/SPO-AL0201A_00005_100  31.18          3      1          3
# 3 2013-01-04  AL/SPO-AL0201A_00005_100  16.66          4      1          4
# 4 2013-01-05  AL/SPO-AL0201A_00005_100  27.60          5      1          5
# 5 2013-01-06  AL/SPO-AL0201A_00005_100  86.14          6      1          6
# 6 2013-01-07  AL/SPO-AL0201A_00005_100  46.02          0      1          7
# 7 2013-01-08  AL/SPO-AL0201A_00005_100  12.22          1      1          8
# 8 2013-01-09  AL/SPO-AL0201A_00005_100  36.72          2      1          9
# 9 2013-01-10  AL/SPO-AL0201A_00005_100  27.54          3      1         10
#
#    IsWeekend  Lag_1  Lag_7  Rolling_Mean_7D  Target
# 0          0    NaN    NaN              NaN   21.94
# 1          0    NaN    NaN              NaN   31.18
# 2          0  21.94    NaN              NaN   16.66
# 3          0  31.18    NaN              NaN   27.60
# 4          1  16.66    NaN        24.345000   86.14
# 5          1  27.60    NaN        36.704000   46.02
# 6          0  86.14    NaN        38.256667   12.22
# 7          0  46.02    NaN        34.537143   36.72
# 8          0  12.22  21.94        36.648571   27.54
# 9          0  36.72  31.18        36.128571  112.75
# Start                0
# Samplingpoint        0
# Value               80
# DayOfWeek            0
# Month                0
# DayOfYear            0
# IsWeekend            0
# Lag_1              148
# Lag_7              438
# Rolling_Mean_7D    240
# Target               0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (4702, 9), Val shape: (6, 9), Test shape: (1876, 9)

# %%
# save features 
feature_names = list(X_train.columns)
features_filename = output_dir / f"xgboost_features_{COUNTRY_CODE}_{POLLUTANT}.pkl"
joblib.dump(feature_names, features_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_PM10\\xgboost_features_AL_PM10.pkl']

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 16:16:27,199] A new study created in memory with name: no-name-d5e5e2e4-07fc-45b4-a8b8-a2f01ab27c44
# [I 2026-03-12 16:16:29,262] Trial 0 finished with value: 18.276840571522882 and parameters: {'n_estimators': 848, 'learning_rate': 0.01757743589393503, 'max_depth': 7, 'subsample': 0.7253616321126973, 'colsample_bytree': 0.734331812714724, 'min_child_weight': 2, 'gamma': 2.070901346601061, 'reg_lambda': 0.03267410232178195}. Best is trial 0 with value: 18.276840571522882.
# [I 2026-03-12 16:16:31,482] Trial 1 finished with value: 18.922331889058707 and parameters: {'n_estimators': 573, 'learning_rate': 0.10456017562148923, 'max_depth': 12, 'subsample': 0.6301935512205523, 'colsample_bytree': 0.7892056822323502, 'min_child_weight': 1, 'gamma': 0.6865942259002694, 'reg_lambda': 0.08943037684487953}. Best is trial 0 with value: 18.276840571522882.
# [I 2026-03-12 16:16:33,988] Trial 2 finished with value: 17.89942500870064 and parameters: {'n_estimators': 556, 'learning_rate': 0.012187061320860778, 'max_depth': 6, 'subsample': 0.830990542248546, 'colsample_bytree': 0.6683766700941187, 'min_child_weight': 8, 'gamma': 1.7580080576491897, 'reg_lambda': 0.05527317322535183}. Best is trial 2 with value: 17.89942500870064.
# [I 2026-03-12 16:16:35,423] Trial 3 finished with value: 18.131492260166375 and parameters: {'n_estimators': 272, 'learning_rate': 0.05474854753818787, 'max_depth': 7, 'subsample': 0.5391794373419831, 'colsample_bytree': 0.7043445266270151, 'min_child_weight': 3, 'gamma': 0.48716669783633204, 'reg_lambda': 5.645898440889677}. Best is trial 2 with value: 17.89942500870064.
# [I 2026-03-12 16:16:36,731] Trial 4 finished with value: 18.26834150578409 and parameters: {'n_estimators': 189, 'learning_rate': 0.16184120807598204, 'max_depth': 11, 'subsample': 0.9609864863945967, 'colsample_bytree': 0.9136395759164315, 'min_child_weight': 9, 'gamma': 3.323063007239115, 'reg_lambda': 7.37352624624002}. Best is trial 2 with value: 17.89942500870064.
# [I 2026-03-12 16:16:37,120] Trial 5 pruned.
# [I 2026-03-12 16:16:39,541] Trial 6 pruned.
# [I 2026-03-12 16:16:41,113] Trial 7 pruned.
# [I 2026-03-12 16:16:42,153] Trial 8 pruned.
# [I 2026-03-12 16:16:42,911] Trial 9 finished with value: 17.942582779095588 and parameters: {'n_estimators': 965, 'learning_rate': 0.0681006637213446, 'max_depth': 4, 'subsample': 0.9451298527271882, 'colsample_bytree': 0.9627544812329034, 'min_child_weight': 5, 'gamma': 2.997659682719784, 'reg_lambda': 0.0022189375338929618}. Best is trial 2 with value: 17.89942500870064.
# [I 2026-03-12 16:16:44,070] Trial 10 pruned.
# [I 2026-03-12 16:16:45,257] Trial 11 finished with value: 17.749333719763698 and parameters: {'n_estimators': 853, 'learning_rate': 0.033699154410610915, 'max_depth': 4, 'subsample': 0.9983705440854083, 'colsample_bytree': 0.8315438887519366, 'min_child_weight': 6, 'gamma': 3.0479205796440216, 'reg_lambda': 0.0014489092480850787}. Best is trial 11 with value: 17.749333719763698.
# [I 2026-03-12 16:16:46,331] Trial 12 pruned.
# [I 2026-03-12 16:16:48,883] Trial 13 pruned.
# [I 2026-03-12 16:16:49,993] Trial 14 pruned.
# [I 2026-03-12 16:16:52,423] Trial 15 pruned.
# [I 2026-03-12 16:16:53,151] Trial 16 pruned.
# [I 2026-03-12 16:16:55,656] Trial 17 pruned.
# [I 2026-03-12 16:16:57,491] Trial 18 pruned.
# [I 2026-03-12 16:16:58,404] Trial 19 finished with value: 17.75968234675447 and parameters: {'n_estimators': 1083, 'learning_rate': 0.040109659503440594, 'max_depth': 4, 'subsample': 0.5498990984929577, 'colsample_bytree': 0.689789244283752, 'min_child_weight': 8, 'gamma': 4.776297138582619, 'reg_lambda': 0.027116777911331928}. Best is trial 11 with value: 17.749333719763698.
# [I 2026-03-12 16:16:59,233] Trial 20 pruned.
# [I 2026-03-12 16:17:00,284] Trial 21 finished with value: 17.8298705287417 and parameters: {'n_estimators': 1007, 'learning_rate': 0.038102543448932866, 'max_depth': 6, 'subsample': 0.6234063408540302, 'colsample_bytree': 0.6823049646015679, 'min_child_weight': 8, 'gamma': 4.896611627223312, 'reg_lambda': 0.08244060863539404}. Best is trial 11 with value: 17.749333719763698.
# [I 2026-03-12 16:17:01,907] Trial 22 finished with value: 17.63901116054998 and parameters: {'n_estimators': 1078, 'learning_rate': 0.03944663932019507, 'max_depth': 4, 'subsample': 0.5907261286361485, 'colsample_bytree': 0.6881690337868542, 'min_child_weight': 9, 'gamma': 4.904344260141678, 'reg_lambda': 0.34268034852297236}. Best is trial 22 with value: 17.63901116054998.
# [I 2026-03-12 16:17:02,578] Trial 23 pruned.
# [I 2026-03-12 16:17:03,258] Trial 24 pruned.
# [I 2026-03-12 16:17:03,921] Trial 25 pruned.
# [I 2026-03-12 16:17:04,601] Trial 26 pruned.
# [I 2026-03-12 16:17:04,926] Trial 27 pruned.
# [I 2026-03-12 16:17:05,312] Trial 28 pruned.
# [I 2026-03-12 16:17:06,199] Trial 29 pruned.
# [I 2026-03-12 16:17:06,925] Trial 30 pruned.
# [I 2026-03-12 16:17:07,704] Trial 31 finished with value: 17.721545416929658 and parameters: {'n_estimators': 1002, 'learning_rate': 0.03611410523767871, 'max_depth': 6, 'subsample': 0.6134930162614614, 'colsample_bytree': 0.6835899880776906, 'min_child_weight': 8, 'gamma': 4.684203738315971, 'reg_lambda': 0.11092437410467222}. Best is trial 22 with value: 17.63901116054998.
# [I 2026-03-12 16:17:08,145] Trial 32 pruned.
# [I 2026-03-12 16:17:08,559] Trial 33 pruned.
# [I 2026-03-12 16:17:08,928] Trial 34 pruned.
# [I 2026-03-12 16:17:09,383] Trial 35 pruned.
# [I 2026-03-12 16:17:10,055] Trial 36 pruned.
# [I 2026-03-12 16:17:10,985] Trial 37 pruned.
# [I 2026-03-12 16:17:11,349] Trial 38 pruned.
# [I 2026-03-12 16:17:11,698] Trial 39 pruned.
# [I 2026-03-12 16:17:11,966] Trial 40 pruned.
# [I 2026-03-12 16:17:12,550] Trial 41 pruned.
# [I 2026-03-12 16:17:13,395] Trial 42 pruned.
# [I 2026-03-12 16:17:13,917] Trial 43 pruned.
# [I 2026-03-12 16:17:14,379] Trial 44 pruned.
# [I 2026-03-12 16:17:14,824] Trial 45 pruned.
# [I 2026-03-12 16:17:15,244] Trial 46 pruned.
# [I 2026-03-12 16:17:16,134] Trial 47 pruned.
# [I 2026-03-12 16:17:16,572] Trial 48 pruned.
# [I 2026-03-12 16:17:16,997] Trial 49 pruned.
# [I 2026-03-12 16:17:17,928] Trial 50 pruned.
# [I 2026-03-12 16:17:19,059] Trial 51 pruned.
# [I 2026-03-12 16:17:21,773] Trial 52 pruned.
# [I 2026-03-12 16:17:23,489] Trial 53 pruned.
# [I 2026-03-12 16:17:24,720] Trial 54 pruned.
# [I 2026-03-12 16:17:25,685] Trial 55 pruned.
# [I 2026-03-12 16:17:26,106] Trial 56 pruned.
# [I 2026-03-12 16:17:26,523] Trial 57 pruned.
# [I 2026-03-12 16:17:27,294] Trial 58 pruned.
# [I 2026-03-12 16:17:27,967] Trial 59 finished with value: 17.544494186852738 and parameters: {'n_estimators': 865, 'learning_rate': 0.037197942090042985, 'max_depth': 4, 'subsample': 0.6765313205932377, 'colsample_bytree': 0.730193593883607, 'min_child_weight': 7, 'gamma': 3.7493263434358837, 'reg_lambda': 1.0492756457796166}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:28,618] Trial 60 finished with value: 17.69214984380522 and parameters: {'n_estimators': 974, 'learning_rate': 0.03518811394879135, 'max_depth': 4, 'subsample': 0.679492511396339, 'colsample_bytree': 0.7119130988466887, 'min_child_weight': 6, 'gamma': 3.622733985953837, 'reg_lambda': 1.2519485555141316}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:29,565] Trial 61 finished with value: 17.562304846870358 and parameters: {'n_estimators': 982, 'learning_rate': 0.03573595044623692, 'max_depth': 4, 'subsample': 0.671633325538625, 'colsample_bytree': 0.732585183260869, 'min_child_weight': 6, 'gamma': 3.5445692784264193, 'reg_lambda': 1.2844299530304961}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:30,292] Trial 62 finished with value: 17.65882867576989 and parameters: {'n_estimators': 873, 'learning_rate': 0.035861785060465765, 'max_depth': 4, 'subsample': 0.7193431385162096, 'colsample_bytree': 0.7268321878453988, 'min_child_weight': 6, 'gamma': 3.822474333860247, 'reg_lambda': 2.9275837580279283}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:31,008] Trial 63 finished with value: 17.67729102132745 and parameters: {'n_estimators': 872, 'learning_rate': 0.033775668581927404, 'max_depth': 4, 'subsample': 0.7161242142225291, 'colsample_bytree': 0.7332323075721827, 'min_child_weight': 5, 'gamma': 3.3085603083628152, 'reg_lambda': 3.3430612348857784}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:31,570] Trial 64 pruned.
# [I 2026-03-12 16:17:32,014] Trial 65 pruned.
# [I 2026-03-12 16:17:32,498] Trial 66 pruned.
# [I 2026-03-12 16:17:32,837] Trial 67 pruned.
# [I 2026-03-12 16:17:33,688] Trial 68 pruned.
# [I 2026-03-12 16:17:34,462] Trial 69 pruned.
# [I 2026-03-12 16:17:35,170] Trial 70 pruned.
# [I 2026-03-12 16:17:35,670] Trial 71 pruned.
# [I 2026-03-12 16:17:36,417] Trial 72 pruned.
# [I 2026-03-12 16:17:37,097] Trial 73 pruned.
# [I 2026-03-12 16:17:37,642] Trial 74 pruned.
# [I 2026-03-12 16:17:38,225] Trial 75 pruned.
# [I 2026-03-12 16:17:38,791] Trial 76 pruned.
# [I 2026-03-12 16:17:40,129] Trial 77 pruned.
# [I 2026-03-12 16:17:40,927] Trial 78 pruned.
# [I 2026-03-12 16:17:41,773] Trial 79 pruned.
# [I 2026-03-12 16:17:42,604] Trial 80 pruned.
# [I 2026-03-12 16:17:43,077] Trial 81 pruned.
# [I 2026-03-12 16:17:43,768] Trial 82 pruned.
# [I 2026-03-12 16:17:44,174] Trial 83 pruned.
# [I 2026-03-12 16:17:44,867] Trial 84 pruned.
# [I 2026-03-12 16:17:45,373] Trial 85 pruned.
# [I 2026-03-12 16:17:45,933] Trial 86 pruned.
# [I 2026-03-12 16:17:46,785] Trial 87 pruned.
# [I 2026-03-12 16:17:47,501] Trial 88 pruned.
# [I 2026-03-12 16:17:48,024] Trial 89 pruned.
# [I 2026-03-12 16:17:48,525] Trial 90 pruned.
# [I 2026-03-12 16:17:49,096] Trial 91 pruned.
# [I 2026-03-12 16:17:49,562] Trial 92 pruned.
# [I 2026-03-12 16:17:49,906] Trial 93 pruned.
# [I 2026-03-12 16:17:50,541] Trial 94 pruned.
# [I 2026-03-12 16:17:51,006] Trial 95 pruned.
# [I 2026-03-12 16:17:51,758] Trial 96 pruned.
# [I 2026-03-12 16:17:52,364] Trial 97 pruned.
# [I 2026-03-12 16:17:52,989] Trial 98 pruned.
# [I 2026-03-12 16:17:53,618] Trial 99 pruned.
# [I 2026-03-12 16:17:54,130] Trial 100 pruned.
# [I 2026-03-12 16:17:54,624] Trial 101 pruned.
# [I 2026-03-12 16:17:55,105] Trial 102 pruned.
# [I 2026-03-12 16:17:55,836] Trial 103 pruned.
# [I 2026-03-12 16:17:56,470] Trial 104 finished with value: 17.595331974618343 and parameters: {'n_estimators': 582, 'learning_rate': 0.04470458182616702, 'max_depth': 4, 'subsample': 0.7270468163877749, 'colsample_bytree': 0.6889816559510383, 'min_child_weight': 8, 'gamma': 3.487137412057509, 'reg_lambda': 0.11425121391714863}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:57,039] Trial 105 finished with value: 17.58516064225246 and parameters: {'n_estimators': 787, 'learning_rate': 0.05659922758128513, 'max_depth': 4, 'subsample': 0.7454190253616416, 'colsample_bytree': 0.6911710320241367, 'min_child_weight': 7, 'gamma': 2.9815826774853766, 'reg_lambda': 0.1543098094962428}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:57,328] Trial 106 pruned.
# [I 2026-03-12 16:17:57,652] Trial 107 pruned.
# [I 2026-03-12 16:17:58,188] Trial 108 pruned.
# [I 2026-03-12 16:17:58,653] Trial 109 pruned.
# [I 2026-03-12 16:17:59,212] Trial 110 finished with value: 17.558160572936536 and parameters: {'n_estimators': 865, 'learning_rate': 0.062464678188179586, 'max_depth': 5, 'subsample': 0.7405083014480535, 'colsample_bytree': 0.7381644063577545, 'min_child_weight': 6, 'gamma': 2.755101624132497, 'reg_lambda': 0.35367121754059644}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:17:59,694] Trial 111 pruned.
# [I 2026-03-12 16:18:00,162] Trial 112 pruned.
# [I 2026-03-12 16:18:00,608] Trial 113 pruned.
# [I 2026-03-12 16:18:01,205] Trial 114 finished with value: 17.585797171267963 and parameters: {'n_estimators': 844, 'learning_rate': 0.05490778252469298, 'max_depth': 4, 'subsample': 0.7259592361865013, 'colsample_bytree': 0.7100011048841487, 'min_child_weight': 7, 'gamma': 3.1272663381670522, 'reg_lambda': 0.5315508894757969}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:18:01,762] Trial 115 finished with value: 17.630910503665447 and parameters: {'n_estimators': 845, 'learning_rate': 0.05758471191825309, 'max_depth': 4, 'subsample': 0.7313354621662821, 'colsample_bytree': 0.7058290791930779, 'min_child_weight': 7, 'gamma': 2.722411302933282, 'reg_lambda': 0.6069485253099681}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:18:02,312] Trial 116 finished with value: 17.63877528929054 and parameters: {'n_estimators': 894, 'learning_rate': 0.07588453780042172, 'max_depth': 4, 'subsample': 0.7262073667392327, 'colsample_bytree': 0.7027459152536674, 'min_child_weight': 7, 'gamma': 2.713977264392798, 'reg_lambda': 0.5779889735542395}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:18:02,788] Trial 117 finished with value: 17.621158126441905 and parameters: {'n_estimators': 846, 'learning_rate': 0.08586927601548043, 'max_depth': 4, 'subsample': 0.7247937991826978, 'colsample_bytree': 0.7118859038910388, 'min_child_weight': 7, 'gamma': 2.5205475853700947, 'reg_lambda': 0.587936419022957}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:18:03,064] Trial 118 pruned.
# [I 2026-03-12 16:18:03,322] Trial 119 pruned.
# [I 2026-03-12 16:18:03,713] Trial 120 pruned.
# [I 2026-03-12 16:18:04,221] Trial 121 finished with value: 17.62462620299721 and parameters: {'n_estimators': 903, 'learning_rate': 0.07740155878319112, 'max_depth': 4, 'subsample': 0.7147071763595406, 'colsample_bytree': 0.7107190250637921, 'min_child_weight': 7, 'gamma': 2.3662816883687308, 'reg_lambda': 0.4474642144239195}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:18:04,503] Trial 122 pruned.
# [I 2026-03-12 16:18:04,871] Trial 123 pruned.
# [I 2026-03-12 16:18:05,168] Trial 124 pruned.
# [I 2026-03-12 16:18:05,591] Trial 125 pruned.
# [I 2026-03-12 16:18:05,868] Trial 126 pruned.
# [I 2026-03-12 16:18:06,187] Trial 127 pruned.
# [I 2026-03-12 16:18:06,486] Trial 128 pruned.
# [I 2026-03-12 16:18:07,088] Trial 129 pruned.
# [I 2026-03-12 16:18:07,400] Trial 130 pruned.
# [I 2026-03-12 16:18:07,681] Trial 131 pruned.
# [I 2026-03-12 16:18:07,976] Trial 132 pruned.
# [I 2026-03-12 16:18:08,287] Trial 133 pruned.
# [I 2026-03-12 16:18:08,604] Trial 134 pruned.
# [I 2026-03-12 16:18:08,838] Trial 135 pruned.
# [I 2026-03-12 16:18:09,319] Trial 136 pruned.
# [I 2026-03-12 16:18:09,731] Trial 137 pruned.
# [I 2026-03-12 16:18:10,195] Trial 138 pruned.
# [I 2026-03-12 16:18:10,502] Trial 139 pruned.
# [I 2026-03-12 16:18:10,824] Trial 140 pruned.
# [I 2026-03-12 16:18:11,307] Trial 141 pruned.
# [I 2026-03-12 16:18:11,714] Trial 142 pruned.
# [I 2026-03-12 16:18:12,106] Trial 143 pruned.
# [I 2026-03-12 16:18:12,726] Trial 144 pruned.
# [I 2026-03-12 16:18:13,273] Trial 145 pruned.
# [I 2026-03-12 16:18:13,560] Trial 146 pruned.
# [I 2026-03-12 16:18:13,930] Trial 147 pruned.
# [I 2026-03-12 16:18:14,550] Trial 148 pruned.
# [I 2026-03-12 16:18:14,996] Trial 149 pruned.
# [I 2026-03-12 16:18:15,291] Trial 150 pruned.
# [I 2026-03-12 16:18:15,685] Trial 151 pruned.
# [I 2026-03-12 16:18:16,106] Trial 152 pruned.
# [I 2026-03-12 16:18:16,764] Trial 153 pruned.
# [I 2026-03-12 16:18:17,282] Trial 154 pruned.
# [I 2026-03-12 16:18:17,609] Trial 155 pruned.
# [I 2026-03-12 16:18:18,007] Trial 156 pruned.
# [I 2026-03-12 16:18:18,519] Trial 157 pruned.
# [I 2026-03-12 16:18:18,926] Trial 158 pruned.
# [I 2026-03-12 16:18:19,488] Trial 159 finished with value: 17.564424026774734 and parameters: {'n_estimators': 903, 'learning_rate': 0.05857500064224496, 'max_depth': 4, 'subsample': 0.6692618550878564, 'colsample_bytree': 0.7302390516629641, 'min_child_weight': 6, 'gamma': 3.7498742734929773, 'reg_lambda': 1.01377871435364}. Best is trial 59 with value: 17.544494186852738.
# [I 2026-03-12 16:18:19,790] Trial 160 pruned.
# [I 2026-03-12 16:18:20,359] Trial 161 finished with value: 17.51488804695775 and parameters: {'n_estimators': 869, 'learning_rate': 0.07114837884612152, 'max_depth': 4, 'subsample': 0.6547412114846813, 'colsample_bytree': 0.7450096204156181, 'min_child_weight': 6, 'gamma': 3.6892646842240504, 'reg_lambda': 1.1105953988178894}. Best is trial 161 with value: 17.51488804695775.
# [I 2026-03-12 16:18:20,797] Trial 162 pruned.
# [I 2026-03-12 16:18:21,265] Trial 163 pruned.
# [I 2026-03-12 16:18:21,621] Trial 164 pruned.
# [I 2026-03-12 16:18:21,999] Trial 165 pruned.
# [I 2026-03-12 16:18:22,294] Trial 166 pruned.
# [I 2026-03-12 16:18:22,609] Trial 167 pruned.
# [I 2026-03-12 16:18:23,110] Trial 168 finished with value: 17.55949635346923 and parameters: {'n_estimators': 341, 'learning_rate': 0.08019561630254501, 'max_depth': 4, 'subsample': 0.7073604653898563, 'colsample_bytree': 0.7649538105546208, 'min_child_weight': 7, 'gamma': 3.620109217722982, 'reg_lambda': 2.951815648348223}. Best is trial 161 with value: 17.51488804695775.
# [I 2026-03-12 16:18:23,540] Trial 169 pruned.
# [I 2026-03-12 16:18:23,868] Trial 170 pruned.
# [I 2026-03-12 16:18:24,375] Trial 171 finished with value: 17.55615387686519 and parameters: {'n_estimators': 247, 'learning_rate': 0.06953438698713803, 'max_depth': 4, 'subsample': 0.7203535067193345, 'colsample_bytree': 0.72399298551921, 'min_child_weight': 7, 'gamma': 3.8039604397297646, 'reg_lambda': 1.7077783494472982}. Best is trial 161 with value: 17.51488804695775.
# [I 2026-03-12 16:18:24,683] Trial 172 pruned.
# [I 2026-03-12 16:18:25,087] Trial 173 pruned.
# [I 2026-03-12 16:18:25,369] Trial 174 pruned.
# [I 2026-03-12 16:18:25,753] Trial 175 pruned.
# [I 2026-03-12 16:18:26,331] Trial 176 finished with value: 17.588033960735437 and parameters: {'n_estimators': 482, 'learning_rate': 0.05692421688876836, 'max_depth': 4, 'subsample': 0.736403665351967, 'colsample_bytree': 0.6986678438394508, 'min_child_weight': 7, 'gamma': 3.829971272467958, 'reg_lambda': 3.235588479695564}. Best is trial 161 with value: 17.51488804695775.
# [I 2026-03-12 16:18:26,781] Trial 177 pruned.
# [I 2026-03-12 16:18:27,110] Trial 178 pruned.
# [I 2026-03-12 16:18:27,447] Trial 179 pruned.
# [I 2026-03-12 16:18:27,882] Trial 180 pruned.
# [I 2026-03-12 16:18:28,313] Trial 181 pruned.
# [I 2026-03-12 16:18:28,653] Trial 182 pruned.
# [I 2026-03-12 16:18:29,303] Trial 183 pruned.
# [I 2026-03-12 16:18:29,618] Trial 184 pruned.
# [I 2026-03-12 16:18:29,959] Trial 185 pruned.
# [I 2026-03-12 16:18:30,613] Trial 186 finished with value: 17.513313265271435 and parameters: {'n_estimators': 239, 'learning_rate': 0.047206743657545305, 'max_depth': 4, 'subsample': 0.7156616798993866, 'colsample_bytree': 0.7411167306460621, 'min_child_weight': 6, 'gamma': 2.4800132729028403, 'reg_lambda': 0.36922739431503376}. Best is trial 186 with value: 17.513313265271435.
# [I 2026-03-12 16:18:30,951] Trial 187 pruned.
# [I 2026-03-12 16:18:31,478] Trial 188 pruned.
# [I 2026-03-12 16:18:32,109] Trial 189 finished with value: 17.52469039628288 and parameters: {'n_estimators': 308, 'learning_rate': 0.05304737703564348, 'max_depth': 4, 'subsample': 0.7375555394023005, 'colsample_bytree': 0.7633681327720566, 'min_child_weight': 6, 'gamma': 2.660242896619106, 'reg_lambda': 0.5627817052171598}. Best is trial 186 with value: 17.513313265271435.
# [I 2026-03-12 16:18:32,407] Trial 190 pruned.
# [I 2026-03-12 16:18:32,948] Trial 191 finished with value: 17.612178776944255 and parameters: {'n_estimators': 325, 'learning_rate': 0.06231654364177965, 'max_depth': 4, 'subsample': 0.741854964836147, 'colsample_bytree': 0.7695007333953227, 'min_child_weight': 6, 'gamma': 2.4741082596557122, 'reg_lambda': 0.6559267252199799}. Best is trial 186 with value: 17.513313265271435.
# [I 2026-03-12 16:18:33,413] Trial 192 pruned.
# [I 2026-03-12 16:18:34,031] Trial 193 finished with value: 17.511747780119197 and parameters: {'n_estimators': 293, 'learning_rate': 0.05968290687100334, 'max_depth': 4, 'subsample': 0.7276910688735931, 'colsample_bytree': 0.7641319881243441, 'min_child_weight': 6, 'gamma': 2.4873852209284784, 'reg_lambda': 0.5030625905828967}. Best is trial 193 with value: 17.511747780119197.
# [I 2026-03-12 16:18:34,363] Trial 194 pruned.
# [I 2026-03-12 16:18:34,649] Trial 195 pruned.
# [I 2026-03-12 16:18:34,987] Trial 196 pruned.
# [I 2026-03-12 16:18:35,319] Trial 197 pruned.
# [I 2026-03-12 16:18:35,979] Trial 198 finished with value: 17.55838033814655 and parameters: {'n_estimators': 312, 'learning_rate': 0.05158880354340898, 'max_depth': 5, 'subsample': 0.7396523457234636, 'colsample_bytree': 0.7677851011048399, 'min_child_weight': 7, 'gamma': 2.4621495706893852, 'reg_lambda': 0.6837315881655508}. Best is trial 193 with value: 17.511747780119197.
# [I 2026-03-12 16:18:36,363] Trial 199 pruned.
# Best trial parameters: {'n_estimators': 293, 'learning_rate': 0.05968290687100334, 'max_depth': 4, 'subsample': 0.7276910688735931, 'colsample_bytree': 0.7641319881243441, 'min_child_weight': 6, 'gamma': 2.4873852209284784, 'reg_lambda': 0.5030625905828967}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# Get the exact number of trees where it peaked
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7641319881243441, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=2.4873852209284784, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05968290687100334,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=6, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=24, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# saving best model
joblib.dump(best_model, model_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_PM10\\xgboost_model_AL_PM10.pkl']

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 17.1879
# MAE:  10.7545
# R2:   0.2357

# %%
log_stat(f"{POLLUTANT} RMSE: ", rmse)
log_stat(f"{POLLUTANT} MAE: ",  mae)
log_stat(f"{POLLUTANT} R2: ",   r2)

# %%
# For Comparrison a naive non ML just guessing that tomorrow's pollutant will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 17.1879
# Naive Baseline RMSE: 20.1843

# %%
log_stat(f"{POLLUTANT}Naive Baseline RMSE: ", naive_rmse)

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title(f"SHAP Feature Importance: What drives {POLLUTANT} Pollution?")
plt.tight_layout()
plt.savefig(output_dir / f"{RUN_ID}_SHAP_Feature_importance.png", bbox_inches='tight')
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.title(f"Feature Importance of {POLLUTANT}")
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
plt.savefig(output_dir / f"{RUN_ID}_Feature_Importance.png", bbox_inches='tight')

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")


# folder for these prediction plots
pred_plot_dir = output_dir / "Predict_vs_Actual_Plots"
pred_plot_dir.mkdir(parents=True, exist_ok=True)

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

station_metrics_list = [] 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])

    station_metrics_list.append({ # add evalutation to list
        'Station': station,
        'RMSE': round(st_rmse, 3),
        'MAE': round(st_mae, 3),
        'R2': round(st_r2, 3)
    })
    
    print(f"Samplingpoint {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label=f'Actual {POLLUTANT}', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label=f'Predicted {POLLUTANT}', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted {POLLUTANT}\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel(f'{POLLUTANT} ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    clean_station_name = str(station).replace(".", "_").replace("/", "_")
    file_name = f"{COUNTRY_CODE}_{POLLUTANT}_{clean_station_name}_predict.png"
    plt.savefig(pred_plot_dir / file_name, dpi=150)

    plt.show()
    plt.close()


# list to df to csv
metrics_df = pd.DataFrame(station_metrics_list)
csv_filename = output_dir / f"{COUNTRY_CODE}_{POLLUTANT}_Every_Station_Metrics.csv"
metrics_df.to_csv(csv_filename, index=False)
# Out:
# RMSE: 17.1879
# MAE:  10.7545
# R2:   0.2357
# Samplingpoint AL/SPO-AL0203A_00005_100 -> RMSE: 25.88 | MAE: 15.67 | R2: 0.22
# Samplingpoint AL/SPO-AL0206A_00005_100 -> RMSE: 12.23 | MAE: 8.73 | R2: 0.26
# Samplingpoint AL/SPO-AL0205A_00005_100 -> RMSE: 12.41 | MAE: 9.06 | R2: 0.19
# Samplingpoint AL/SPO-AL0208A_00005_100 -> RMSE: 12.87 | MAE: 8.97 | R2: 0.06
