# %%
import pandas as pd
import numpy as np  
import xgboost as xgb
import optuna
from optuna_integration import XGBoostPruningCallback
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import shap
from dotenv import load_dotenv
import os
import joblib
from pathlib import Path

# %% [markdown]
# # Establish Country & Pollutant

# %%
load_dotenv()
# Out:
# True

# %%
POLLUTANT = "NO2"

# %%
COUNTRY_CODE = os.getenv("COUNTRY_CODE")   
RESULTS_SAVE_FOLDER = os.getenv("RESULTS_SAVE_FOLDER")

# %%
# reading in data
base_path = os.getenv("BASE_DATA_PATH")
file_name = f"{COUNTRY_CODE}_{POLLUTANT}_Daily_Cleaned.parquet"
file_path = os.path.join(base_path, file_name)

# %%
# saving results
RUN_ID = f"{COUNTRY_CODE}_{POLLUTANT}"

output_dir = Path(RESULTS_SAVE_FOLDER) / f"Results_{RUN_ID}"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
# saving model
model_filename = output_dir / f"xgboost_model_{COUNTRY_CODE}_{POLLUTANT}.pkl"

# %%
df = pd.read_parquet(file_path, engine = 'pyarrow')

# %%
df.head(10)
# Out:
#               Samplingpoint      Start      Value
# 0  AL/SPO-AL0201A_00008_100 2013-01-01  40.829783
# 1  AL/SPO-AL0201A_00008_100 2013-01-02  39.076875
# 2  AL/SPO-AL0201A_00008_100 2013-01-03  43.441250
# 3  AL/SPO-AL0201A_00008_100 2013-01-04  49.670833
# 4  AL/SPO-AL0201A_00008_100 2013-01-05  50.848125
# 5  AL/SPO-AL0201A_00008_100 2013-01-06  42.196667
# 6  AL/SPO-AL0201A_00008_100 2013-01-07  37.556250
# 7  AL/SPO-AL0201A_00008_100 2013-01-08  48.547292
# 8  AL/SPO-AL0201A_00008_100 2013-01-09  49.101042
# 9  AL/SPO-AL0201A_00008_100 2013-01-10  44.490208

# %% [markdown]
# # Machine Learning Preperation - Feature Extraction & Dropping NaN

# %%
df['Start'] = pd.to_datetime(df['Start']) 
df = df.sort_values(by=['Samplingpoint', 'Start']).reset_index(drop=True) # sorting by station and start(date) and resetting index

df['Samplingpoint'] = df['Samplingpoint'].astype('category') # set as a category to use as category feature (can avpid using pd.getdummies onehotencoding and creating more columns), faster processing and less memory usage

# %%
# Extracting time based features
df['DayOfWeek'] = df['Start'].dt.dayofweek
df['Month'] = df['Start'].dt.month
df['DayOfYear'] = df['Start'].dt.dayofyear
df['IsWeekend'] = df['DayOfWeek'].isin([5, 6]).astype(int)

# %%
df['Lag_1'] = df.groupby('Samplingpoint')['Value'].shift(1) 
df['Lag_7'] = df.groupby('Samplingpoint')['Value'].shift(7)

# %%
df = df.set_index('Start') # Need index to be the 'Start'(date) column for rolling with time-based windows to work properly

df['Rolling_Mean_7D'] = df.groupby('Samplingpoint')['Value'].transform(
    lambda x: x.rolling('7D', min_periods=4).mean() # 7d creates rolling window of 7 calendar days instead of last 7 rows
)
df = df.reset_index()

# %%
df['Target'] = df.groupby('Samplingpoint')['Value'].shift(-1) # Target (y), shfts value back by 1 on the indexlevel, to get the next day today

# %%
print(f"Data shape after Feature Engineering {df.shape}")
df.head(10)
# Out:
# Data shape after Feature Engineering (17971, 11)
#        Start             Samplingpoint      Value  DayOfWeek  Month  \
# 0 2013-01-01  AL/SPO-AL0201A_00008_100  40.829783          1      1
# 1 2013-01-02  AL/SPO-AL0201A_00008_100  39.076875          2      1
# 2 2013-01-03  AL/SPO-AL0201A_00008_100  43.441250          3      1
# 3 2013-01-04  AL/SPO-AL0201A_00008_100  49.670833          4      1
# 4 2013-01-05  AL/SPO-AL0201A_00008_100  50.848125          5      1
# 5 2013-01-06  AL/SPO-AL0201A_00008_100  42.196667          6      1
# 6 2013-01-07  AL/SPO-AL0201A_00008_100  37.556250          0      1
# 7 2013-01-08  AL/SPO-AL0201A_00008_100  48.547292          1      1
# 8 2013-01-09  AL/SPO-AL0201A_00008_100  49.101042          2      1
# 9 2013-01-10  AL/SPO-AL0201A_00008_100  44.490208          3      1
#
#    DayOfYear  IsWeekend      Lag_1      Lag_7  Rolling_Mean_7D     Target
# 0          1          0        NaN        NaN              NaN  39.076875
# 1          2          0  40.829783        NaN              NaN  43.441250
# 2          3          0  39.076875        NaN              NaN  49.670833
# 3          4          0  43.441250        NaN        43.254685  50.848125
# 4          5          1  49.670833        NaN        44.773373  42.196667
# 5          6          1  50.848125        NaN        44.343922  37.556250
# 6          7          0  42.196667        NaN        43.374255  48.547292
# 7          8          0  37.556250  40.829783        44.476756  49.101042
# 8          9          0  48.547292  39.076875        45.908780  44.490208
# 9         10          0  49.101042  43.441250        46.058631  52.484375

# %%
df_ml_ready = df.dropna(subset=['Target']).reset_index(drop=True) # drop Nan target but keep the featues with xgboost
display(df_ml_ready.head(10))
df_ml_ready.isna().sum()
# Out:
#        Start             Samplingpoint      Value  DayOfWeek  Month  \
# 0 2013-01-01  AL/SPO-AL0201A_00008_100  40.829783          1      1
# 1 2013-01-02  AL/SPO-AL0201A_00008_100  39.076875          2      1
# 2 2013-01-03  AL/SPO-AL0201A_00008_100  43.441250          3      1
# 3 2013-01-04  AL/SPO-AL0201A_00008_100  49.670833          4      1
# 4 2013-01-05  AL/SPO-AL0201A_00008_100  50.848125          5      1
# 5 2013-01-06  AL/SPO-AL0201A_00008_100  42.196667          6      1
# 6 2013-01-07  AL/SPO-AL0201A_00008_100  37.556250          0      1
# 7 2013-01-08  AL/SPO-AL0201A_00008_100  48.547292          1      1
# 8 2013-01-09  AL/SPO-AL0201A_00008_100  49.101042          2      1
# 9 2013-01-10  AL/SPO-AL0201A_00008_100  44.490208          3      1
#
#    DayOfYear  IsWeekend      Lag_1      Lag_7  Rolling_Mean_7D     Target
# 0          1          0        NaN        NaN              NaN  39.076875
# 1          2          0  40.829783        NaN              NaN  43.441250
# 2          3          0  39.076875        NaN              NaN  49.670833
# 3          4          0  43.441250        NaN        43.254685  50.848125
# 4          5          1  49.670833        NaN        44.773373  42.196667
# 5          6          1  50.848125        NaN        44.343922  37.556250
# 6          7          0  42.196667        NaN        43.374255  48.547292
# 7          8          0  37.556250  40.829783        44.476756  49.101042
# 8          9          0  48.547292  39.076875        45.908780  44.490208
# 9         10          0  49.101042  43.441250        46.058631  52.484375
# Start                0
# Samplingpoint        0
# Value              110
# DayOfWeek            0
# Month                0
# DayOfYear            0
# IsWeekend            0
# Lag_1              208
# Lag_7              576
# Rolling_Mean_7D    309
# Target               0
# dtype: int64

# %% [markdown]
# # Machine Learning

# %%
features = ['Samplingpoint', 'Value', 'DayOfWeek', 'Month', 'DayOfYear', 'IsWeekend', 'Lag_1', 'Lag_7', 'Rolling_Mean_7D']

# %%
train_data = df_ml_ready[(df_ml_ready['Start'] >= '2013-01-01') & (df_ml_ready['Start'] <= '2020-12-31')]
val_data = df_ml_ready[(df_ml_ready['Start'] >= '2021-01-01') & (df_ml_ready['Start'] <= '2022-12-31')]
test_data = df_ml_ready[(df_ml_ready['Start'] >= '2023-01-01') & (df_ml_ready['Start'] <= '2024-12-31')]

# Sort purely by date so TimeSeriesSplit moves properly through time, no longer need to sort by station anymore
train_data = train_data.sort_values(by='Start').reset_index(drop=True)
val_data = val_data.sort_values(by='Start').reset_index(drop=True)
test_data = test_data.sort_values(by='Start').reset_index(drop=True)

X_train, y_train = train_data[features], train_data['Target']
X_val, y_val = val_data[features], val_data['Target']
X_test, y_test = test_data[features], test_data['Target']

print(f"Train shape: {X_train.shape}, Val shape: {X_val.shape}, Test shape: {X_test.shape}")
# Out:
# Train shape: (6720, 9), Val shape: (46, 9), Test shape: (2253, 9)

# %%
# save features 
feature_names = list(X_train.columns)
features_filename = output_dir / f"xgboost_features_{COUNTRY_CODE}_{POLLUTANT}.pkl"
joblib.dump(feature_names, features_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_NO2\\xgboost_features_AL_NO2.pkl']

# %%
def objective(trial):
    # Hyperparameeter search space
    params = {
        'objective': 'reg:squarederror',
        'tree_method': 'hist', # faster for cpu 
        # 'tree_method' : 'exact', # more accurate but slower
        'n_estimators': trial.suggest_int('n_estimators', 100, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # prevent overfitting
        "gamma": trial.suggest_float("gamma", 0, 5),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)  
    }
    
    tscv = TimeSeriesSplit(n_splits=5) # Time Series Cross Validation Split (5 splits/folds)
    cv_scores = []
    
    for fold_idx, (train_idx, val_idx) in enumerate(tscv.split(X_train)):

        X_fold_train, X_fold_val = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_fold_train, y_fold_val = y_train.iloc[train_idx], y_train.iloc[val_idx]


        model = xgb.XGBRegressor(
            **params, 
            enable_categorical=True, # for the samplingpoint categorical
            early_stopping_rounds=30,
            random_state=42 # for reproducatbility
        )
        
        model.fit(
            X_fold_train, y_fold_train, 
            eval_set=[(X_fold_val, y_fold_val)],  # validation data for early stopping
            verbose=False, 
        )

        preds = model.predict(X_fold_val)
        rmse = np.sqrt(mean_squared_error(y_fold_val, preds))
        cv_scores.append(rmse)

        # Report the RMSE for this fold to Optuna for pruning decisions
        trial.report(rmse, step=fold_idx)

        # Handle pruning based on the fold's performance
        if trial.should_prune():
            raise optuna.TrialPruned()
        

    weights = np.arange(1, len(cv_scores) + 1) # more recent folds get higher weight, as there will be more data to train on and gives better representation of recenncy
    return np.average(cv_scores, weights=weights)

# %%
# Bayesian Hyperparameter Optimisation using Optuna
study = optuna.create_study(direction='minimize', pruner=optuna.pruners.MedianPruner(n_warmup_steps=2)) # minimise rmse and use median pruner to stop bad trials early based on median of intermediate results
study.optimize(objective, n_trials=200) 
print(f"Best trial parameters: {study.best_params}")
# Out:
# [I 2026-03-12 16:38:13,217] A new study created in memory with name: no-name-ec22c31d-6611-45e9-b546-fae5a0a38a8c
# [I 2026-03-12 16:38:18,767] Trial 0 finished with value: 4.906104082736787 and parameters: {'n_estimators': 1134, 'learning_rate': 0.023868932716288045, 'max_depth': 8, 'subsample': 0.722437413719055, 'colsample_bytree': 0.9897274203794988, 'min_child_weight': 2, 'gamma': 3.8876494707928537, 'reg_lambda': 0.018493207054851794}. Best is trial 0 with value: 4.906104082736787.
# [I 2026-03-12 16:38:21,871] Trial 1 finished with value: 4.803911665490114 and parameters: {'n_estimators': 1072, 'learning_rate': 0.03412031732616511, 'max_depth': 6, 'subsample': 0.955189005158971, 'colsample_bytree': 0.7691653966331171, 'min_child_weight': 6, 'gamma': 4.287020186208915, 'reg_lambda': 3.808710534748109}. Best is trial 1 with value: 4.803911665490114.
# [I 2026-03-12 16:38:24,421] Trial 2 finished with value: 5.002566106423324 and parameters: {'n_estimators': 265, 'learning_rate': 0.027228248485909105, 'max_depth': 6, 'subsample': 0.5702638959352233, 'colsample_bytree': 0.5786164454793776, 'min_child_weight': 9, 'gamma': 3.3104150201730604, 'reg_lambda': 0.05231721008664631}. Best is trial 1 with value: 4.803911665490114.
# [I 2026-03-12 16:38:46,361] Trial 3 finished with value: 5.506240279610902 and parameters: {'n_estimators': 335, 'learning_rate': 0.005994515547664072, 'max_depth': 12, 'subsample': 0.8651056089586677, 'colsample_bytree': 0.9075554876117129, 'min_child_weight': 1, 'gamma': 4.2042634022817325, 'reg_lambda': 0.04355338563658132}. Best is trial 1 with value: 4.803911665490114.
# [I 2026-03-12 16:38:48,583] Trial 4 finished with value: 4.824732161967509 and parameters: {'n_estimators': 673, 'learning_rate': 0.061854626221305026, 'max_depth': 7, 'subsample': 0.6923065408657274, 'colsample_bytree': 0.8142399216143874, 'min_child_weight': 7, 'gamma': 2.8788624974004504, 'reg_lambda': 0.03236078489675618}. Best is trial 1 with value: 4.803911665490114.
# [I 2026-03-12 16:38:49,907] Trial 5 finished with value: 4.582787287928221 and parameters: {'n_estimators': 539, 'learning_rate': 0.06451833496271826, 'max_depth': 4, 'subsample': 0.6130067158985455, 'colsample_bytree': 0.7545038402405311, 'min_child_weight': 5, 'gamma': 4.193289210641403, 'reg_lambda': 0.5969416599149204}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:38:52,263] Trial 6 finished with value: 4.84319468456051 and parameters: {'n_estimators': 957, 'learning_rate': 0.04496899259888108, 'max_depth': 5, 'subsample': 0.998012427430828, 'colsample_bytree': 0.7663660386425195, 'min_child_weight': 3, 'gamma': 4.905024293770734, 'reg_lambda': 0.40307496330529174}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:38:54,517] Trial 7 pruned.
# [I 2026-03-12 16:39:01,900] Trial 8 pruned.
# [I 2026-03-12 16:39:02,957] Trial 9 pruned.
# [I 2026-03-12 16:39:03,833] Trial 10 pruned.
# [I 2026-03-12 16:39:04,875] Trial 11 finished with value: 4.67487316656242 and parameters: {'n_estimators': 817, 'learning_rate': 0.06466832623324603, 'max_depth': 3, 'subsample': 0.6109019276444044, 'colsample_bytree': 0.6756481913813508, 'min_child_weight': 5, 'gamma': 4.970047048931286, 'reg_lambda': 9.587381573774504}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:05,714] Trial 12 finished with value: 4.673951231032401 and parameters: {'n_estimators': 522, 'learning_rate': 0.08414875147297646, 'max_depth': 3, 'subsample': 0.6261058737001417, 'colsample_bytree': 0.6668898883028725, 'min_child_weight': 4, 'gamma': 4.827916147902953, 'reg_lambda': 8.669840690792986}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:06,459] Trial 13 finished with value: 4.746787918970996 and parameters: {'n_estimators': 470, 'learning_rate': 0.10225652669890699, 'max_depth': 4, 'subsample': 0.6327507785886823, 'colsample_bytree': 0.8599666823639195, 'min_child_weight': 4, 'gamma': 2.1587883503839045, 'reg_lambda': 0.4501359497613161}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:07,099] Trial 14 pruned.
# [I 2026-03-12 16:39:07,819] Trial 15 finished with value: 4.684562458312282 and parameters: {'n_estimators': 527, 'learning_rate': 0.17696609704716046, 'max_depth': 4, 'subsample': 0.6463682895728174, 'colsample_bytree': 0.7098939010672805, 'min_child_weight': 4, 'gamma': 0.2754076090985653, 'reg_lambda': 7.353160482634331}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:09,953] Trial 16 pruned.
# [I 2026-03-12 16:39:10,725] Trial 17 pruned.
# [I 2026-03-12 16:39:11,749] Trial 18 pruned.
# [I 2026-03-12 16:39:12,948] Trial 19 finished with value: 4.975420885826171 and parameters: {'n_estimators': 424, 'learning_rate': 0.1314868219737822, 'max_depth': 10, 'subsample': 0.6658491010772014, 'colsample_bytree': 0.7168381231901435, 'min_child_weight': 3, 'gamma': 2.52069526391358, 'reg_lambda': 0.958248718500389}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:13,804] Trial 20 pruned.
# [I 2026-03-12 16:39:14,933] Trial 21 finished with value: 4.662256055052799 and parameters: {'n_estimators': 837, 'learning_rate': 0.06823791238528107, 'max_depth': 3, 'subsample': 0.6025369380625892, 'colsample_bytree': 0.6677637727734587, 'min_child_weight': 5, 'gamma': 4.894968284267921, 'reg_lambda': 6.400590669880778}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:15,649] Trial 22 pruned.
# [I 2026-03-12 16:39:16,414] Trial 23 pruned.
# [I 2026-03-12 16:39:16,966] Trial 24 pruned.
# [I 2026-03-12 16:39:17,681] Trial 25 pruned.
# [I 2026-03-12 16:39:19,370] Trial 26 pruned.
# [I 2026-03-12 16:39:20,629] Trial 27 pruned.
# [I 2026-03-12 16:39:21,922] Trial 28 finished with value: 4.636189429703396 and parameters: {'n_estimators': 731, 'learning_rate': 0.051398327282959975, 'max_depth': 4, 'subsample': 0.7097657302054989, 'colsample_bytree': 0.6829579387547255, 'min_child_weight': 3, 'gamma': 3.6091793131705625, 'reg_lambda': 0.7107678918687987}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:26,098] Trial 29 finished with value: 4.813376608207212 and parameters: {'n_estimators': 761, 'learning_rate': 0.022982768079288767, 'max_depth': 8, 'subsample': 0.7134676200331215, 'colsample_bytree': 0.9408040177758816, 'min_child_weight': 2, 'gamma': 3.590824164711364, 'reg_lambda': 0.523570951412699}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:26,952] Trial 30 pruned.
# [I 2026-03-12 16:39:28,161] Trial 31 finished with value: 4.721534563469658 and parameters: {'n_estimators': 608, 'learning_rate': 0.0742271131923707, 'max_depth': 4, 'subsample': 0.6414452729683547, 'colsample_bytree': 0.6851389713324074, 'min_child_weight': 4, 'gamma': 4.634343010102316, 'reg_lambda': 0.6962593943104826}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:29,150] Trial 32 pruned.
# [I 2026-03-12 16:39:30,110] Trial 33 finished with value: 4.667595474273097 and parameters: {'n_estimators': 855, 'learning_rate': 0.056568821706901605, 'max_depth': 4, 'subsample': 0.6526611886336808, 'colsample_bytree': 0.6760497308973983, 'min_child_weight': 3, 'gamma': 3.840235344061051, 'reg_lambda': 5.418939454141288}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:31,032] Trial 34 pruned.
# [I 2026-03-12 16:39:31,918] Trial 35 pruned.
# [I 2026-03-12 16:39:32,955] Trial 36 finished with value: 4.725955250823771 and parameters: {'n_estimators': 970, 'learning_rate': 0.03889983044942646, 'max_depth': 5, 'subsample': 0.668245331719427, 'colsample_bytree': 0.7781364425751469, 'min_child_weight': 3, 'gamma': 2.55135047233985, 'reg_lambda': 0.2314029755398434}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:33,796] Trial 37 pruned.
# [I 2026-03-12 16:39:35,637] Trial 38 finished with value: 4.747468080925492 and parameters: {'n_estimators': 935, 'learning_rate': 0.025699810081885304, 'max_depth': 6, 'subsample': 0.7007748980595878, 'colsample_bytree': 0.8079176963511121, 'min_child_weight': 2, 'gamma': 3.930372665022111, 'reg_lambda': 2.710901076715724}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:36,147] Trial 39 pruned.
# [I 2026-03-12 16:39:42,720] Trial 40 pruned.
# [I 2026-03-12 16:39:43,455] Trial 41 finished with value: 4.650226901340284 and parameters: {'n_estimators': 631, 'learning_rate': 0.0805960298584147, 'max_depth': 3, 'subsample': 0.6520005111597126, 'colsample_bytree': 0.6737453882984492, 'min_child_weight': 4, 'gamma': 4.71858248935692, 'reg_lambda': 6.196371923149559}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:43,994] Trial 42 pruned.
# [I 2026-03-12 16:39:45,369] Trial 43 finished with value: 4.663084874699217 and parameters: {'n_estimators': 610, 'learning_rate': 0.04275419664728406, 'max_depth': 3, 'subsample': 0.6113584731227041, 'colsample_bytree': 0.6935446030677807, 'min_child_weight': 4, 'gamma': 4.743781349193209, 'reg_lambda': 5.576896141346448}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:46,460] Trial 44 pruned.
# [I 2026-03-12 16:39:47,489] Trial 45 finished with value: 4.629041488627631 and parameters: {'n_estimators': 648, 'learning_rate': 0.07322932141448948, 'max_depth': 3, 'subsample': 0.6922733985692275, 'colsample_bytree': 0.724830079630969, 'min_child_weight': 4, 'gamma': 4.769034329395289, 'reg_lambda': 6.859112466658457}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:48,172] Trial 46 pruned.
# [I 2026-03-12 16:39:48,786] Trial 47 pruned.
# [I 2026-03-12 16:39:49,754] Trial 48 pruned.
# [I 2026-03-12 16:39:50,539] Trial 49 finished with value: 4.821829895746972 and parameters: {'n_estimators': 734, 'learning_rate': 0.15273607803117728, 'max_depth': 8, 'subsample': 0.6367094722699181, 'colsample_bytree': 0.8356454722997454, 'min_child_weight': 4, 'gamma': 4.159517259632828, 'reg_lambda': 2.554335362901832}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:51,357] Trial 50 pruned.
# [I 2026-03-12 16:39:51,965] Trial 51 pruned.
# [I 2026-03-12 16:39:52,985] Trial 52 pruned.
# [I 2026-03-12 16:39:53,756] Trial 53 pruned.
# [I 2026-03-12 16:39:54,559] Trial 54 pruned.
# [I 2026-03-12 16:39:55,273] Trial 55 pruned.
# [I 2026-03-12 16:39:56,044] Trial 56 finished with value: 4.691906845668139 and parameters: {'n_estimators': 563, 'learning_rate': 0.08156407519633645, 'max_depth': 4, 'subsample': 0.5978003051703858, 'colsample_bytree': 0.7545690386553788, 'min_child_weight': 6, 'gamma': 4.9996279810788, 'reg_lambda': 6.482587294006}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:56,774] Trial 57 pruned.
# [I 2026-03-12 16:39:57,732] Trial 58 finished with value: 4.674105393660974 and parameters: {'n_estimators': 783, 'learning_rate': 0.07050227997674242, 'max_depth': 3, 'subsample': 0.6788015404210057, 'colsample_bytree': 0.7132097896166724, 'min_child_weight': 7, 'gamma': 4.02908242727989, 'reg_lambda': 0.13734332739646213}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:39:59,213] Trial 59 pruned.
# [I 2026-03-12 16:39:59,769] Trial 60 pruned.
# [I 2026-03-12 16:40:00,636] Trial 61 finished with value: 4.646210546516013 and parameters: {'n_estimators': 843, 'learning_rate': 0.05581492377535669, 'max_depth': 4, 'subsample': 0.6546543513077562, 'colsample_bytree': 0.6865123840048095, 'min_child_weight': 3, 'gamma': 3.8462473730378477, 'reg_lambda': 4.989382769307077}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:02,090] Trial 62 pruned.
# [I 2026-03-12 16:40:04,271] Trial 63 pruned.
# [I 2026-03-12 16:40:07,612] Trial 64 pruned.
# [I 2026-03-12 16:40:09,706] Trial 65 pruned.
# [I 2026-03-12 16:40:11,686] Trial 66 pruned.
# [I 2026-03-12 16:40:12,447] Trial 67 finished with value: 4.630575499782926 and parameters: {'n_estimators': 594, 'learning_rate': 0.07196635675052072, 'max_depth': 4, 'subsample': 0.585018534693405, 'colsample_bytree': 0.7047213417733208, 'min_child_weight': 4, 'gamma': 4.659896086853268, 'reg_lambda': 1.0051576828523003}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:13,384] Trial 68 finished with value: 4.70703064893054 and parameters: {'n_estimators': 448, 'learning_rate': 0.08332337908434372, 'max_depth': 5, 'subsample': 0.5165378986887101, 'colsample_bytree': 0.7120815322408941, 'min_child_weight': 5, 'gamma': 2.6757651607377597, 'reg_lambda': 0.6972785235352238}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:14,018] Trial 69 finished with value: 4.603981434533867 and parameters: {'n_estimators': 1004, 'learning_rate': 0.07181138510954568, 'max_depth': 4, 'subsample': 0.5821575032116655, 'colsample_bytree': 0.792192224817775, 'min_child_weight': 3, 'gamma': 3.9244793883456053, 'reg_lambda': 0.9158128638950476}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:14,641] Trial 70 finished with value: 4.606770504546203 and parameters: {'n_estimators': 1154, 'learning_rate': 0.07513867140239852, 'max_depth': 4, 'subsample': 0.5810501638361799, 'colsample_bytree': 0.7878419580370462, 'min_child_weight': 2, 'gamma': 3.83640300632261, 'reg_lambda': 0.9715924381491183}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:15,333] Trial 71 finished with value: 4.657547722315253 and parameters: {'n_estimators': 1053, 'learning_rate': 0.0743102280485785, 'max_depth': 4, 'subsample': 0.582230810120553, 'colsample_bytree': 0.7928851422302401, 'min_child_weight': 2, 'gamma': 3.9128773110076223, 'reg_lambda': 0.8750033996438488}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:15,837] Trial 72 pruned.
# [I 2026-03-12 16:40:16,402] Trial 73 finished with value: 4.63369276823945 and parameters: {'n_estimators': 573, 'learning_rate': 0.09405007745749014, 'max_depth': 4, 'subsample': 0.6653207876418519, 'colsample_bytree': 0.8789019174257784, 'min_child_weight': 3, 'gamma': 3.6311944058024985, 'reg_lambda': 0.29092987125096714}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:17,019] Trial 74 pruned.
# [I 2026-03-12 16:40:17,570] Trial 75 pruned.
# [I 2026-03-12 16:40:18,558] Trial 76 finished with value: 4.666178170875859 and parameters: {'n_estimators': 1132, 'learning_rate': 0.05039007721383915, 'max_depth': 6, 'subsample': 0.528766932366379, 'colsample_bytree': 0.8754313492030357, 'min_child_weight': 3, 'gamma': 3.987920989298386, 'reg_lambda': 0.7944394849398689}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:19,113] Trial 77 finished with value: 4.630099933026974 and parameters: {'n_estimators': 574, 'learning_rate': 0.13855503330028246, 'max_depth': 4, 'subsample': 0.5872106199309987, 'colsample_bytree': 0.7696397576536246, 'min_child_weight': 1, 'gamma': 3.1527805051953584, 'reg_lambda': 1.115205470202798}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:19,652] Trial 78 pruned.
# [I 2026-03-12 16:40:20,171] Trial 79 finished with value: 4.726686710598676 and parameters: {'n_estimators': 437, 'learning_rate': 0.13520953989118373, 'max_depth': 4, 'subsample': 0.5963113085931777, 'colsample_bytree': 0.7678949518206536, 'min_child_weight': 1, 'gamma': 3.642345942066862, 'reg_lambda': 0.3822606245141702}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:20,667] Trial 80 finished with value: 4.627991132156528 and parameters: {'n_estimators': 511, 'learning_rate': 0.14617544425679507, 'max_depth': 5, 'subsample': 0.557153775297127, 'colsample_bytree': 0.7865299746435261, 'min_child_weight': 1, 'gamma': 3.3678103471306295, 'reg_lambda': 0.6143997229765308}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:21,089] Trial 81 pruned.
# [I 2026-03-12 16:40:21,621] Trial 82 pruned.
# [I 2026-03-12 16:40:22,056] Trial 83 pruned.
# [I 2026-03-12 16:40:22,602] Trial 84 pruned.
# [I 2026-03-12 16:40:23,008] Trial 85 finished with value: 4.6550546437736795 and parameters: {'n_estimators': 545, 'learning_rate': 0.1760968922749497, 'max_depth': 4, 'subsample': 0.5872756574927138, 'colsample_bytree': 0.7488839558234224, 'min_child_weight': 1, 'gamma': 3.740975821957691, 'reg_lambda': 0.17521172290277123}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:24,081] Trial 86 finished with value: 4.707060001502203 and parameters: {'n_estimators': 603, 'learning_rate': 0.06662456601276795, 'max_depth': 7, 'subsample': 0.5668694178796077, 'colsample_bytree': 0.7818420093048952, 'min_child_weight': 2, 'gamma': 3.195060117449471, 'reg_lambda': 1.4460186264024668}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:24,651] Trial 87 finished with value: 4.626531118300632 and parameters: {'n_estimators': 465, 'learning_rate': 0.08748969671007242, 'max_depth': 4, 'subsample': 0.5013149699019135, 'colsample_bytree': 0.7615593630036726, 'min_child_weight': 1, 'gamma': 4.207127693747568, 'reg_lambda': 0.7721820068369282}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:25,164] Trial 88 pruned.
# [I 2026-03-12 16:40:25,649] Trial 89 pruned.
# [I 2026-03-12 16:40:26,171] Trial 90 finished with value: 4.722759418723576 and parameters: {'n_estimators': 453, 'learning_rate': 0.14197839628660414, 'max_depth': 4, 'subsample': 0.6275813244800498, 'colsample_bytree': 0.7538360927738915, 'min_child_weight': 1, 'gamma': 4.436053386006421, 'reg_lambda': 0.5770946495045435}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:26,626] Trial 91 pruned.
# [I 2026-03-12 16:40:27,438] Trial 92 finished with value: 4.5845902421687565 and parameters: {'n_estimators': 307, 'learning_rate': 0.0740726952363478, 'max_depth': 4, 'subsample': 0.5024957280493292, 'colsample_bytree': 0.8381536568043928, 'min_child_weight': 3, 'gamma': 3.929019907336548, 'reg_lambda': 0.5018738273727327}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:27,936] Trial 93 pruned.
# [I 2026-03-12 16:40:28,322] Trial 94 pruned.
# [I 2026-03-12 16:40:28,854] Trial 95 pruned.
# [I 2026-03-12 16:40:29,471] Trial 96 pruned.
# [I 2026-03-12 16:40:30,184] Trial 97 finished with value: 4.66004403027984 and parameters: {'n_estimators': 508, 'learning_rate': 0.07188426562249392, 'max_depth': 4, 'subsample': 0.5206667730446424, 'colsample_bytree': 0.737779719465599, 'min_child_weight': 2, 'gamma': 3.4688928437806728, 'reg_lambda': 2.3017330167960264}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:30,648] Trial 98 pruned.
# [I 2026-03-12 16:40:31,420] Trial 99 finished with value: 4.629337028915273 and parameters: {'n_estimators': 627, 'learning_rate': 0.06486747001096861, 'max_depth': 4, 'subsample': 0.5645129492837081, 'colsample_bytree': 0.7615657478946097, 'min_child_weight': 4, 'gamma': 4.626678343999413, 'reg_lambda': 0.5878287339628556}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:32,223] Trial 100 finished with value: 4.695640394408174 and parameters: {'n_estimators': 317, 'learning_rate': 0.06695773260849942, 'max_depth': 5, 'subsample': 0.5627307346768661, 'colsample_bytree': 0.7635490302509218, 'min_child_weight': 4, 'gamma': 4.426452920387387, 'reg_lambda': 1.424731425940785}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:32,849] Trial 101 finished with value: 4.637095529103383 and parameters: {'n_estimators': 248, 'learning_rate': 0.07663700785068592, 'max_depth': 4, 'subsample': 0.5977841291787722, 'colsample_bytree': 0.7925489485268654, 'min_child_weight': 4, 'gamma': 4.8920956576505175, 'reg_lambda': 0.586573946838565}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:33,734] Trial 102 finished with value: 4.63542588827771 and parameters: {'n_estimators': 626, 'learning_rate': 0.05977648675044586, 'max_depth': 4, 'subsample': 0.6185320056144465, 'colsample_bytree': 0.7559129274398461, 'min_child_weight': 4, 'gamma': 4.636206965733183, 'reg_lambda': 0.9180795172761351}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:34,515] Trial 103 finished with value: 4.661957484607428 and parameters: {'n_estimators': 594, 'learning_rate': 0.06414316598634458, 'max_depth': 4, 'subsample': 0.543846975885922, 'colsample_bytree': 0.7731949061983139, 'min_child_weight': 3, 'gamma': 4.246264050278412, 'reg_lambda': 0.5027843237345907}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:35,261] Trial 104 pruned.
# [I 2026-03-12 16:40:35,781] Trial 105 pruned.
# [I 2026-03-12 16:40:36,291] Trial 106 pruned.
# [I 2026-03-12 16:40:36,809] Trial 107 finished with value: 4.690358482033116 and parameters: {'n_estimators': 627, 'learning_rate': 0.1287701836845652, 'max_depth': 4, 'subsample': 0.6044195703880322, 'colsample_bytree': 0.7467547996898743, 'min_child_weight': 2, 'gamma': 3.6662911524235753, 'reg_lambda': 1.8711479733563654}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:37,519] Trial 108 pruned.
# [I 2026-03-12 16:40:38,064] Trial 109 pruned.
# [I 2026-03-12 16:40:39,860] Trial 110 pruned.
# [I 2026-03-12 16:40:40,976] Trial 111 finished with value: 4.665946241437464 and parameters: {'n_estimators': 633, 'learning_rate': 0.04815032898850829, 'max_depth': 4, 'subsample': 0.6383813083379413, 'colsample_bytree': 0.7556985033195796, 'min_child_weight': 4, 'gamma': 4.451979253986389, 'reg_lambda': 0.9805977436240615}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:42,047] Trial 112 finished with value: 4.631482322033111 and parameters: {'n_estimators': 603, 'learning_rate': 0.06963458207813014, 'max_depth': 4, 'subsample': 0.5879845187662948, 'colsample_bytree': 0.7597424255887716, 'min_child_weight': 4, 'gamma': 4.6748275146703815, 'reg_lambda': 0.8767905987023742}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:42,676] Trial 113 finished with value: 4.615652767824222 and parameters: {'n_estimators': 608, 'learning_rate': 0.08021459631743492, 'max_depth': 4, 'subsample': 0.578901070863901, 'colsample_bytree': 0.7994543077083393, 'min_child_weight': 5, 'gamma': 4.659196518664116, 'reg_lambda': 1.2692942641442813}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:43,442] Trial 114 finished with value: 4.602762340305935 and parameters: {'n_estimators': 1184, 'learning_rate': 0.07055707963962189, 'max_depth': 4, 'subsample': 0.5937684959129378, 'colsample_bytree': 0.8029972928234969, 'min_child_weight': 5, 'gamma': 4.688110334803041, 'reg_lambda': 1.638889590602131}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:44,191] Trial 115 pruned.
# [I 2026-03-12 16:40:45,512] Trial 116 pruned.
# [I 2026-03-12 16:40:46,045] Trial 117 pruned.
# [I 2026-03-12 16:40:46,919] Trial 118 finished with value: 4.64130432113198 and parameters: {'n_estimators': 1138, 'learning_rate': 0.05292736859338917, 'max_depth': 5, 'subsample': 0.5952894664349269, 'colsample_bytree': 0.7902956350051106, 'min_child_weight': 6, 'gamma': 4.734880721998291, 'reg_lambda': 0.618209902172537}. Best is trial 5 with value: 4.582787287928221.
# [I 2026-03-12 16:40:47,722] Trial 119 finished with value: 4.554281107735817 and parameters: {'n_estimators': 1055, 'learning_rate': 0.06513744463225146, 'max_depth': 4, 'subsample': 0.5547774194861173, 'colsample_bytree': 0.7690050925388409, 'min_child_weight': 5, 'gamma': 4.5429753553683865, 'reg_lambda': 1.3267099569982064}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:48,284] Trial 120 pruned.
# [I 2026-03-12 16:40:49,007] Trial 121 finished with value: 4.593698362229166 and parameters: {'n_estimators': 1027, 'learning_rate': 0.07872930005453342, 'max_depth': 4, 'subsample': 0.6114521001732323, 'colsample_bytree': 0.7715720527226808, 'min_child_weight': 5, 'gamma': 4.372293938386142, 'reg_lambda': 1.2999227082276008}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:49,766] Trial 122 finished with value: 4.612476095171172 and parameters: {'n_estimators': 1001, 'learning_rate': 0.08059848526700611, 'max_depth': 4, 'subsample': 0.6098844724857966, 'colsample_bytree': 0.7776588893234353, 'min_child_weight': 5, 'gamma': 4.348809520872404, 'reg_lambda': 1.2492504891671998}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:50,555] Trial 123 finished with value: 4.595370983738041 and parameters: {'n_estimators': 1025, 'learning_rate': 0.07892576523646146, 'max_depth': 4, 'subsample': 0.6122007821672284, 'colsample_bytree': 0.7852255796709352, 'min_child_weight': 5, 'gamma': 4.392716206529956, 'reg_lambda': 1.9274558418309882}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:51,167] Trial 124 pruned.
# [I 2026-03-12 16:40:51,980] Trial 125 pruned.
# [I 2026-03-12 16:40:52,781] Trial 126 finished with value: 4.660337767026509 and parameters: {'n_estimators': 978, 'learning_rate': 0.08594749241995774, 'max_depth': 5, 'subsample': 0.6244444063132167, 'colsample_bytree': 0.8005928661010223, 'min_child_weight': 6, 'gamma': 4.499340681716534, 'reg_lambda': 2.9984178499301057}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:53,556] Trial 127 finished with value: 4.595133274477147 and parameters: {'n_estimators': 1082, 'learning_rate': 0.06963876020925396, 'max_depth': 4, 'subsample': 0.6403689470730026, 'colsample_bytree': 0.8284777256979229, 'min_child_weight': 5, 'gamma': 4.168733161864816, 'reg_lambda': 1.3922946447600524}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:54,322] Trial 128 pruned.
# [I 2026-03-12 16:40:54,788] Trial 129 pruned.
# [I 2026-03-12 16:40:55,442] Trial 130 pruned.
# [I 2026-03-12 16:40:56,179] Trial 131 finished with value: 4.611178445644338 and parameters: {'n_estimators': 1005, 'learning_rate': 0.06837663035981924, 'max_depth': 4, 'subsample': 0.6067171926452458, 'colsample_bytree': 0.8074784484459784, 'min_child_weight': 5, 'gamma': 4.372044757442459, 'reg_lambda': 1.66967009164436}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:57,253] Trial 132 finished with value: 4.596588699453439 and parameters: {'n_estimators': 1009, 'learning_rate': 0.06718813609801126, 'max_depth': 4, 'subsample': 0.5961792901583115, 'colsample_bytree': 0.7865267733921488, 'min_child_weight': 5, 'gamma': 4.300345117408814, 'reg_lambda': 1.7547161097409696}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:58,178] Trial 133 finished with value: 4.583156916739436 and parameters: {'n_estimators': 1015, 'learning_rate': 0.06558990136041849, 'max_depth': 4, 'subsample': 0.5992251278535284, 'colsample_bytree': 0.8102544863072505, 'min_child_weight': 5, 'gamma': 4.379223449674772, 'reg_lambda': 1.7295845944496222}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:40:59,036] Trial 134 finished with value: 4.608332327142675 and parameters: {'n_estimators': 1013, 'learning_rate': 0.06792439240490385, 'max_depth': 4, 'subsample': 0.5999545062468522, 'colsample_bytree': 0.8141465290828599, 'min_child_weight': 5, 'gamma': 4.357733908027215, 'reg_lambda': 1.7124577438420827}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:00,076] Trial 135 finished with value: 4.610397479062114 and parameters: {'n_estimators': 1017, 'learning_rate': 0.06564779278087594, 'max_depth': 4, 'subsample': 0.5982284239343618, 'colsample_bytree': 0.810379244236398, 'min_child_weight': 5, 'gamma': 4.35163977947225, 'reg_lambda': 1.6801829644780744}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:00,649] Trial 136 pruned.
# [I 2026-03-12 16:41:01,347] Trial 137 pruned.
# [I 2026-03-12 16:41:02,428] Trial 138 finished with value: 4.565197631762426 and parameters: {'n_estimators': 966, 'learning_rate': 0.06898833288525415, 'max_depth': 4, 'subsample': 0.5922866884938791, 'colsample_bytree': 0.8121759852365953, 'min_child_weight': 5, 'gamma': 4.292934626374462, 'reg_lambda': 2.08408669197384}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:03,271] Trial 139 finished with value: 4.601913630029113 and parameters: {'n_estimators': 968, 'learning_rate': 0.06244398626642407, 'max_depth': 4, 'subsample': 0.595676743435362, 'colsample_bytree': 0.8419586144909832, 'min_child_weight': 5, 'gamma': 3.9197319844703227, 'reg_lambda': 3.1335176342807203}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:04,323] Trial 140 pruned.
# [I 2026-03-12 16:41:05,045] Trial 141 finished with value: 4.578355817247024 and parameters: {'n_estimators': 921, 'learning_rate': 0.06382356702111205, 'max_depth': 4, 'subsample': 0.6182876983393663, 'colsample_bytree': 0.8284164990728959, 'min_child_weight': 5, 'gamma': 4.054360907191793, 'reg_lambda': 2.1906444684842117}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:05,670] Trial 142 pruned.
# [I 2026-03-12 16:41:06,227] Trial 143 pruned.
# [I 2026-03-12 16:41:06,941] Trial 144 finished with value: 4.592612479017726 and parameters: {'n_estimators': 1087, 'learning_rate': 0.06314696807943286, 'max_depth': 4, 'subsample': 0.6186174089142096, 'colsample_bytree': 0.8359825951643356, 'min_child_weight': 5, 'gamma': 3.795650925201445, 'reg_lambda': 3.7470169595807166}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:07,734] Trial 145 pruned.
# [I 2026-03-12 16:41:09,050] Trial 146 finished with value: 4.586135181072922 and parameters: {'n_estimators': 1095, 'learning_rate': 0.06346128438274835, 'max_depth': 4, 'subsample': 0.6280800721083755, 'colsample_bytree': 0.8302513639001632, 'min_child_weight': 5, 'gamma': 4.124480423031293, 'reg_lambda': 3.8656496277871386}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:09,861] Trial 147 pruned.
# [I 2026-03-12 16:41:10,958] Trial 148 pruned.
# [I 2026-03-12 16:41:12,529] Trial 149 pruned.
# [I 2026-03-12 16:41:14,602] Trial 150 finished with value: 4.589794557464608 and parameters: {'n_estimators': 963, 'learning_rate': 0.05817358711967004, 'max_depth': 4, 'subsample': 0.6248813194884758, 'colsample_bytree': 0.8540634187287536, 'min_child_weight': 5, 'gamma': 3.963912899258164, 'reg_lambda': 4.394037668216679}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:16,560] Trial 151 pruned.
# [I 2026-03-12 16:41:17,679] Trial 152 pruned.
# [I 2026-03-12 16:41:18,997] Trial 153 finished with value: 4.59750749745312 and parameters: {'n_estimators': 1120, 'learning_rate': 0.06330602679942973, 'max_depth': 4, 'subsample': 0.5914053037176972, 'colsample_bytree': 0.8788581789792944, 'min_child_weight': 5, 'gamma': 4.101886222589861, 'reg_lambda': 2.3720039192835194}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:20,224] Trial 154 pruned.
# [I 2026-03-12 16:41:21,285] Trial 155 pruned.
# [I 2026-03-12 16:41:23,174] Trial 156 finished with value: 4.615731103420513 and parameters: {'n_estimators': 891, 'learning_rate': 0.05699563239231288, 'max_depth': 7, 'subsample': 0.6100676475902727, 'colsample_bytree': 0.8550360340406546, 'min_child_weight': 5, 'gamma': 4.45763424508141, 'reg_lambda': 2.396943235558705}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:24,273] Trial 157 pruned.
# [I 2026-03-12 16:41:25,795] Trial 158 finished with value: 4.676399738213422 and parameters: {'n_estimators': 1129, 'learning_rate': 0.06288342467210066, 'max_depth': 8, 'subsample': 0.6396906778956882, 'colsample_bytree': 0.9071429849182829, 'min_child_weight': 5, 'gamma': 4.165344008783603, 'reg_lambda': 2.6020541773161936}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:26,682] Trial 159 finished with value: 4.599113767289977 and parameters: {'n_estimators': 1088, 'learning_rate': 0.053560529038685266, 'max_depth': 4, 'subsample': 0.6061674427472636, 'colsample_bytree': 0.8431169169936052, 'min_child_weight': 5, 'gamma': 4.505846575815767, 'reg_lambda': 3.4891402189243443}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:27,557] Trial 160 pruned.
# [I 2026-03-12 16:41:28,336] Trial 161 pruned.
# [I 2026-03-12 16:41:29,065] Trial 162 pruned.
# [I 2026-03-12 16:41:29,705] Trial 163 pruned.
# [I 2026-03-12 16:41:30,342] Trial 164 finished with value: 4.581741759086255 and parameters: {'n_estimators': 1099, 'learning_rate': 0.07558073376561618, 'max_depth': 4, 'subsample': 0.5727725312883716, 'colsample_bytree': 0.8325089737902939, 'min_child_weight': 5, 'gamma': 3.776584906389939, 'reg_lambda': 3.370576479336376}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:31,340] Trial 165 pruned.
# [I 2026-03-12 16:41:31,947] Trial 166 pruned.
# [I 2026-03-12 16:41:34,182] Trial 167 pruned.
# [I 2026-03-12 16:41:34,858] Trial 168 pruned.
# [I 2026-03-12 16:41:35,874] Trial 169 pruned.
# [I 2026-03-12 16:41:36,468] Trial 170 pruned.
# [I 2026-03-12 16:41:37,405] Trial 171 pruned.
# [I 2026-03-12 16:41:38,118] Trial 172 pruned.
# [I 2026-03-12 16:41:39,022] Trial 173 finished with value: 4.574441351967638 and parameters: {'n_estimators': 1100, 'learning_rate': 0.06963125549694296, 'max_depth': 4, 'subsample': 0.6180334584012548, 'colsample_bytree': 0.8519323643203749, 'min_child_weight': 5, 'gamma': 4.1695881723406885, 'reg_lambda': 0.007231759547224612}. Best is trial 119 with value: 4.554281107735817.
# [I 2026-03-12 16:41:39,787] Trial 174 finished with value: 4.532634991936939 and parameters: {'n_estimators': 1101, 'learning_rate': 0.06558253663713279, 'max_depth': 4, 'subsample': 0.617740539469704, 'colsample_bytree': 0.8499628565760939, 'min_child_weight': 5, 'gamma': 4.162406500754432, 'reg_lambda': 4.037642234571359}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:40,393] Trial 175 pruned.
# [I 2026-03-12 16:41:41,000] Trial 176 pruned.
# [I 2026-03-12 16:41:41,588] Trial 177 pruned.
# [I 2026-03-12 16:41:42,144] Trial 178 pruned.
# [I 2026-03-12 16:41:43,286] Trial 179 pruned.
# [I 2026-03-12 16:41:44,561] Trial 180 pruned.
# [I 2026-03-12 16:41:45,682] Trial 181 pruned.
# [I 2026-03-12 16:41:46,423] Trial 182 pruned.
# [I 2026-03-12 16:41:47,416] Trial 183 pruned.
# [I 2026-03-12 16:41:48,232] Trial 184 finished with value: 4.545792647893995 and parameters: {'n_estimators': 995, 'learning_rate': 0.06024556335452645, 'max_depth': 4, 'subsample': 0.6245249885580996, 'colsample_bytree': 0.837500832540915, 'min_child_weight': 5, 'gamma': 4.170179110693215, 'reg_lambda': 1.9764200128103542}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:49,086] Trial 185 finished with value: 4.588163904927902 and parameters: {'n_estimators': 1067, 'learning_rate': 0.05769676509466584, 'max_depth': 4, 'subsample': 0.6272574670517358, 'colsample_bytree': 0.8630924490413567, 'min_child_weight': 5, 'gamma': 4.18516924926587, 'reg_lambda': 1.8232046281821825}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:49,631] Trial 186 pruned.
# [I 2026-03-12 16:41:50,190] Trial 187 pruned.
# [I 2026-03-12 16:41:50,968] Trial 188 finished with value: 4.616814187193224 and parameters: {'n_estimators': 1033, 'learning_rate': 0.05844894341198771, 'max_depth': 4, 'subsample': 0.633883333269117, 'colsample_bytree': 0.8085161093839076, 'min_child_weight': 5, 'gamma': 4.232662098589763, 'reg_lambda': 1.8688950517252272}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:51,616] Trial 189 pruned.
# [I 2026-03-12 16:41:52,291] Trial 190 pruned.
# [I 2026-03-12 16:41:53,274] Trial 191 finished with value: 4.614742754838677 and parameters: {'n_estimators': 1080, 'learning_rate': 0.05000500127747732, 'max_depth': 4, 'subsample': 0.6076943850088264, 'colsample_bytree': 0.8562782147897928, 'min_child_weight': 5, 'gamma': 4.295248014683316, 'reg_lambda': 0.028446011586673748}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:53,940] Trial 192 pruned.
# [I 2026-03-12 16:41:54,800] Trial 193 finished with value: 4.593944700944519 and parameters: {'n_estimators': 1065, 'learning_rate': 0.05900385637948916, 'max_depth': 4, 'subsample': 0.6112708699578494, 'colsample_bytree': 0.8466803546810466, 'min_child_weight': 5, 'gamma': 4.410966795171844, 'reg_lambda': 2.3055874122905253}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:55,756] Trial 194 finished with value: 4.574165916818619 and parameters: {'n_estimators': 1052, 'learning_rate': 0.06043583044169359, 'max_depth': 4, 'subsample': 0.6281245019701045, 'colsample_bytree': 0.8632320844657032, 'min_child_weight': 5, 'gamma': 4.177991518503489, 'reg_lambda': 2.186951299074462}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:56,907] Trial 195 finished with value: 4.580323637283323 and parameters: {'n_estimators': 1039, 'learning_rate': 0.06008883427719362, 'max_depth': 4, 'subsample': 0.6314111469662208, 'colsample_bytree': 0.8521142073237271, 'min_child_weight': 5, 'gamma': 4.225027427346966, 'reg_lambda': 1.4831454879596262}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:41:58,114] Trial 196 pruned.
# [I 2026-03-12 16:41:59,131] Trial 197 pruned.
# [I 2026-03-12 16:41:59,807] Trial 198 finished with value: 4.619646511321028 and parameters: {'n_estimators': 1027, 'learning_rate': 0.07276593274601713, 'max_depth': 4, 'subsample': 0.6439959118357017, 'colsample_bytree': 0.8660462052751053, 'min_child_weight': 5, 'gamma': 4.022815180262936, 'reg_lambda': 2.15556346251898}. Best is trial 174 with value: 4.532634991936939.
# [I 2026-03-12 16:42:00,621] Trial 199 finished with value: 4.621597404088105 and parameters: {'n_estimators': 1065, 'learning_rate': 0.05752582686345937, 'max_depth': 5, 'subsample': 0.6163612152706056, 'colsample_bytree': 0.8304616750656901, 'min_child_weight': 6, 'gamma': 4.418720096111077, 'reg_lambda': 2.8186448083328677}. Best is trial 174 with value: 4.532634991936939.
# Best trial parameters: {'n_estimators': 1101, 'learning_rate': 0.06558253663713279, 'max_depth': 4, 'subsample': 0.617740539469704, 'colsample_bytree': 0.8499628565760939, 'min_child_weight': 5, 'gamma': 4.162406500754432, 'reg_lambda': 4.037642234571359}

# %%
# Incorporation the validating set into train set after opitmal hyperparameters found

# Use X_val purely to find the optimal stopping point
temp_model = xgb.XGBRegressor(
    **study.best_params,
    objective='reg:squarederror', 
    enable_categorical=True,
    tree_method = 'hist', 
    early_stopping_rounds=30,
    random_state=42
    
)

temp_model.fit(
    X_train, y_train,
    eval_set=[(X_val, y_val)],
    verbose=False
)

# Get the exact number of trees where it peaked
optimal_trees = temp_model.best_iteration + 1  # best_iteration is zero-indexed, so add 1 to get the actual number of trees

# Make a copy of the best parameters and overwrite with best trees so it works in the best (final) model
final_params = study.best_params.copy()
final_params['n_estimators'] = optimal_trees

X_train_full = pd.concat([X_train, X_val]) # concat train and val sets to retrain final model on all data up to 2022m(recent trends)
y_train_full = pd.concat([y_train, y_val])


# Retrain with our final (best) hyperparams with new trian data
best_model = xgb.XGBRegressor(
    **final_params,
    objective='reg:squarederror',
    tree_method='hist', 
    enable_categorical=True,
    random_state=42
)


best_model.fit(X_train_full, y_train_full, verbose=100)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8499628565760939, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=4.162406500754432, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.06558253663713279,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=88, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# saving best model
joblib.dump(best_model, model_filename)
# Out:
# ['C:\\Users\\keith\\OneDrive\\Documents\\DataWranglingwithEuropeanAirQualityData\\Source_Task7_Demo\\SavedResults\\Results_AL_NO2\\xgboost_model_AL_NO2.pkl']

# %%
# Predit on the Test Set
test_preds = best_model.predict(X_test)

# %% [markdown]
# # Results & Evaluation

# %%
# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, test_preds))
mae = mean_absolute_error(y_test, test_preds)
r2 = r2_score(y_test, test_preds)

print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")
# Out:
# RMSE: 5.8572
# MAE:  4.2707
# R2:   0.8413

# %%
# For Comparrison a naive non ML just guessing that tomorrow's pollutant will be the same as today
naive_preds = X_test['Value'].dropna()

# if you want the RMSE you must compare against the same rows of y_test
naive_rmse = np.sqrt(
    mean_squared_error(y_test.loc[naive_preds.index], naive_preds)
)

print(f"XGBoost RMSE: {rmse:.4f}")
print(f"Naive Baseline RMSE: {naive_rmse:.4f}")
# Out:
# XGBoost RMSE: 5.8572
# Naive Baseline RMSE: 6.2662

# %%
# Initialize the SHAP Explainer using your trained XGBoost model
explainer = shap.TreeExplainer(best_model) # For XGBoost use TreeExplaienr

shap_values = explainer.shap_values(X_test)

plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test, plot_type="dot", show=False)
plt.title(f"SHAP Feature Importance: What drives {POLLUTANT} Pollution?")
plt.tight_layout()
plt.savefig(output_dir / f"{RUN_ID}_SHAP_Feature_importance.png", bbox_inches='tight')
plt.show()

# %%
importance = best_model.get_booster().get_score(importance_type='weight')

importance_df = pd.DataFrame({
    'Feature': list(importance.keys()),
    'Importance': list(importance.values())
}).sort_values(by='Importance', ascending=False)


top_n = 20
plt.figure(figsize=(10, 8))
plt.title(f"Feature Importance of {POLLUTANT}")
plt.barh(
    importance_df['Feature'].head(top_n)[::-1],
    importance_df['Importance'].head(top_n)[::-1],
    color='skyblue'
)
plt.savefig(output_dir / f"{RUN_ID}_Feature_Importance.png", bbox_inches='tight')

# %%
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"R2:   {r2:.4f}")


# folder for these prediction plots
pred_plot_dir = output_dir / "Predict_vs_Actual_Plots"
pred_plot_dir.mkdir(parents=True, exist_ok=True)

# Plotting Actual vs Predicted for each station in the Test Set
results_df = test_data.copy() # already grouped staion and start (date)
results_df['Actual'] = y_test
results_df['Predicted'] = test_preds


stations = results_df['Samplingpoint'].unique() 

station_metrics_list = [] 

for station in stations:
    station_data = results_df[results_df['Samplingpoint'] == station] 
    
    # skip stations with not enough data to calculate R2 for the stations that have shut down/little test data
    if len(station_data) < 2:
        continue
        
    st_rmse = np.sqrt(mean_squared_error(station_data['Actual'], station_data['Predicted']))
    st_mae = mean_absolute_error(station_data['Actual'], station_data['Predicted'])
    st_r2 = r2_score(station_data['Actual'], station_data['Predicted'])

    station_metrics_list.append({ # add evalutation to list
        'Station': station,
        'RMSE': round(st_rmse, 3),
        'MAE': round(st_mae, 3),
        'R2': round(st_r2, 3)
    })
    
    print(f"Samplingpoint {station} -> RMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R2: {st_r2:.2f}")
    

    plt.figure(figsize=(14, 4))
    
    # Using 'Start' for the x-axis datetime timeline
    plt.plot(station_data['Start'], station_data['Actual'], label=f'Actual {POLLUTANT}', color='blue', alpha=0.6)
    plt.plot(station_data['Start'], station_data['Predicted'], label=f'Predicted {POLLUTANT}', color='red', alpha=0.8, linewidth=1.5)
    
    plt.title(f'Samplingpoint {station} | Actual vs Predicted {POLLUTANT}\nRMSE: {st_rmse:.2f} | MAE: {st_mae:.2f} | R²: {st_r2:.2f}')
    plt.xlabel('Date')
    plt.ylabel(f'{POLLUTANT} ug.m-3')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    clean_station_name = str(station).replace(".", "_").replace("/", "_")
    file_name = f"{COUNTRY_CODE}_{POLLUTANT}_{clean_station_name}_predict.png"
    plt.savefig(pred_plot_dir / file_name, dpi=150)

    plt.show()
    plt.close()


# list to df to csv
metrics_df = pd.DataFrame(station_metrics_list)
csv_filename = output_dir / f"{COUNTRY_CODE}_{POLLUTANT}_Every_Station_Metrics.csv"
metrics_df.to_csv(csv_filename, index=False)
# Out:
# RMSE: 5.8572
# MAE:  4.2707
# R2:   0.8413
# Samplingpoint AL/SPO-AL0203A_00008_100 -> RMSE: 4.94 | MAE: 3.67 | R2: 0.51
# Samplingpoint AL/SPO-AL0206A_00008_100 -> RMSE: 3.40 | MAE: 2.47 | R2: 0.67
# Samplingpoint AL/SPO-AL0207A_00008_100 -> RMSE: 6.54 | MAE: 5.10 | R2: 0.82
# Samplingpoint AL/SPO-AL0205A_00008_100 -> RMSE: 8.22 | MAE: 6.31 | R2: 0.43
# Samplingpoint AL/SPO-AL0208A_00008_100 -> RMSE: 4.64 | MAE: 3.54 | R2: 0.57
